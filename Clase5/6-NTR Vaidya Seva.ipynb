# %% [markdown]
# Fuente:
# - https://www.kaggle.com/scratchpad/notebook4031fa4176/edit
# - https://www.kaggle.com/srikarkashyap/analyzing-healthcare-data-tutorial

# %% [markdown]
# # Analizando datos de programas de salud (EDA)

# %% [markdown]
# ## Introducción

# %% [markdown]
# NTR Vaidya Seva (o Arogya Seva) es el programa de salud insignia del gobierno de Anhra Pradesh (India), con el cual las personas de bajos ingresos de ese estado pueden obtener salud pública de forma gratuita para muchas enfermedades y dolencias importantes

# %% [markdown]
# ## A meter código!

# %% [markdown]
# Comenzamos importando las librerias necesarias:
# * *Pandas* para cargar datos y explorar los datos
# * *Matplotlib, Seaborn* para su visualización.

# %%
# Importamos las librerias 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Vamos a leer el archivo de datos usando la función *read_csv* de Pandas. *read_csv* puede leer de manera sencilla archivos de valores separados por comas (csv).
#
# No existen restricciones para nombrar las variables. *df*, *data* son los términos genéricos más comunes. Arrancamos con *data*.

# %%
# Leemos el dataframe
data = pd.read_csv('https://github.com/matog/iSalud-IntroCienciaDeDatos/raw/main/ntrarogyaseva.zip')
# data = pd.read_csv('data/ntrarogyaseva.csv')

# %% [markdown]
# Explotamos los datos con la función *head()* que por defecto, muestra los primeros 5 datos.

# %%
data.sample(5)
# Out:
#                 AGE     SEX CASTE_NAME CATEGORY_CODE  \
# 12820    12821   45  Female         SC            S7
# 247993  247994   56  Female         OC           S13
# 123864  123865   39    Male         BC            S2
# 431272  431273   59    Male         SC            S1
# 79051    79052   50  Female         SC           S13
#
#                              CATEGORY_NAME SURGERY_CODE  \
# 12820   CARDIAC AND CARDIOTHORACIC SURGERY     S7.1.2.1
# 247993                  RADIATION ONCOLOGY    S13.3.1.1
# 123864                        ENT  SURGERY       S2.3.1
# 431272                     GENERAL SURGERY    S1.3.1.10
# 79051                   RADIATION ONCOLOGY      S13.2.1
#
#                                                   SURGERY        VILLAGE  \
# 12820                                  ASD Device Closure  Konakanamitla
# 247993  Brachytherapy Intracavitary I. Ldr Per Applica...        Ward-44
# 123864                           Endoscopic Sinus Surgery        Ward-23
# 431272      Herinoplasty with Mesh Direct Inguinal Hernia     Pernamitta
# 79051   Radical Treatment With Photons External Beam R...         Anjuru
#
#              MANDAL_NAME  ... CLAIM_AMOUNT  \
# 12820      Konakanamitla  ...        80000
# 247993        Vijayawada  ...         5850
# 123864        Vijayawada  ...        10000
# 431272  Santhanuthlapadu  ...        25500
# 79051        K.V.B.Puram  ...        64838
#
#                                              HOSP_NAME  HOSP_TYPE  \
# 12820              Government General Hospital, Guntur          G
# 247993               Guntur Cancer Care Centre Limited          C
# 123864              Govt. General Hospital- Vijayawada          G
# 431272                            Nalluri Nursing Home          C
# 79051   Sri Venkateswara Institute Of Medical Sciences          G
#
#        HOSP_LOCATION  HOSP_DISTRICT         SURGERY_DATE       DISCHARGE_DATE  \
# 12820         GUNTUR         Guntur  29/06/2016 00:00:00  01/07/2016 00:00:00
# 247993        GUNTUR         Guntur  24/03/2017 00:00:00  27/03/2017 00:00:00
# 123864    VIJAYAWADA        Krishna  10/12/2016 00:00:00  19/12/2016 00:00:00
# 431272        Ongole       Prakasam  30/08/2017 00:00:00  11/09/2017 00:00:00
# 79051      TIRUPATHI       Chittoor  29/11/2016 00:00:00  29/11/2016 00:00:00
#
#        Mortality Y / N MORTALITY_DATE SRC_REGISTRATION
# 12820               NO            NaN              CMO
# 247993              NO            NaN                D
# 123864              NO            NaN                D
# 431272              NO            NaN                D
# 79051               NO            NaN                D
#
# [5 rows x 24 columns]

# %%
data.columns
# Out:
# Index(['   ', 'AGE', 'SEX', 'CASTE_NAME', 'CATEGORY_CODE', 'CATEGORY_NAME',
#        'SURGERY_CODE', 'SURGERY', 'VILLAGE', 'MANDAL_NAME', 'DISTRICT_NAME',
#        'PREAUTH_DATE', 'PREAUTH_AMT', 'CLAIM_DATE', 'CLAIM_AMOUNT',
#        'HOSP_NAME', 'HOSP_TYPE', 'HOSP_LOCATION', 'HOSP_DISTRICT',
#        'SURGERY_DATE', 'DISCHARGE_DATE', 'Mortality Y / N', 'MORTALITY_DATE',
#        'SRC_REGISTRATION'],
#       dtype='object')

# %% [markdown]
# Ahora vamos a mostrar algunas estadisticas simples de las columnas numéricas del dataset. Utilizamos la función *describe* de los datos para obtenerlas..

# %%
# Estadísticas descriptivas
# data.describe(include='all') # Incluye todas las variables
data.describe()
# Out:
#                                 AGE    PREAUTH_AMT   CLAIM_AMOUNT
# count  479688.000000  479688.000000  479688.000000  479688.000000
# mean   239844.500000      44.912264   30428.941698   27652.205861
# std    138474.142301      18.961084   27441.592281   25951.706037
# min         1.000000       0.000000       5.000000       2.000000
# 25%    119922.750000      34.000000   12500.000000   12500.000000
# 50%    239844.500000      47.000000   25000.000000   23200.000000
# 75%    359766.250000      59.000000   35000.000000   30600.000000
# max    479688.000000     107.000000  520000.000000  520000.000000

# %% [markdown]
# Ahora analizamos los nombres de las columnas

# %%
# Matriz de correlación. Texto y grafica. Descomentar la que se quiera ejecutar, y comentar la restante.
# data.corr()
sns.heatmap(data.corr());

# %%
# Muestra los nombres de las columnas en el dataset _data_
data.columns
# Out:
# Index(['   ', 'AGE', 'SEX', 'CASTE_NAME', 'CATEGORY_CODE', 'CATEGORY_NAME',
#        'SURGERY_CODE', 'SURGERY', 'VILLAGE', 'MANDAL_NAME', 'DISTRICT_NAME',
#        'PREAUTH_DATE', 'PREAUTH_AMT', 'CLAIM_DATE', 'CLAIM_AMOUNT',
#        'HOSP_NAME', 'HOSP_TYPE', 'HOSP_LOCATION', 'HOSP_DISTRICT',
#        'SURGERY_DATE', 'DISCHARGE_DATE', 'Mortality Y / N', 'MORTALITY_DATE',
#        'SRC_REGISTRATION'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479688 entries, 0 to 479687
# Data columns (total 24 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0                     479688 non-null  int64
#  1   AGE               479688 non-null  int64
#  2   SEX               479688 non-null  object
#  3   CASTE_NAME        479688 non-null  object
#  4   CATEGORY_CODE     479688 non-null  object
#  5   CATEGORY_NAME     479688 non-null  object
#  6   SURGERY_CODE      479688 non-null  object
#  7   SURGERY           479688 non-null  object
#  8   VILLAGE           479688 non-null  object
#  9   MANDAL_NAME       479688 non-null  object
#  10  DISTRICT_NAME     479688 non-null  object
#  11  PREAUTH_DATE      479688 non-null  object
#  12  PREAUTH_AMT       479688 non-null  int64
#  13  CLAIM_DATE        479688 non-null  object
#  14  CLAIM_AMOUNT      479688 non-null  int64
#  15  HOSP_NAME         479688 non-null  object
#  16  HOSP_TYPE         479688 non-null  object
#  17  HOSP_LOCATION     479688 non-null  object
#  18  HOSP_DISTRICT     479688 non-null  object
#  19  SURGERY_DATE      479688 non-null  object
#  20  DISCHARGE_DATE    475128 non-null  object
#  21  Mortality Y / N   479688 non-null  object
#  22  MORTALITY_DATE    10122 non-null   object
#  23  SRC_REGISTRATION  479688 non-null  object
# dtypes: int64(4), object(20)
# memory usage: 87.8+ MB

# %% [markdown]
# ### Tamaño del dataframe

# %%
data[['SURGERY']].value_counts()
# Out:
# SURGERY
# Maintenance Hemodialysis For Crf                               65378
# Surgical Correction Of Longbone Fracture                       55752
# Coronary Balloon Angioplasty with Drug eluting stent(00.45)    17175
# Chemotherapy for Cervical Cancer with Weekly Cisplatin         17123
# ursl                                                           15499
#                                                                ...
# Excision of Carotid Body Tumours                                   1
# Surgical management of Malrotation                                 1
# Surgical management of Empyema Thoracis                            1
# Surgical Correction of Hemifacial Atrophy                          1
# Femoro- Ileal Bypass Without Graft                                 1
# Length: 923, dtype: int64

# %%
data.shape
# Out:
# (479688, 24)

# %% [markdown]
# ### Creación de variables
# Es muy útil trabajar con las variables existentes para generar nueva información.

# %%
data['CATEGORY'] = data['CATEGORY_CODE'] + ' - ' + data['CATEGORY_NAME']
data[['CATEGORY_CODE', 'CATEGORY_NAME', 'CATEGORY']].sample(10)
# Out:
#        CATEGORY_CODE                       CATEGORY_NAME  \
# 278972            M5                          CARDIOLOGY
# 252941            S7  CARDIAC AND CARDIOTHORACIC SURGERY
# 340610            M4                          PEDIATRICS
# 337903           S11                   SURGICAL ONCOLOGY
# 36422             M6                          NEPHROLOGY
# 148685           S12                    MEDICAL ONCOLOGY
# 294179           S15                         POLY TRAUMA
# 165367            M6                          NEPHROLOGY
# 171211           S15                         POLY TRAUMA
# 139921            S9            GENITO URINARY SURGERIES
#
#                                        CATEGORY
# 278972                          M5 - CARDIOLOGY
# 252941  S7 - CARDIAC AND CARDIOTHORACIC SURGERY
# 340610                          M4 - PEDIATRICS
# 337903                  S11 - SURGICAL ONCOLOGY
# 36422                           M6 - NEPHROLOGY
# 148685                   S12 - MEDICAL ONCOLOGY
# 294179                        S15 - POLY TRAUMA
# 165367                          M6 - NEPHROLOGY
# 171211                        S15 - POLY TRAUMA
# 139921            S9 - GENITO URINARY SURGERIES

# %%
data['DIFF'] = data['CLAIM_AMOUNT'] - data['PREAUTH_AMT']

# %%
data[['CLAIM_AMOUNT','PREAUTH_AMT', 'DIFF']]
# Out:
#         CLAIM_AMOUNT  PREAUTH_AMT  DIFF
# 0              11000        12500 -1500
# 1              11000        12500 -1500
# 2              11500        12500 -1000
# 3              11000        12500 -1500
# 4              11000        12500 -1500
# ...              ...          ...   ...
# 479683         24910        24910     0
# 479684         45910        45910     0
# 479685         30000        30000     0
# 479686         23020        23020     0
# 479687         23020        23020     0
#
# [479688 rows x 3 columns]

# %%
# Eliminamos las variables recién creadas
# data.drop(['DIFF', 'CATEGORY_NAME'], axis = 1, inplace = True)

# %%
data.head(2)
# Out:
#         AGE     SEX CASTE_NAME CATEGORY_CODE CATEGORY_NAME SURGERY_CODE  \
# 0    1   56  Female         BC            M6    NEPHROLOGY         M6.5
# 1    2   37    Male         BC            M6    NEPHROLOGY         M6.5
#
#                             SURGERY    VILLAGE MANDAL_NAME  ... HOSP_TYPE  \
# 0  Maintenance Hemodialysis For Crf     Lolugu     Ponduru  ...         G
# 1  Maintenance Hemodialysis For Crf  Borivanka      Kaviti  ...         G
#
#   HOSP_LOCATION  HOSP_DISTRICT         SURGERY_DATE       DISCHARGE_DATE  \
# 0    SRIKAKULAM     Srikakulam  06/08/2013 00:00:00  07/09/2013 00:00:00
# 1    SRIKAKULAM     Srikakulam  08/08/2013 00:00:00  09/09/2013 00:00:00
#
#   Mortality Y / N MORTALITY_DATE SRC_REGISTRATION         CATEGORY  DIFF
# 0              NO            NaN                D  M6 - NEPHROLOGY -1500
# 1              NO            NaN                D  M6 - NEPHROLOGY -1500
#
# [2 rows x 26 columns]

# %% [markdown]
# ### Corrección de formatos

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479688 entries, 0 to 479687
# Data columns (total 26 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0                     479688 non-null  int64
#  1   AGE               479688 non-null  int64
#  2   SEX               479688 non-null  object
#  3   CASTE_NAME        479688 non-null  object
#  4   CATEGORY_CODE     479688 non-null  object
#  5   CATEGORY_NAME     479688 non-null  object
#  6   SURGERY_CODE      479688 non-null  object
#  7   SURGERY           479688 non-null  object
#  8   VILLAGE           479688 non-null  object
#  9   MANDAL_NAME       479688 non-null  object
#  10  DISTRICT_NAME     479688 non-null  object
#  11  PREAUTH_DATE      479688 non-null  object
#  12  PREAUTH_AMT       479688 non-null  int64
#  13  CLAIM_DATE        479688 non-null  object
#  14  CLAIM_AMOUNT      479688 non-null  int64
#  15  HOSP_NAME         479688 non-null  object
#  16  HOSP_TYPE         479688 non-null  object
#  17  HOSP_LOCATION     479688 non-null  object
#  18  HOSP_DISTRICT     479688 non-null  object
#  19  SURGERY_DATE      479688 non-null  object
#  20  DISCHARGE_DATE    475128 non-null  object
#  21  Mortality Y / N   479688 non-null  object
#  22  MORTALITY_DATE    10122 non-null   object
#  23  SRC_REGISTRATION  479688 non-null  object
#  24  CATEGORY          479688 non-null  object
#  25  DIFF              479688 non-null  int64
# dtypes: int64(5), object(21)
# memory usage: 95.2+ MB

# %% [markdown]
# Las columnas PREAUTH_DATE, CLAIM_DATE, SURGERY_DATE, DISCHARGE_DATE y MORTALITY_DATE son cargadas como si fueran del tipo Object, cuando en realidad deberían ser levantadas como fechas

# %%
from datetime import datetime

# %%
# Convertimos el campo DISCHARGE_DATE a fecha. Tira un error
data['DISCHARGE_DATE'] = pd.to_datetime(data['DISCHARGE_DATE'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2236, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2235 try:
# -> 2236     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2237     # If tzaware, these values represent unix timestamps, so we
#    2238     #  return them as i8 to distinguish from wall times
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       1 # Convertimos el campo DISCHARGE_DATE a fecha. Tira un error
# ----> 2 data['DISCHARGE_DATE'] = pd.to_datetime(data['DISCHARGE_DATE'])
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:1047, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045             result = arg.tz_localize(tz)
#    1046 elif isinstance(arg, ABCSeries):
# -> 1047     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1048     if not cache_array.empty:
#    1049         result = arg.map(cache_array)
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# --> 197     cache_dates = convert_listlike(unique_dates, format)
#     198     cache_array = Series(cache_dates, index=unique_dates)
#     199     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/core/tools/datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2242, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2240         return values.view("i8"), tz_parsed
#    2241     except (ValueError, TypeError):
# -> 2242         raise err
#    2244 if tz_parsed is not None:
#    2245     # We can take a shortcut since the datetime64 numpy array
#    2246     #  is in UTC
#    2247     # Return i8 values to denote unix timestamps
#    2248     return result.view("i8"), tz_parsed
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/core/arrays/datetimes.py:2224, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2222 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2223 try:
# -> 2224     result, tz_parsed = tslib.array_to_datetime(
#    2225         data.ravel("K"),
#    2226         errors=errors,
#    2227         utc=utc,
#    2228         dayfirst=dayfirst,
#    2229         yearfirst=yearfirst,
#    2230         require_iso8601=require_iso8601,
#    2231         allow_mixed=allow_mixed,
#    2232     )
#    2233     result = result.reshape(data.shape, order=order)
#    2234 except ValueError as err:
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:608, in pandas._libs.tslib.array_to_datetime()
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:604, in pandas._libs.tslib.array_to_datetime()
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/_libs/tslib.pyx:559, in pandas._libs.tslib.array_to_datetime()
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/_libs/tslibs/conversion.pyx:517, in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# File ~/jupyter/jupyterenv/lib/python3.10/site-packages/pandas/_libs/tslibs/np_datetime.pyx:120, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 116-04-30 00:00:00

# %%
# Buscamos el error:
# Alternativa I:
data.loc[data['DISCHARGE_DATE'].str.contains('116', na=False)]
# Out:
#             AGE   SEX CASTE_NAME CATEGORY_CODE CATEGORY_NAME SURGERY_CODE  \
# 1767  1768   44  Male         ST            M6    NEPHROLOGY         M6.5
# 2856  2857   44  Male         ST            M6    NEPHROLOGY         M6.5
#
#                                SURGERY        VILLAGE   MANDAL_NAME  ...  \
# 1767  Maintenance Hemodialysis For Crf     Ratnapuram       Chintur  ...
# 2856  Maintenance Hemodialysis For Crf  Kusumanapalli  Bhadrachalam  ...
#
#      HOSP_TYPE HOSP_LOCATION  HOSP_DISTRICT         SURGERY_DATE  \
# 1767         G       KHAMMAM        Khammam  27/01/2016 00:00:00
# 2856         G       KHAMMAM        Khammam  02/03/2016 00:00:00
#
#            DISCHARGE_DATE Mortality Y / N       MORTALITY_DATE  \
# 1767  30/04/0116 00:00:00             YES  30/04/2016 00:00:00
# 2856  30/04/0116 00:00:00             YES  30/04/2016 00:00:00
#
#      SRC_REGISTRATION         CATEGORY DIFF
# 1767                D  M6 - NEPHROLOGY    0
# 2856                D  M6 - NEPHROLOGY    0
#
# [2 rows x 26 columns]

# %%
# Buscamos el error:
# Alternativa II
data.loc[data['DISCHARGE_DATE']=='30/04/0116 00:00:00']
# Out:
# Empty DataFrame
# Columns: [   , AGE, SEX, CASTE_NAME, CATEGORY_CODE, CATEGORY_NAME, SURGERY_CODE, SURGERY, VILLAGE, MANDAL_NAME, DISTRICT_NAME, PREAUTH_DATE, PREAUTH_AMT, CLAIM_DATE, CLAIM_AMOUNT, HOSP_NAME, HOSP_TYPE, HOSP_LOCATION, HOSP_DISTRICT, SURGERY_DATE, DISCHARGE_DATE, Mortality Y / N, MORTALITY_DATE, SRC_REGISTRATION, CATEGORY, DIFF]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Reemplazamos los datos erroneos:
# Alternativa I
mappings = {'30/04/0116 00:00:00':'30/04/2016 00:00:00'}

# %%
data['DISCHARGE_DATE'] = data['DISCHARGE_DATE'].replace(mappings)

# %%
# Alternativa II
data.loc[data['DISCHARGE_DATE']=='30/04/0116 00:00:00', 'DISCHARGE_DATE'] = '30/04/2016 00:00:00'

# %%
# Convertimos el campo DISCHARGE_DATE a fecha nuevamente
data['DISCHARGE_DATE'] = pd.to_datetime(data['DISCHARGE_DATE'])

# %%
data['PREAUTH_DATE'] = pd.to_datetime(data['PREAUTH_DATE'])

# %%
data['CLAIM_DATE'] = pd.to_datetime(data['CLAIM_DATE'])

# %%
data['MORTALITY_DATE'] = pd.to_datetime(data['MORTALITY_DATE'])

# %%
data['SURGERY_DATE'] = pd.to_datetime(data['SURGERY_DATE'])

# %%
# Borramos la columna que tiene el índice del CSV 
data = data.drop('   ', axis = 1)

# %%
# data.to_csv('data/ntrarogyaseva_fixed.csv', index = False)

# %% [markdown]
# ### NAN Values

# %%
data.isnull().sum()
# data['DISCHARGE_DATE'].isnull().sum()
# Out:
# AGE                      0
# SEX                      0
# CASTE_NAME               0
# CATEGORY_CODE            0
# CATEGORY_NAME            0
# SURGERY_CODE             0
# SURGERY                  0
# VILLAGE                  0
# MANDAL_NAME              0
# DISTRICT_NAME            0
# PREAUTH_DATE             0
# PREAUTH_AMT              0
# CLAIM_DATE               0
# CLAIM_AMOUNT             0
# HOSP_NAME                0
# HOSP_TYPE                0
# HOSP_LOCATION            0
# HOSP_DISTRICT            0
# SURGERY_DATE             0
# DISCHARGE_DATE        4560
# Mortality Y / N          0
# MORTALITY_DATE      469566
# SRC_REGISTRATION         0
# CATEGORY                 0
# DIFF                     0
# dtype: int64

# %%
# DISCHARGE_DATE tiene NAs porque pueden referirse a los pacientes que siguen internados o no tienen el alta
data.loc[data['DISCHARGE_DATE'].isna()]
# Out:
#         AGE          SEX  CASTE_NAME CATEGORY_CODE  CATEGORY_NAME  \
# 7        73         Male          BC            M6     NEPHROLOGY
# 10       52         Male          BC            M6     NEPHROLOGY
# 86       40         Male          SC            M6     NEPHROLOGY
# 97       75         Male          BC            M6     NEPHROLOGY
# 122      58       Female          SC            M6     NEPHROLOGY
# ...     ...          ...         ...           ...            ...
# 479300   69         Male          OC            M6     NEPHROLOGY
# 479305   60       Female          BC            M6     NEPHROLOGY
# 479372   67       Female          BC            M5     CARDIOLOGY
# 479403    0  Male(Child)  Minorities            M4     PEDIATRICS
# 479404   46       Female          BC            M1  CRITICAL CARE
#
#        SURGERY_CODE                                            SURGERY  \
# 7              M6.5                   Maintenance Hemodialysis For Crf
# 10             M6.5                   Maintenance Hemodialysis For Crf
# 86             M6.5                   Maintenance Hemodialysis For Crf
# 97             M6.5                   Maintenance Hemodialysis For Crf
# 122            M6.5                   Maintenance Hemodialysis For Crf
# ...             ...                                                ...
# 479300         M6.5                   Maintenance Hemodialysis For Crf
# 479305         M6.5                   Maintenance Hemodialysis For Crf
# 479372       M5.1.2              Management Of Acute MI With Angiogram
# 479403      M4.1.14  Medical Management of Term Baby With Severe Pe...
# 479404         M1.4                         Medical Management of ARDS
#
#                  VILLAGE     MANDAL_NAME   DISTRICT_NAME  ... HOSP_TYPE  \
# 7            Bhoghapuram     Bhoghapuram    Vizianagaram  ...         C
# 10                 Rajam   Butchayyapeta  Vishakhapatnam  ...         C
# 86             Dakamarri  Bheemunipatnam  Vishakhapatnam  ...         C
# 97               Ward-13      Vijayawada         Krishna  ...         C
# 122            Mudunuruu         Vuyyuru         Krishna  ...         C
# ...                  ...             ...             ...  ...       ...
# 479300    Badvel (P) (U)          Badvel      YSR Kadapa  ...         C
# 479305  Garividi (Urban)        Garividi    Vizianagaram  ...         C
# 479372         Ambapuram         Nellore         Nellore  ...         C
# 479403        Guntur (U)          Guntur          Guntur  ...         C
# 479404        Poolathota  Doravarisatram         Nellore  ...         C
#
#         HOSP_LOCATION   HOSP_DISTRICT  SURGERY_DATE DISCHARGE_DATE  \
# 7       Visakhapatnam  Vishakhapatnam    2014-05-05            NaT
# 10      Visakhapatnam  Vishakhapatnam    2014-06-27            NaT
# 86      Visakhapatnam  Vishakhapatnam    2015-02-23            NaT
# 97         VIJAYAWADA         Krishna    2015-08-04            NaT
# 122        VIJAYAWADA         Krishna    2015-06-15            NaT
# ...               ...             ...           ...            ...
# 479300        NELLORE         Nellore    2017-10-11            NaT
# 479305   VIZIANAGARAM    Vizianagaram    2017-12-11            NaT
# 479372        NELLORE         Nellore    2017-10-11            NaT
# 479403    NARSARAOPET          Guntur    2017-11-11            NaT
# 479404        NELLORE         Nellore    2017-11-11            NaT
#
#        Mortality Y / N MORTALITY_DATE SRC_REGISTRATION            CATEGORY  \
# 7                  YES     2014-05-23                D     M6 - NEPHROLOGY
# 10                 YES     2014-07-16                P     M6 - NEPHROLOGY
# 86                 YES     2015-10-03                D     M6 - NEPHROLOGY
# 97                 YES     2015-03-05                P     M6 - NEPHROLOGY
# 122                YES     2015-08-23                D     M6 - NEPHROLOGY
# ...                ...            ...              ...                 ...
# 479300             YES     2017-11-11                D     M6 - NEPHROLOGY
# 479305             YES     2017-11-26                D     M6 - NEPHROLOGY
# 479372             YES     2017-11-11                D     M5 - CARDIOLOGY
# 479403             YES     2017-11-17                D     M4 - PEDIATRICS
# 479404             YES     2017-11-11                D  M1 - CRITICAL CARE
#
#          DIFF
# 7       -7500
# 10      -6250
# 86      -6250
# 97      -2500
# 122     -1250
# ...       ...
# 479300  -9252
# 479305  -5140
# 479372 -20000
# 479403 -10000
# 479404 -90000
#
# [4560 rows x 25 columns]

# %%
# Podemos chequear si hay pacientes con DISCHARGE_DATE NA y que hallan fallecido
data.loc[(data['Mortality Y / N']=='YES') & (data['DISCHARGE_DATE'].isna())]
# Out:
#         AGE          SEX  CASTE_NAME CATEGORY_CODE  CATEGORY_NAME  \
# 7        73         Male          BC            M6     NEPHROLOGY
# 10       52         Male          BC            M6     NEPHROLOGY
# 86       40         Male          SC            M6     NEPHROLOGY
# 97       75         Male          BC            M6     NEPHROLOGY
# 122      58       Female          SC            M6     NEPHROLOGY
# ...     ...          ...         ...           ...            ...
# 479300   69         Male          OC            M6     NEPHROLOGY
# 479305   60       Female          BC            M6     NEPHROLOGY
# 479372   67       Female          BC            M5     CARDIOLOGY
# 479403    0  Male(Child)  Minorities            M4     PEDIATRICS
# 479404   46       Female          BC            M1  CRITICAL CARE
#
#        SURGERY_CODE                                            SURGERY  \
# 7              M6.5                   Maintenance Hemodialysis For Crf
# 10             M6.5                   Maintenance Hemodialysis For Crf
# 86             M6.5                   Maintenance Hemodialysis For Crf
# 97             M6.5                   Maintenance Hemodialysis For Crf
# 122            M6.5                   Maintenance Hemodialysis For Crf
# ...             ...                                                ...
# 479300         M6.5                   Maintenance Hemodialysis For Crf
# 479305         M6.5                   Maintenance Hemodialysis For Crf
# 479372       M5.1.2              Management Of Acute MI With Angiogram
# 479403      M4.1.14  Medical Management of Term Baby With Severe Pe...
# 479404         M1.4                         Medical Management of ARDS
#
#                  VILLAGE     MANDAL_NAME   DISTRICT_NAME  ... HOSP_TYPE  \
# 7            Bhoghapuram     Bhoghapuram    Vizianagaram  ...         C
# 10                 Rajam   Butchayyapeta  Vishakhapatnam  ...         C
# 86             Dakamarri  Bheemunipatnam  Vishakhapatnam  ...         C
# 97               Ward-13      Vijayawada         Krishna  ...         C
# 122            Mudunuruu         Vuyyuru         Krishna  ...         C
# ...                  ...             ...             ...  ...       ...
# 479300    Badvel (P) (U)          Badvel      YSR Kadapa  ...         C
# 479305  Garividi (Urban)        Garividi    Vizianagaram  ...         C
# 479372         Ambapuram         Nellore         Nellore  ...         C
# 479403        Guntur (U)          Guntur          Guntur  ...         C
# 479404        Poolathota  Doravarisatram         Nellore  ...         C
#
#         HOSP_LOCATION   HOSP_DISTRICT  SURGERY_DATE DISCHARGE_DATE  \
# 7       Visakhapatnam  Vishakhapatnam    2014-05-05            NaT
# 10      Visakhapatnam  Vishakhapatnam    2014-06-27            NaT
# 86      Visakhapatnam  Vishakhapatnam    2015-02-23            NaT
# 97         VIJAYAWADA         Krishna    2015-08-04            NaT
# 122        VIJAYAWADA         Krishna    2015-06-15            NaT
# ...               ...             ...           ...            ...
# 479300        NELLORE         Nellore    2017-10-11            NaT
# 479305   VIZIANAGARAM    Vizianagaram    2017-12-11            NaT
# 479372        NELLORE         Nellore    2017-10-11            NaT
# 479403    NARSARAOPET          Guntur    2017-11-11            NaT
# 479404        NELLORE         Nellore    2017-11-11            NaT
#
#        Mortality Y / N MORTALITY_DATE SRC_REGISTRATION            CATEGORY  \
# 7                  YES     2014-05-23                D     M6 - NEPHROLOGY
# 10                 YES     2014-07-16                P     M6 - NEPHROLOGY
# 86                 YES     2015-10-03                D     M6 - NEPHROLOGY
# 97                 YES     2015-03-05                P     M6 - NEPHROLOGY
# 122                YES     2015-08-23                D     M6 - NEPHROLOGY
# ...                ...            ...              ...                 ...
# 479300             YES     2017-11-11                D     M6 - NEPHROLOGY
# 479305             YES     2017-11-26                D     M6 - NEPHROLOGY
# 479372             YES     2017-11-11                D     M5 - CARDIOLOGY
# 479403             YES     2017-11-17                D     M4 - PEDIATRICS
# 479404             YES     2017-11-11                D  M1 - CRITICAL CARE
#
#          DIFF
# 7       -7500
# 10      -6250
# 86      -6250
# 97      -2500
# 122     -1250
# ...       ...
# 479300  -9252
# 479305  -5140
# 479372 -20000
# 479403 -10000
# 479404 -90000
#
# [4559 rows x 25 columns]

# %%
# Los MORTALITY_DATE en blanco, es porque no falleció o por error en la base
data.loc[(data['Mortality Y / N']=='NO') & (data['MORTALITY_DATE'].isna())]
# Out:
#         AGE     SEX CASTE_NAME CATEGORY_CODE  \
# 0        56  Female         BC            M6
# 1        37    Male         BC            M6
# 2        50    Male         BC            M6
# 3        45    Male         BC            M6
# 4        54    Male         BC            M6
# ...     ...     ...        ...           ...
# 479683   22  Female         BC            S4
# 479684   60    Male         BC           S12
# 479685   38    Male         OC           S15
# 479686   59    Male         OC            S3
# 479687   63    Male         OC            S3
#
#                               CATEGORY_NAME SURGERY_CODE  \
# 0                                NEPHROLOGY         M6.5
# 1                                NEPHROLOGY         M6.5
# 2                                NEPHROLOGY         M6.5
# 3                                NEPHROLOGY         M6.5
# 4                                NEPHROLOGY         M6.5
# ...                                     ...          ...
# 479683  GYNAECOLOGY AND OBSTETRICS  SURGERY       S4.2.2
# 479684                     MEDICAL ONCOLOGY   S12.16.2.2
# 479685                          POLY TRAUMA      S15.1.1
# 479686               OPHTHALMOLOGY  SURGERY       S3.3.1
# 479687               OPHTHALMOLOGY  SURGERY       S3.3.1
#
#                                                   SURGERY        VILLAGE  \
# 0                        Maintenance Hemodialysis For Crf         Lolugu
# 1                        Maintenance Hemodialysis For Crf      Borivanka
# 2                        Maintenance Hemodialysis For Crf    Kapasakuddi
# 3                        Maintenance Hemodialysis For Crf    Telikipenta
# 4                        Maintenance Hemodialysis For Crf  Thandemvalasa
# ...                                                   ...            ...
# 479683                            Laparoscopic Cystectomy  Kalayakagollu
# 479684  Chemotherapy for Non Hodgkin Lymphoma with  R ...      Rajupalem
# 479685           Surgical Correction Of Longbone Fracture         Yeturu
# 479686                                         Vitrectomy    Ganapavaram
# 479687                                         Vitrectomy    Savarigudem
#
#              MANDAL_NAME  DISTRICT_NAME  ... HOSP_TYPE  HOSP_LOCATION  \
# 0                Ponduru     Srikakulam  ...         G     SRIKAKULAM
# 1                 Kaviti     Srikakulam  ...         G     SRIKAKULAM
# 2                 Kaviti     Srikakulam  ...         G     SRIKAKULAM
# 3            Sarubujjili     Srikakulam  ...         G     SRIKAKULAM
# 4             Srikakulam     Srikakulam  ...         G     SRIKAKULAM
# ...                  ...            ...  ...       ...            ...
# 479683  Butchireddipalem        Nellore  ...         C        NELLORE
# 479684       Kothapatnam       Prakasam  ...         C         GUNTUR
# 479685          Chejerla        Nellore  ...         C        NELLORE
# 479686       Ganapavaram  West Godavari  ...         C         GUNTUR
# 479687        Gannavaram        Krishna  ...         C         GUNTUR
#
#        HOSP_DISTRICT  SURGERY_DATE DISCHARGE_DATE Mortality Y / N  \
# 0         Srikakulam    2013-06-08     2013-07-09              NO
# 1         Srikakulam    2013-08-08     2013-09-09              NO
# 2         Srikakulam    2013-08-15     2013-10-18              NO
# 3         Srikakulam    2013-08-24     2013-09-27              NO
# 4         Srikakulam    2013-08-31     2013-02-10              NO
# ...              ...           ...            ...             ...
# 479683       Nellore    2017-11-15     2017-11-19              NO
# 479684        Guntur    2017-11-17     2017-11-18              NO
# 479685       Nellore    2017-11-16     2017-11-18              NO
# 479686        Guntur    2017-11-16     2017-11-18              NO
# 479687        Guntur    2017-11-16     2017-11-18              NO
#
#        MORTALITY_DATE SRC_REGISTRATION  \
# 0                 NaT                D
# 1                 NaT                D
# 2                 NaT                D
# 3                 NaT                D
# 4                 NaT                D
# ...               ...              ...
# 479683            NaT                D
# 479684            NaT                D
# 479685            NaT                D
# 479686            NaT                D
# 479687            NaT                D
#
#                                         CATEGORY  DIFF
# 0                                M6 - NEPHROLOGY -1500
# 1                                M6 - NEPHROLOGY -1500
# 2                                M6 - NEPHROLOGY -1000
# 3                                M6 - NEPHROLOGY -1500
# 4                                M6 - NEPHROLOGY -1500
# ...                                          ...   ...
# 479683  S4 - GYNAECOLOGY AND OBSTETRICS  SURGERY     0
# 479684                    S12 - MEDICAL ONCOLOGY     0
# 479685                         S15 - POLY TRAUMA     0
# 479686               S3 - OPHTHALMOLOGY  SURGERY     0
# 479687               S3 - OPHTHALMOLOGY  SURGERY     0
#
# [469566 rows x 25 columns]

# %% [markdown]
# ### map, apply, mapapply

# %%
# data = pd.read_csv('data/ntrarogyaseva_fixed.csv')

# %%
data['CASTE_NAME'].value_counts()

# %% [markdown]
# | Sigla       | Definición|
# |-----------|---------------------|
# | OC:       | other category |
# | BC:       | backward class    |
# | SC:       | scheduded caste    |
# | ST:       | scheduled tribes   |
# | obc       |other backward class    |

# %%
# map: mapea valores de una serie
caste_mapper = { 'OC':'other category',
                 'BC':'backward class',
                 'SC':'scheduled caste',
                 'ST':'scheduled tribes',
                 'Minorities':'Minorities',
                 'Others':'Others'
}

data['CASTE_NAME'] = data['CASTE_NAME'].map(caste_mapper)

# %%
# Apply
# 'Aplica' una función a un eje del DataFrame
#     axis=0: Aplica la función a cada fila
#     axis=1: Aplica la función a cada columna


# Supongamos que el programa aplica una serie de descuentos sobre los costos de la operación según la edad
def calculate_total_cost(row):
    total_cost = 0
    if (row['AGE']<80) & (row['AGE']>69):
        total_cost = row['PREAUTH_AMT'] - row['PREAUTH_AMT']*0.20
    if (row['AGE']<70) & (row['AGE']>59):
        total_cost = row['PREAUTH_AMT'] - row['PREAUTH_AMT']*0.15
    if (row['AGE']<60) & (row['AGE']>49):
        total_cost = row['PREAUTH_AMT'] - row['PREAUTH_AMT']*0.10
    return total_cost


def calculate_group_age(row):
    AGE_CAT = ''
    if (row['AGE']<10) :
        AGE_CAT = 'Child'
    if (row['AGE']<18) & (row['AGE']>9):
        AGE_CAT = 'Young'
    return AGE_CAT

# %%
# data.apply(calculate_total_cost, axis=1)
data['DISCOUNT_COST'] = data.apply(calculate_total_cost, axis=1)

# data['GROUP_AGE'] = data.apply(calculate_group_age, axis=1)

# %%
data[['AGE', 'PREAUTH_AMT', 'DISCOUNT_COST']]
# Out:
#         AGE  PREAUTH_AMT  DISCOUNT_COST
# 0        56        12500        11250.0
# 1        37        12500            0.0
# 2        50        12500        11250.0
# 3        45        12500            0.0
# 4        54        12500        11250.0
# ...     ...          ...            ...
# 479683   22        24910            0.0
# 479684   60        45910        39023.5
# 479685   38        30000            0.0
# 479686   59        23020        20718.0
# 479687   63        23020        19567.0
#
# [479688 rows x 3 columns]

# %%
# Generamos un dataframe mas chico para poder trabajar de manera rápida
data_cut = data.groupby(['CASTE_NAME']).median().reset_index()
# data_cut.to_csv('data/data_cut_caste_groupby.csv', index = False)
data_cut
# Out:
#          CASTE_NAME   AGE  PREAUTH_AMT  CLAIM_AMOUNT  DIFF  DISCOUNT_COST
# 0        Minorities  46.0      26000.0       24419.0   0.0            0.0
# 1            Others  48.0      25989.0       25000.0   0.0            0.0
# 2    backward class  46.0      25000.0       22500.0   0.0            0.0
# 3    other category  51.0      25000.0       24000.0   0.0         2925.0
# 4   scheduled caste  45.0      25989.0       24000.0   0.0            0.0
# 5  scheduled tribes  41.0      29146.0       24910.0   0.0            0.0

# %%
# Si queremos sumar los valores de una columna  y crear una columna total, usamos axis=0

def add_everything(column):
    return column.sum()

# %%
data_cut.loc['sum'] = data_cut.apply(add_everything, axis=0)
data_cut
# Out:
#                                             CASTE_NAME    AGE  PREAUTH_AMT  \
# 0                                           Minorities   46.0      26000.0
# 1                                               Others   48.0      25989.0
# 2                                       backward class   46.0      25000.0
# 3                                       other category   51.0      25000.0
# 4                                      scheduled caste   45.0      25989.0
# 5                                     scheduled tribes   41.0      29146.0
# sum  MinoritiesOthersbackward classother categorysc...  277.0     157124.0
#
#      CLAIM_AMOUNT  DIFF  DISCOUNT_COST
# 0         24419.0   0.0            0.0
# 1         25000.0   0.0            0.0
# 2         22500.0   0.0            0.0
# 3         24000.0   0.0         2925.0
# 4         24000.0   0.0            0.0
# 5         24910.0   0.0            0.0
# sum      144829.0   0.0         2925.0

# %%
# Applymap: Aplica una función a todo el dataframe

def show_len(element):
    return len(str(element))

data_cut.applymap(show_len)
# Out:
#      CASTE_NAME  AGE  PREAUTH_AMT  CLAIM_AMOUNT  DIFF  DISCOUNT_COST
# 0            10    4            7             7     3              3
# 1             6    4            7             7     3              3
# 2            14    4            7             7     3              3
# 3            14    4            7             7     3              6
# 4            15    4            7             7     3              3
# 5            16    4            7             7     3              3
# sum          75    5            8             8     3              6

# %% [markdown]
# ## Analizando un poco mas profundo...

# %% [markdown]
# ### Cual es la distribución de la variable SEX?

# %% [markdown]
# *value_counts()* es una función de Pandas que puede ser usada para obtener la distribución de los datos, en la columna que se especifique.

# %%
# Cantidad de cada valor en la columna SEX
data['SEX'].value_counts()
# Out:
# Male             260718
# Female           178947
# Male(Child)       25068
# Female(Child)     14925
# FEMALE               21
# MALE                  9
# Name: SEX, dtype: int64

# %% [markdown]
# *CUIDADO*: Existe valores que están ingresados de forma diferente, que refieren al mismo valor. *Male* and *MALE* no representan valores diferentes!
#
# Es posible hacer un *replace* de los valores mal ingresados para normalizar la variable.
# (Ademas de reemplazar Male (Child) -> Boy and Female (Child) -> Girl por conveniencia)

# %%
# Mapeamos para normalizar
mappings = {'MALE' : 'Male', 
            'FEMALE' : 'Female', 
            'Male(Child)' : 'Boy', 
            'Female(Child)' : 'Girl'}

# %%
# Reemplazamos los valores utilizando el mapping arriba definido
data['SEX'] = data['SEX'].replace(mappings)
data['SEX'].value_counts()
# Out:
# Male      260727
# Female    178968
# Boy        25068
# Girl       14925
# Name: SEX, dtype: int64

# %% [markdown]
# La visualización de esta información se puede hacer de manera sencilla utilizando la función gráfica que incluye Pandas.

# %%
data_sex = data['SEX'].value_counts()
data_sex
# Out:
# Male      260727
# Female    178968
# Boy        25068
# Girl       14925
# Name: SEX, dtype: int64

# %%
# Value count de Sex de forma gráfica
# data_sex.value_counts().plot.bar()
sex = data['SEX'].value_counts()
sex.plot.bar();

# %% [markdown]
# ### Cual es la distribución de la variable AGE?

# %% [markdown]
# Media, mediana y moda:

# %%
# print the mean, median and mode of the age distribution
print("Media: {}".format(data['AGE'].mean()))
print("Mediana: {}".format(data['AGE'].median()))
print("Moda: {}".format(data['AGE'].mode()))
# Out:
# Media: 44.91226380480646
# Mediana: 47.0
# Moda: 0    0
# Name: AGE, dtype: int64

# %% [markdown]
# Top 10 de las edades mas repetidas.

# %%
# top 10 age
data['AGE'].value_counts().head(10)
# Out:
# 0     17513
# 50    16191
# 55    15184
# 45    15052
# 60    13732
# 46    12858
# 56    12590
# 51    12470
# 40    11962
# 65    11878
# Name: AGE, dtype: int64

# %%
# boxplot para AGE
data['AGE'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# En el grafico de arriba, la caja representa el **[Rango Intercuatilico (IQR, en inglés)](https://es.wikipedia.org/wiki/Rango_intercuart%C3%ADlico)** de los datos.
#
#
# El IQR representa la región donde cae el 50% de los datos. Por ejemplo del 25% al 75% del dataframe.
# Todo dato que cae fuera de 1.5 veces el IQR es considerado, en general, una anomalía (OJO, NO SIEMPRE, DEPENDE DEL CONOCIMIENTO DE LOS DATOS POR PARTE DEL ANALISTA)
#
# Los círculos se considerarían _outliers_
#
# La librería _Seaborn_ ofrece visualizaciones mejores, de forma sencilla.

# %%
# sns.boxplot(data['AGE']) # Devuelve un warning, que se solucina definiendo x e y.
sns.boxplot(x=data['AGE']); # El ; evita la impresión de texto previo al gráfico.

# %% [markdown]
# ### Preguntando y respondiendo con los datos

# %% [markdown]
# Una vez que hayamos realizado una pequeña exploración en los datos, ahora avancemos a realizarnos algunas preguntas para entender mejor el dataframe.

# %% [markdown]
# **Qué debería hacer si sólo quiero analizar los registros que pertenecen al distrito de Krishna?**
#
# Debería selecciononar un subconjunto de datos pertenencientes a Krishna. Pandas lo hace en dos sencillos pasos:
#
#     1. Condición que se debe satisfacer: data['DISTRICT_NAME']=='Krishna'
#     2. Insertamos la condición en el dataframe: [data['DISTRICT_NAME']=='Krishna']

# %%
# subset de datos que pertenecen al distrito de Krishna
krishna = data.loc[data['DISTRICT_NAME']=='Krishna']
krishna.to_csv('data/krishna_cut.csv', index = False)

# %%
data.loc[data['DISTRICT_NAME']=='Krishna'].to_csv('data/krishna_cut.csv', index = False)

# %% [markdown]
# **Estadísticas por categoria de operación**
#
# Vamos a utilizar el _groupby_ de Pandas para construir estadísticas, agrupando los datos por la categoría de operación. El _groupby_ trabaja de forma similar al comando de _SQL_ del mismo nombre

# %%
data.columns
# Out:
# Index(['AGE', 'SEX', 'CASTE_NAME', 'CATEGORY_CODE', 'CATEGORY_NAME',
#        'SURGERY_CODE', 'SURGERY', 'VILLAGE', 'MANDAL_NAME', 'DISTRICT_NAME',
#        'PREAUTH_DATE', 'PREAUTH_AMT', 'CLAIM_DATE', 'CLAIM_AMOUNT',
#        'HOSP_NAME', 'HOSP_TYPE', 'HOSP_LOCATION', 'HOSP_DISTRICT',
#        'SURGERY_DATE', 'DISCHARGE_DATE', 'Mortality Y / N', 'MORTALITY_DATE',
#        'SRC_REGISTRATION', 'CATEGORY', 'DIFF', 'DISCOUNT_COST'],
#       dtype='object')

# %%
# group by surgery para obtener estadísticas
data.groupby(['CATEGORY_NAME','SEX']).mean()
#data.groupby(['CATEGORY_NAME','HOSP_DISTRICT']).mean()
# Out:
#                                                  AGE   PREAUTH_AMT  \
# CATEGORY_NAME                      SEX
# CARDIAC AND CARDIOTHORACIC SURGERY Boy      4.013562  93489.256781
#                                    Female  53.477690  88877.845829
#                                    Girl     4.116635  86519.702677
#                                    Male    54.540619  85984.827489
# CARDIOLOGY                         Boy     11.133333  85490.666667
# ...                                              ...           ...
# SURGICAL GASTRO ENTEROLOGY         Male    45.821070  66707.396321
# SURGICAL ONCOLOGY                  Boy     10.421053  39630.421053
#                                    Female  50.684096  42808.181713
#                                    Girl     8.500000  46669.894737
#                                    Male    52.049853  49753.387897
#
#                                            CLAIM_AMOUNT          DIFF  \
# CATEGORY_NAME                      SEX
# CARDIAC AND CARDIOTHORACIC SURGERY Boy     89437.787523  -4051.469259
#                                    Female  84843.775689  -4034.070140
#                                    Girl    84019.333652  -2500.369025
#                                    Male    81080.929801  -4903.897688
# CARDIOLOGY                         Boy     61929.000000 -23561.666667
# ...                                                 ...           ...
# SURGICAL GASTRO ENTEROLOGY         Male    62079.110368  -4628.285953
# SURGICAL ONCOLOGY                  Boy     34752.263158  -4878.157895
#                                    Female  40411.641629  -2396.540084
#                                    Girl    43262.000000  -3407.894737
#                                    Male    46392.943482  -3360.444415
#
#                                            DISCOUNT_COST
# CATEGORY_NAME                      SEX
# CARDIAC AND CARDIOTHORACIC SURGERY Boy          0.000000
#                                    Female   49627.930155
#                                    Girl         0.000000
#                                    Male     50665.026255
# CARDIOLOGY                         Boy          0.000000
# ...                                                  ...
# SURGICAL GASTRO ENTEROLOGY         Male     22414.826756
# SURGICAL ONCOLOGY                  Boy          0.000000
#                                    Female   20116.906125
#                                    Girl         0.000000
#                                    Male     23897.441189
#
# [105 rows x 5 columns]

# %% [markdown]
# Cochlear Implant Surgery es el que tiene la operación mas costosa. (₹520000 en promedio). Las Protesis (Prostheses) cuestan ₹1200 (las mas baratas). A su vez, el grupo mas joven también para ser el que demanada la Cochlear Implant Surgery: 1.58 años, mientras que Neurology  tiene pacientes de, en promedio, ~56.

# %%
#data.groupby(['HOSP_DISTRICT','CATEGORY_NAME'])['AGE'].mean().reset_index()
data.groupby(['CATEGORY_NAME','SEX']).agg({'AGE':'mean',
                                           'MORTALITY_DATE':'count', 
                                           'DISCHARGE_DATE':'max',
                                           'VILLAGE':'nunique'
                                          }).reset_index()
# Out:
#                           CATEGORY_NAME     SEX        AGE  MORTALITY_DATE  \
# 0    CARDIAC AND CARDIOTHORACIC SURGERY     Boy   4.013562              62
# 1    CARDIAC AND CARDIOTHORACIC SURGERY  Female  53.477690             391
# 2    CARDIAC AND CARDIOTHORACIC SURGERY    Girl   4.116635              40
# 3    CARDIAC AND CARDIOTHORACIC SURGERY    Male  54.540619             535
# 4                            CARDIOLOGY     Boy  11.133333               0
# ..                                  ...     ...        ...             ...
# 100          SURGICAL GASTRO ENTEROLOGY    Male  45.821070              15
# 101                   SURGICAL ONCOLOGY     Boy  10.421053               0
# 102                   SURGICAL ONCOLOGY  Female  50.684096              45
# 103                   SURGICAL ONCOLOGY    Girl   8.500000               0
# 104                   SURGICAL ONCOLOGY    Male  52.049853              50
#
#     DISCHARGE_DATE  VILLAGE
# 0       2017-12-09      799
# 1       2017-12-10     3911
# 2       2017-12-09      775
# 3       2017-12-10     5689
# 4       2017-10-24       15
# ..             ...      ...
# 100     2017-12-09      507
# 101     2017-11-15       17
# 102     2017-12-10     3052
# 103     2017-12-09       30
# 104     2017-12-10     1954
#
# [105 rows x 6 columns]

# %% [markdown]
# **Que intervenciones están vinculadas a SURGERY**

# %%
data.loc[data['CATEGORY_NAME'].str.contains('SURGERY')].groupby(['SEX']).mean()
# Out:
#               AGE   PREAUTH_AMT  CLAIM_AMOUNT         DIFF  DISCOUNT_COST
# SEX
# Boy      7.295001  54169.084949  50582.253756 -3586.831194       0.000000
# Female  46.396697  45233.060813  42182.035286 -3051.025527   20297.887297
# Girl     6.639416  55306.632482  52280.439781 -3026.192701       0.000000
# Male    47.727112  51022.281661  47558.443743 -3463.837918   25156.232899

# %% [markdown]
# **Edad minima y maxima por CATEGORY**

# %%
data.groupby(['CATEGORY_NAME']).agg(
    **{
        'Edad Promedio': ('AGE', 'mean'),
        'Edad Maxima': ('AGE', 'max'),
    }).reset_index()
# Out:
#                           CATEGORY_NAME  Edad Promedio  Edad Maxima
# 0    CARDIAC AND CARDIOTHORACIC SURGERY      51.764553           90
# 1                            CARDIOLOGY      54.652048           93
# 2              COCHLEAR IMPLANT SURGERY       1.581081           11
# 3                         CRITICAL CARE      51.014649           90
# 4                           DERMATOLOGY      46.573171           86
# 5                         ENDOCRINOLOGY      45.066667           96
# 6                          ENT  SURGERY      32.521940           86
# 7                      GASTROENTEROLOGY      41.662383           88
# 8                      GENERAL MEDICINE      35.330161           89
# 9                       GENERAL SURGERY      44.979473           92
# 10             GENITO URINARY SURGERIES      43.718295           91
# 11  GYNAECOLOGY AND OBSTETRICS  SURGERY      41.442323           81
# 12                  INFECTIOUS DISEASES      35.800000           46
# 13                     MEDICAL ONCOLOGY      48.545298           91
# 14                           NEPHROLOGY      48.011808           96
# 15                            NEUROLOGY      56.160018           96
# 16                         NEUROSURGERY      43.187689           93
# 17               OPHTHALMOLOGY  SURGERY      49.846924           95
# 18   ORTHOPEDIC  SURGERY AND PROCEDURES      36.967490          107
# 19                  PEDIATRIC SURGERIES       3.504840           61
# 20                           PEDIATRICS       1.413553           39
# 21                      PLASTIC SURGERY      27.419738           86
# 22                          POLY TRAUMA      46.256150          107
# 23                           PROSTHESES      48.500000           50
# 24                          PULMONOLOGY      51.937149           94
# 25                   RADIATION ONCOLOGY      51.835382           91
# 26                         RHEUMATOLOGY      29.392857           61
# 27           SURGICAL GASTRO ENTEROLOGY      44.645103           83
# 28                    SURGICAL ONCOLOGY      50.940826           91

# %% [markdown]
# **Operación mas común por grupo de edad**
#
# Para encontrar la operación mas común por grupo de edad, vamos a redondear las edades al valor múltiplo de 10 mas cercano.
#
# Hacemos una copia del dataframe para no _ensuciar_ el dataframe original.

# %%
dataround = data.copy()

# %% [markdown]
# Utilizamos la función _round_ de Pandas para redonder el valor de la edad. *1* indica que redondeamos hasta1 dígito a la izquierda del valor decimal.

# %%
# round a la edad en 0 o 1
dataround['AGE'] = dataround['AGE'].round(1)

# %%
dataround['AGE']
# Out:
# 0         56
# 1         37
# 2         50
# 3         45
# 4         54
#           ..
# 479683    22
# 479684    60
# 479685    38
# 479686    59
# 479687    63
# Name: AGE, Length: 479688, dtype: int64

# %% [markdown]
# Visualizamos los grupos de edad utilizando la función _Seaborn countplot_

# %%
# frequency plot
sns.countplot(x=dataround['AGE']);

# %%
# Cuadro mostrando la 'CATEGORY_NAME' con mas intervenciones, por edad.
res = dataround.groupby(['AGE', 'CATEGORY_NAME'], as_index=False)['SEX'].count()\
        .sort_values('SEX', ascending=False)\
        .drop_duplicates('AGE')\
        .sort_values('AGE')
        
res
# Out:
#       AGE                       CATEGORY_NAME    SEX
# 10      0                          PEDIATRICS  15096
# 26      1                          PEDIATRICS   1707
# 46      2                          PEDIATRICS    918
# 66      3                          PEDIATRICS    670
# 85      4                          PEDIATRICS    691
# ...   ...                                 ...    ...
# 2061   97                         POLY TRAUMA      4
# 2062   99                         POLY TRAUMA      1
# 2063  100                         POLY TRAUMA      1
# 2064  101                         POLY TRAUMA      1
# 2065  107  ORTHOPEDIC  SURGERY AND PROCEDURES      1
#
# [102 rows x 3 columns]

# %% [markdown]
# #### Unir dataframes
#
# Vamos a descargar la tabla de distritos del estado de Andhra Pradesh (https://en.wikipedia.org/wiki/List_of_districts_of_Andhra_Pradesh) con algunas variables adicionales, para pegarle datos del dataframe original a nivel distrito.

# %%
wiki_url = 'https://en.wikipedia.org/wiki/List_of_districts_of_Andhra_Pradesh'
df_wiki = pd.read_html(wiki_url)[2]
df_wiki
# Out:
#    Code[10]                Official name        Headquarters  \
# 0        SR                   Srikakulam          Srikakulam
# 1        PM         Parvathipuram Manyam       Parvathipuram
# 2        VZ                 Vizianagaram        Vizianagaram
# 3        VS                Visakhapatnam       Visakhapatnam
# 4        AS        Alluri Sitharama Raju              Paderu
# 5        AK                   Anakapalli          Anakapalli
# 6        KK                     Kakinada            Kakinada
# 7        EG                East Godavari  Rajahmahendravaram
# 8        KN  Dr. B.R. Ambedkar Konaseema         Amalapuramu
# 9        EL                        Eluru               Eluru
# 10       WG                West Godavari          Bhimavaram
# 11       NT                          NTR          Vijayawada
# 12       KR                      Krishna       Machilipatnam
# 13       PL                      Palnadu       Narasaraopeta
# 14       GU                       Guntur              Guntur
# 15       BP                      Bapatla             Bapatla
# 16       PR                     Prakasam              Ongole
# 17       NE  Sri Potti Sriramulu Nellore             Nellore
# 18       KU                      Kurnool             Kurnool
# 19       NN                      Nandyal            Nandyala
# 20       AN                    Anantapur           Anantapur
# 21       SS               Sri Sathya Sai         Puttaparthi
# 22       CU                          YSR              Kadapa
# 23       AM                    Annamayya           Rayachoti
# 24       TR                     Tirupati            Tirupati
# 25       CH                     Chittoor            Chittoor
#
#     Revenuedivisions  Mandals  Population  Area(in sq.km)  Density(per sq.km)  \
# 0                  3       30     2191471            4591              477.34
# 1                  2       15      925340            3659              252.89
# 2                  2       27     1930811            4122              468.42
# 3                  2       11     1959544            1048             1869.79
# 4                  2       22      953960           12251               77.87
# 5                  2       24     1726998            4292              402.38
# 6                  2       21     2092374            3019              693.07
# 7                  2       20     1832332            2561              715.48
# 8                  3       22     1719093            2083              825.30
# 9                  3       28     2071700            6679              310.18
# 10                 2       19     1779935            2178              817.23
# 11                 3       20     2218591            3316              669.06
# 12                 3       25     1735079            3775              459.62
# 13                 3       28     2041723            7298              279.76
# 14                 2       18     2091075            2443              855.95
# 15                 2       25     1586918            3829              414.45
# 16                 3       38     2288026           14322              159.76
# 17                 4       38     2469712           10441              236.54
# 18                 3       26     2271686            7980              284.67
# 19                 3       29     1781777            9682              184.03
# 20                 3       31     2241105           10205              219.61
# 21                 4       32     1840043            8925              206.17
# 22                 3       36     2060654           11228              183.53
# 23                 3       30     1697308            7954              213.39
# 24                 4       34     2196984            8231              266.92
# 25                 4       31     1872951            6855              273.22
#
#     Map
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# 10  NaN
# 11  NaN
# 12  NaN
# 13  NaN
# 14  NaN
# 15  NaN
# 16  NaN
# 17  NaN
# 18  NaN
# 19  NaN
# 20  NaN
# 21  NaN
# 22  NaN
# 23  NaN
# 24  NaN
# 25  NaN

# %% [markdown]
# Vamos a agregar ua columna en la tabla extraída de wikipedia con la cantidad de personas de cada Distrito, que aparece en la base del programa de salud.
#
# Para poder hacerlo, vamos a crear un nuevo dataframe que es el resultado de agrupar en la base del programa la cantidad de registros por distrito.

# %%
df_new = data.groupby(['HOSP_DISTRICT'])['AGE'].count().reset_index()
df_new
# Out:
#      HOSP_DISTRICT    AGE
# 0        Anantapur  18444
# 1         Chittoor  49172
# 2    East Godavari  58065
# 3           Guntur  60988
# 4        Hyderabad  27915
# 5       Karimnagar     11
# 6          Khammam    346
# 7          Krishna  45174
# 8          Kurnool  33024
# 9     Mahabubnagar      6
# 10         Nellore  42405
# 11       Nizamabad      3
# 12        Prakasam  16756
# 13     Ranga Reddy   1244
# 14      Srikakulam  16137
# 15  Vishakhapatnam  59334
# 16    Vizianagaram  13563
# 17        Warangal      3
# 18   West Godavari  23769
# 19      YSR Kadapa  13329

# %% [markdown]
# Vamos a cambiar el nombre de la columna AGE:

# %%
df_new.rename(columns = {'AGE': 'Cantidad de Personas en el programa'}, 
                inplace = True)

# %%
df_new['HOSP_DISTRICT'].unique()
# Out:
# array(['Anantapur', 'Chittoor', 'East Godavari', 'Guntur', 'Hyderabad',
#        'Karimnagar', 'Khammam', 'Krishna', 'Kurnool', 'Mahabubnagar',
#        'Nellore', 'Nizamabad', 'Prakasam', 'Ranga Reddy', 'Srikakulam',
#        'Vishakhapatnam', 'Vizianagaram', 'Warangal', 'West Godavari',
#        'YSR Kadapa'], dtype=object)

# %%
df_new
# Out:
#      HOSP_DISTRICT  Cantidad de Personas en el programa
# 0        Anantapur                                18444
# 1         Chittoor                                49172
# 2    East Godavari                                58065
# 3           Guntur                                60988
# 4        Hyderabad                                27915
# 5       Karimnagar                                   11
# 6          Khammam                                  346
# 7          Krishna                                45174
# 8          Kurnool                                33024
# 9     Mahabubnagar                                    6
# 10         Nellore                                42405
# 11       Nizamabad                                    3
# 12        Prakasam                                16756
# 13     Ranga Reddy                                 1244
# 14      Srikakulam                                16137
# 15  Vishakhapatnam                                59334
# 16    Vizianagaram                                13563
# 17        Warangal                                    3
# 18   West Godavari                                23769
# 19      YSR Kadapa                                13329

# %%
df_merged = pd.merge(df_wiki,
                    df_new,
                    left_on = 'Official name',
                    right_on = 'HOSP_DISTRICT',
                    how = 'left')

# %%
df_merged.reset_index()
# Out:
#     index Code[10]                Official name        Headquarters  \
# 0       0       SR                   Srikakulam          Srikakulam
# 1       1       PM         Parvathipuram Manyam       Parvathipuram
# 2       2       VZ                 Vizianagaram        Vizianagaram
# 3       3       VS                Visakhapatnam       Visakhapatnam
# 4       4       AS        Alluri Sitharama Raju              Paderu
# 5       5       AK                   Anakapalli          Anakapalli
# 6       6       KK                     Kakinada            Kakinada
# 7       7       EG                East Godavari  Rajahmahendravaram
# 8       8       KN  Dr. B.R. Ambedkar Konaseema         Amalapuramu
# 9       9       EL                        Eluru               Eluru
# 10     10       WG                West Godavari          Bhimavaram
# 11     11       NT                          NTR          Vijayawada
# 12     12       KR                      Krishna       Machilipatnam
# 13     13       PL                      Palnadu       Narasaraopeta
# 14     14       GU                       Guntur              Guntur
# 15     15       BP                      Bapatla             Bapatla
# 16     16       PR                     Prakasam              Ongole
# 17     17       NE  Sri Potti Sriramulu Nellore             Nellore
# 18     18       KU                      Kurnool             Kurnool
# 19     19       NN                      Nandyal            Nandyala
# 20     20       AN                    Anantapur           Anantapur
# 21     21       SS               Sri Sathya Sai         Puttaparthi
# 22     22       CU                          YSR              Kadapa
# 23     23       AM                    Annamayya           Rayachoti
# 24     24       TR                     Tirupati            Tirupati
# 25     25       CH                     Chittoor            Chittoor
#
#     Revenuedivisions  Mandals  Population  Area(in sq.km)  Density(per sq.km)  \
# 0                  3       30     2191471            4591              477.34
# 1                  2       15      925340            3659              252.89
# 2                  2       27     1930811            4122              468.42
# 3                  2       11     1959544            1048             1869.79
# 4                  2       22      953960           12251               77.87
# 5                  2       24     1726998            4292              402.38
# 6                  2       21     2092374            3019              693.07
# 7                  2       20     1832332            2561              715.48
# 8                  3       22     1719093            2083              825.30
# 9                  3       28     2071700            6679              310.18
# 10                 2       19     1779935            2178              817.23
# 11                 3       20     2218591            3316              669.06
# 12                 3       25     1735079            3775              459.62
# 13                 3       28     2041723            7298              279.76
# 14                 2       18     2091075            2443              855.95
# 15                 2       25     1586918            3829              414.45
# 16                 3       38     2288026           14322              159.76
# 17                 4       38     2469712           10441              236.54
# 18                 3       26     2271686            7980              284.67
# 19                 3       29     1781777            9682              184.03
# 20                 3       31     2241105           10205              219.61
# 21                 4       32     1840043            8925              206.17
# 22                 3       36     2060654           11228              183.53
# 23                 3       30     1697308            7954              213.39
# 24                 4       34     2196984            8231              266.92
# 25                 4       31     1872951            6855              273.22
#
#     Map  HOSP_DISTRICT  Cantidad de Personas en el programa
# 0   NaN     Srikakulam                              16137.0
# 1   NaN            NaN                                  NaN
# 2   NaN   Vizianagaram                              13563.0
# 3   NaN            NaN                                  NaN
# 4   NaN            NaN                                  NaN
# 5   NaN            NaN                                  NaN
# 6   NaN            NaN                                  NaN
# 7   NaN  East Godavari                              58065.0
# 8   NaN            NaN                                  NaN
# 9   NaN            NaN                                  NaN
# 10  NaN  West Godavari                              23769.0
# 11  NaN            NaN                                  NaN
# 12  NaN        Krishna                              45174.0
# 13  NaN            NaN                                  NaN
# 14  NaN         Guntur                              60988.0
# 15  NaN            NaN                                  NaN
# 16  NaN       Prakasam                              16756.0
# 17  NaN            NaN                                  NaN
# 18  NaN        Kurnool                              33024.0
# 19  NaN            NaN                                  NaN
# 20  NaN      Anantapur                              18444.0
# 21  NaN            NaN                                  NaN
# 22  NaN            NaN                                  NaN
# 23  NaN            NaN                                  NaN
# 24  NaN            NaN                                  NaN
# 25  NaN       Chittoor                              49172.0

# %% [markdown]
# Borramos la columna HOSP_DISTRICT

# %%
df_merged = df_merged[['Code[10]', 'Official name', 'Headquarters', 'Revenuedivisions',
       'Mandals', 'Population', 'Area(in sq.km)', 'Density(per sq.km)', 'Cantidad de Personas en el programa']]

# %%
df_merged
# Out:
#    Code[10]                Official name        Headquarters  \
# 0        SR                   Srikakulam          Srikakulam
# 1        PM         Parvathipuram Manyam       Parvathipuram
# 2        VZ                 Vizianagaram        Vizianagaram
# 3        VS                Visakhapatnam       Visakhapatnam
# 4        AS        Alluri Sitharama Raju              Paderu
# 5        AK                   Anakapalli          Anakapalli
# 6        KK                     Kakinada            Kakinada
# 7        EG                East Godavari  Rajahmahendravaram
# 8        KN  Dr. B.R. Ambedkar Konaseema         Amalapuramu
# 9        EL                        Eluru               Eluru
# 10       WG                West Godavari          Bhimavaram
# 11       NT                          NTR          Vijayawada
# 12       KR                      Krishna       Machilipatnam
# 13       PL                      Palnadu       Narasaraopeta
# 14       GU                       Guntur              Guntur
# 15       BP                      Bapatla             Bapatla
# 16       PR                     Prakasam              Ongole
# 17       NE  Sri Potti Sriramulu Nellore             Nellore
# 18       KU                      Kurnool             Kurnool
# 19       NN                      Nandyal            Nandyala
# 20       AN                    Anantapur           Anantapur
# 21       SS               Sri Sathya Sai         Puttaparthi
# 22       CU                          YSR              Kadapa
# 23       AM                    Annamayya           Rayachoti
# 24       TR                     Tirupati            Tirupati
# 25       CH                     Chittoor            Chittoor
#
#     Revenuedivisions  Mandals  Population  Area(in sq.km)  Density(per sq.km)  \
# 0                  3       30     2191471            4591              477.34
# 1                  2       15      925340            3659              252.89
# 2                  2       27     1930811            4122              468.42
# 3                  2       11     1959544            1048             1869.79
# 4                  2       22      953960           12251               77.87
# 5                  2       24     1726998            4292              402.38
# 6                  2       21     2092374            3019              693.07
# 7                  2       20     1832332            2561              715.48
# 8                  3       22     1719093            2083              825.30
# 9                  3       28     2071700            6679              310.18
# 10                 2       19     1779935            2178              817.23
# 11                 3       20     2218591            3316              669.06
# 12                 3       25     1735079            3775              459.62
# 13                 3       28     2041723            7298              279.76
# 14                 2       18     2091075            2443              855.95
# 15                 2       25     1586918            3829              414.45
# 16                 3       38     2288026           14322              159.76
# 17                 4       38     2469712           10441              236.54
# 18                 3       26     2271686            7980              284.67
# 19                 3       29     1781777            9682              184.03
# 20                 3       31     2241105           10205              219.61
# 21                 4       32     1840043            8925              206.17
# 22                 3       36     2060654           11228              183.53
# 23                 3       30     1697308            7954              213.39
# 24                 4       34     2196984            8231              266.92
# 25                 4       31     1872951            6855              273.22
#
#     Cantidad de Personas en el programa
# 0                               16137.0
# 1                                   NaN
# 2                               13563.0
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                               58065.0
# 8                                   NaN
# 9                                   NaN
# 10                              23769.0
# 11                                  NaN
# 12                              45174.0
# 13                                  NaN
# 14                              60988.0
# 15                                  NaN
# 16                              16756.0
# 17                                  NaN
# 18                              33024.0
# 19                                  NaN
# 20                              18444.0
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                              49172.0

# %%
df_merged.to_csv('data/ntrarogyasev_merged.csv', index = False)

# %% [markdown]
# ### Anomalías
# Fuente: https://towardsdatascience.com/5-ways-to-detect-outliers-that-every-data-scientist-should-know-python-code-70a54335a623

# %%
# Leemos el dataset
# data = pd.read_csv('data/ntrarogyaseva_fixed.csv')

# %%
plt.figure(figsize=(20, 6))
sns.lineplot(data=data, x="AGE", y="CLAIM_AMOUNT", ci=95, hue="Mortality Y / N")
# sns.scatterplot(x='AGE', 
#              y='CLAIM_AMOUNT', 
#              data=data, 
#              color='g')
# Out:
# <AxesSubplot:xlabel='AGE', ylabel='CLAIM_AMOUNT'>

# %%
# Reducimos el DF para trabajar con mayor velocidad
data_graph = data.loc[data['SURGERY_DATE']>'29/12/2016 00:00:00']

#data_graph = data_graph.copy()
data_graph.shape
# Out:
# (330905, 26)

# %%
plt.figure(figsize=(20, 6))
ax = sns.lineplot(data=data_graph, x="SURGERY_DATE", y="CLAIM_AMOUNT")
plt.xticks(rotation=45); # el ; oculta el texto previo al gráfico. El mismo resultado se logra con plt.show()

# %%
# Para tomar la media movil, primero es necesario ordenar los datos por fecha.
data_graph.sort_values(by='SURGERY_DATE', ascending=False)

# Tomamos la media movil de 5 observaciones hacia atrás, y le sumamos/restamos 3 desvíos de esa media movil.
data_graph['CLAIM_AMOUNT_min'] = data_graph['CLAIM_AMOUNT'].rolling(5).mean() - 3*data_graph['CLAIM_AMOUNT'].rolling(5).std()
data_graph['CLAIM_AMOUNT_max'] = data_graph['CLAIM_AMOUNT'].rolling(5).mean() + 3*data_graph['CLAIM_AMOUNT'].rolling(5).std()
data_graph['CLAIM_AMOUNT_RM'] = data_graph['CLAIM_AMOUNT'].rolling(5).mean()

#data_graph['CLAIM_AMOUNT_min'] = data_graph['CLAIM_AMOUNT'] - 3*data_graph['CLAIM_AMOUNT']
#data_graph['CLAIM_AMOUNT_max'] = data_graph['CLAIM_AMOUNT'] + 3*data_graph['CLAIM_AMOUNT']
# data_graph['CLAIM_AMOUNT_RM'] = data_graph['CLAIM_AMOUNT'].rolling(5).mean()
# Out:
# /tmp/ipykernel_201674/4058705081.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_graph['CLAIM_AMOUNT_min'] = data_graph['CLAIM_AMOUNT'].rolling(5).mean() - 3*data_graph['CLAIM_AMOUNT'].rolling(5).std()
# /tmp/ipykernel_201674/4058705081.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_graph['CLAIM_AMOUNT_max'] = data_graph['CLAIM_AMOUNT'].rolling(5).mean() + 3*data_graph['CLAIM_AMOUNT'].rolling(5).std()
# /tmp/ipykernel_201674/4058705081.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_graph['CLAIM_AMOUNT_RM'] = data_graph['CLAIM_AMOUNT'].rolling(5).mean()

# %%
fig, ax = plt.subplots(figsize=(20, 6))

sns.lineplot(x='SURGERY_DATE',
             y='CLAIM_AMOUNT_max',
             data=data_graph,
             ci=False)

sns.lineplot(x='SURGERY_DATE',
             y='CLAIM_AMOUNT_min',
             data=data_graph,
             color='y',
             ci=False)

sns.lineplot(x='SURGERY_DATE', 
             y='CLAIM_AMOUNT', 
             data=data_graph, 
             color='g')

sns.scatterplot(x='SURGERY_DATE', 
             y='CLAIM_AMOUNT', 
             data=data_graph, 
             color='g')

# ax.axes.set_title("Date and Claim Amount",fontsize=20)
# ax.set_xlabel("Date",fontsize=15)
# ax.set_ylabel("Claim Amount",fontsize=15)
# ax.tick_params(labelsize=5)
# plt.xticks(rotation=45)

plt.show()

# %%
# Agrupamos los datos por fecha, con el promedio del CLAIM_AMOUNT
graph = data_graph.groupby(['SURGERY_DATE']).agg({'CLAIM_AMOUNT': 'mean'}).reset_index()

# Calculamos la media movil para el CLAIM_AMOUNT y -+ 3 desvíos
graph.sort_values(by='SURGERY_DATE', ascending=False)
graph['CLAIM_AMOUNT_min'] = graph['CLAIM_AMOUNT'].rolling(5).mean() - 3*graph['CLAIM_AMOUNT'].rolling(5).std()
graph['CLAIM_AMOUNT_max'] = graph['CLAIM_AMOUNT'].rolling(5).mean() + 3*graph['CLAIM_AMOUNT'].rolling(5).std()
graph['CLAIM_AMOUNT_RM'] = graph['CLAIM_AMOUNT'].rolling(5).mean()

fig, ax = plt.subplots(figsize=(20, 6))

sns.lineplot(x='SURGERY_DATE',
             y='CLAIM_AMOUNT_max',
             data=graph,
             ci=False)

sns.lineplot(x='SURGERY_DATE',
             y='CLAIM_AMOUNT_min',
             data=graph,
             color='y',
             ci=False)

sns.lineplot(x='SURGERY_DATE', 
             y='CLAIM_AMOUNT_RM', 
             data=graph, 
             color='g')

sns.scatterplot(x='SURGERY_DATE', 
             y='CLAIM_AMOUNT', 
             data=data_graph, 
             color='g');

# %% [markdown]
# #### Eliminar outliers

# %% [markdown]
# - Computamos el Z-score para la columna seleccionada, relativo a la media y al STD de esa columna
# - Tomamos el valor absoluto del Z-score.
#
# Si queremos calcular para todas las variables
# - df[(np.abs(stats.zscore(df)) < 3).all(axis=1)]
#
# _all(axis=1)_  garantiza que para cada fila, todas las columnas satisfacen la restricciónensures that for each row, all column satisfy the constraint.

# %%
from scipy import stats
import numpy as np
# graph_graph = data_graph.groupby(['SURGERY_DATE']).agg({'CLAIM_AMOUNT': 'mean'}).reset_index()

data_graph = data_graph[(np.abs(stats.zscore(data_graph['CLAIM_AMOUNT'])) < 3)]

# %%
# fig, ax = plt.subplots(figsize=(20, 6))

# sns.boxplot(x=data_graph['DISTRICT_NAME'], y=data_graph['CLAIM_AMOUNT']);

# %%
# Graficamos las series sin los valores que exceden el z-score
fig, ax = plt.subplots(figsize=(20, 6))

sns.lineplot(x='SURGERY_DATE',
             y='CLAIM_AMOUNT_max',
             data=data_graph,
             ci=False)

sns.lineplot(x='SURGERY_DATE',
             y='CLAIM_AMOUNT_min',
             data=data_graph,
             color='y',
             ci=False)

sns.lineplot(x='SURGERY_DATE', 
             y='CLAIM_AMOUNT_RM', 
             data=data_graph, 
             color='g',
             ci=False)

sns.scatterplot(x='SURGERY_DATE', 
             y='CLAIM_AMOUNT', 
             data=data_graph, 
             color='g');

# %% [markdown]
# ### MAPA

# %% [markdown]
# Los mapas _shp_ necesarios para correr esta sección se pueden descargar siguiendo [este enlace](http://projects.datameet.org/maps/districts/) o directamente desde [acá](https://github.com/datameet/maps/archive/master.zip). Sólo vamos a utilizar los archivos de la carpeta ``/maps-master/Districts/Census_2011``

# %%
import geopandas
import pandas as pd

# %%
df_merged = pd.read_csv('https://raw.githubusercontent.com/matog/Flacso_ciencia_de_datos_python_2022/main/Clase5/data/ntrarogyasev_merged.csv')

# %%
df_merged
# Out:
#    Code[10]                Official name        Headquarters  \
# 0        SR                   Srikakulam          Srikakulam
# 1        PM         Parvathipuram Manyam       Parvathipuram
# 2        VZ                 Vizianagaram        Vizianagaram
# 3        VS                Visakhapatnam       Visakhapatnam
# 4        AS        Alluri Sitharama Raju              Paderu
# 5        AK                   Anakapalli          Anakapalli
# 6        KK                     Kakinada            Kakinada
# 7        EG                East Godavari  Rajahmahendravaram
# 8        KN  Dr. B.R. Ambedkar Konaseema         Amalapuramu
# 9        EL                        Eluru               Eluru
# 10       WG                West Godavari          Bhimavaram
# 11       NT                          NTR          Vijayawada
# 12       KR                      Krishna       Machilipatnam
# 13       PL                      Palnadu       Narasaraopeta
# 14       GU                       Guntur              Guntur
# 15       BP                      Bapatla             Bapatla
# 16       PR                     Prakasam              Ongole
# 17       NE  Sri Potti Sriramulu Nellore             Nellore
# 18       KU                      Kurnool             Kurnool
# 19       NN                      Nandyal            Nandyala
# 20       AN                    Anantapur           Anantapur
# 21       SS               Sri Sathya Sai         Puttaparthi
# 22       CU                          YSR              Kadapa
# 23       AM                    Annamayya           Rayachoti
# 24       TR                     Tirupati            Tirupati
# 25       CH                     Chittoor            Chittoor
#
#     Revenuedivisions  Mandals  Population  Area(in sq.km)  Density(per sq.km)  \
# 0                  3       30     2191471            4591              477.34
# 1                  2       15      925340            3659              252.89
# 2                  2       27     1930811            4122              468.42
# 3                  2       11     1959544            1048             1869.79
# 4                  2       22      953960           12251               77.87
# 5                  2       24     1726998            4292              402.38
# 6                  2       21     2092374            3019              693.07
# 7                  2       20     1832332            2561              715.48
# 8                  3       22     1719093            2083              825.30
# 9                  3       28     2071700            6679              310.18
# 10                 2       19     1779935            2178              817.23
# 11                 3       20     2218591            3316              669.06
# 12                 3       25     1735079            3775              459.62
# 13                 3       28     2041723            7298              279.76
# 14                 2       18     2091075            2443              855.95
# 15                 2       25     1586918            3829              414.45
# 16                 3       38     2288026           14322              159.76
# 17                 4       38     2469712           10441              236.54
# 18                 3       26     2271686            7980              284.67
# 19                 3       29     1781777            9682              184.03
# 20                 3       31     2241105           10205              219.61
# 21                 4       32     1840043            8925              206.17
# 22                 3       36     2060654           11228              183.53
# 23                 3       30     1697308            7954              213.39
# 24                 4       34     2196984            8231              266.92
# 25                 4       31     1872951            6855              273.22
#
#     Cantidad de Personas en el programa
# 0                               16137.0
# 1                                   NaN
# 2                               13563.0
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                               58065.0
# 8                                   NaN
# 9                                   NaN
# 10                              23769.0
# 11                                  NaN
# 12                              45174.0
# 13                                  NaN
# 14                              60988.0
# 15                                  NaN
# 16                              16756.0
# 17                                  NaN
# 18                              33024.0
# 19                                  NaN
# 20                              18444.0
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                              49172.0

# %%
dfg = geopandas.read_file('https://github.com/matog/Flacso_ciencia_de_datos_python_2022/raw/main/Clase5/data/India.geojson')

# %%
type(dfg)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
dfg.head()
# Out:
#      DISTRICT           ST_NM  ST_CEN_CD  DT_CEN_CD  censuscode  \
# 0    Adilabad  Andhra Pradesh         28          1         532
# 1        Agra   Uttar Pradesh          9         15         146
# 2   Ahmadabad         Gujarat         24          7         474
# 3  Ahmadnagar     Maharashtra         27         26         522
# 4      Aizawl         Mizoram         15          3         283
#
#                                             geometry
# 0  POLYGON ((78.84972 19.76010, 78.85102 19.75945...
# 1  POLYGON ((78.19803 27.40280, 78.19804 27.40278...
# 2  MULTIPOLYGON (((72.03456 23.50527, 72.03337 23...
# 3  POLYGON ((74.67333 19.94670, 74.67393 19.93509...
# 4  POLYGON ((92.98749 24.40453, 92.99107 24.40236...

# %%
dfg.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.merge(dfg,
              df_merged,
              left_on = 'DISTRICT',
              right_on ='Official name',
              how = 'left'
             )

# %%
df
# Out:
#                    DISTRICT                     ST_NM  ST_CEN_CD  DT_CEN_CD  \
# 0                  Adilabad            Andhra Pradesh         28          1
# 1                      Agra             Uttar Pradesh          9         15
# 2                 Ahmadabad                   Gujarat         24          7
# 3                Ahmadnagar               Maharashtra         27         26
# 4                    Aizawl                   Mizoram         15          3
# ..                      ...                       ...        ...        ...
# 636                    Tapi                   Gujarat         24         26
# 637                 Nicobar  Andaman & Nicobar Island         35          1
# 638           South Andaman  Andaman & Nicobar Island         35          3
# 639  North & Middle Andaman  Andaman & Nicobar Island         35          2
# 640             Lakshadweep               Lakshadweep         31          1
#
#      censuscode                                           geometry Code[10]  \
# 0           532  POLYGON ((78.84972 19.76010, 78.85102 19.75945...      NaN
# 1           146  POLYGON ((78.19803 27.40280, 78.19804 27.40278...      NaN
# 2           474  MULTIPOLYGON (((72.03456 23.50527, 72.03337 23...      NaN
# 3           522  POLYGON ((74.67333 19.94670, 74.67393 19.93509...      NaN
# 4           283  POLYGON ((92.98749 24.40453, 92.99107 24.40236...      NaN
# ..          ...                                                ...      ...
# 636         493  POLYGON ((74.08573 21.55513, 74.08672 21.55515...      NaN
# 637         638  MULTIPOLYGON (((93.84861 7.24051, 93.84870 7.2...      NaN
# 638         640  MULTIPOLYGON (((92.69758 12.23961, 92.69778 12...      NaN
# 639         639  MULTIPOLYGON (((92.89905 12.91512, 92.89905 12...      NaN
# 640         587  MULTIPOLYGON (((74.10131 11.20431, 74.09908 11...      NaN
#
#     Official name Headquarters  Revenuedivisions  Mandals  Population  \
# 0             NaN          NaN               NaN      NaN         NaN
# 1             NaN          NaN               NaN      NaN         NaN
# 2             NaN          NaN               NaN      NaN         NaN
# 3             NaN          NaN               NaN      NaN         NaN
# 4             NaN          NaN               NaN      NaN         NaN
# ..            ...          ...               ...      ...         ...
# 636           NaN          NaN               NaN      NaN         NaN
# 637           NaN          NaN               NaN      NaN         NaN
# 638           NaN          NaN               NaN      NaN         NaN
# 639           NaN          NaN               NaN      NaN         NaN
# 640           NaN          NaN               NaN      NaN         NaN
#
#      Area(in sq.km)  Density(per sq.km)  Cantidad de Personas en el programa
# 0               NaN                 NaN                                  NaN
# 1               NaN                 NaN                                  NaN
# 2               NaN                 NaN                                  NaN
# 3               NaN                 NaN                                  NaN
# 4               NaN                 NaN                                  NaN
# ..              ...                 ...                                  ...
# 636             NaN                 NaN                                  NaN
# 637             NaN                 NaN                                  NaN
# 638             NaN                 NaN                                  NaN
# 639             NaN                 NaN                                  NaN
# 640             NaN                 NaN                                  NaN
#
# [641 rows x 15 columns]

# %%
df = df.loc[df['Population']>0]

# %%
df
# Out:
#                         DISTRICT           ST_NM  ST_CEN_CD  DT_CEN_CD  \
# 19                     Anantapur  Andhra Pradesh         28         22
# 119                     Chittoor  Andhra Pradesh         28         23
# 168                East Godavari  Andhra Pradesh         28         14
# 210                       Guntur  Andhra Pradesh         28         17
# 322                      Krishna  Andhra Pradesh         28         16
# 327                      Kurnool  Andhra Pradesh         28         21
# 408  Sri Potti Sriramulu Nellore  Andhra Pradesh         28         19
# 445                     Prakasam  Andhra Pradesh         28         18
# 549                   Srikakulam  Andhra Pradesh         28         11
# 605                Visakhapatnam  Andhra Pradesh         28         13
# 606                 Vizianagaram  Andhra Pradesh         28         12
# 614                West Godavari  Andhra Pradesh         28         15
#
#      censuscode                                           geometry Code[10]  \
# 19          553  POLYGON ((78.14427 14.94530, 78.14382 14.94009...       AN
# 119         554  POLYGON ((80.01818 13.49927, 80.01815 13.49928...       CH
# 168         545  POLYGON ((82.01023 17.96357, 82.01368 17.95620...       EG
# 210         548  POLYGON ((80.81934 15.74265, 80.81973 15.74426...       GU
# 322         547  MULTIPOLYGON (((80.60374 17.12738, 80.61251 17...       KR
# 327         552  POLYGON ((78.92098 16.11569, 78.93327 16.06979...       KU
# 408         550  POLYGON ((80.04883 15.01838, 80.05100 15.00723...       NE
# 445         549  POLYGON ((80.43917 15.80629, 80.43345 15.80437...       PR
# 549         542  POLYGON ((84.76858 19.08002, 84.76625 19.07514...       SR
# 605         544  POLYGON ((83.07406 18.40189, 83.08967 18.41428...       VS
# 606         543  POLYGON ((83.63610 19.13934, 83.63751 19.13484...       VZ
# 614         546  POLYGON ((81.72023 16.32845, 81.71887 16.32727...       WG
#
#                    Official name        Headquarters  Revenuedivisions  \
# 19                     Anantapur           Anantapur               3.0
# 119                     Chittoor            Chittoor               4.0
# 168                East Godavari  Rajahmahendravaram               2.0
# 210                       Guntur              Guntur               2.0
# 322                      Krishna       Machilipatnam               3.0
# 327                      Kurnool             Kurnool               3.0
# 408  Sri Potti Sriramulu Nellore             Nellore               4.0
# 445                     Prakasam              Ongole               3.0
# 549                   Srikakulam          Srikakulam               3.0
# 605                Visakhapatnam       Visakhapatnam               2.0
# 606                 Vizianagaram        Vizianagaram               2.0
# 614                West Godavari          Bhimavaram               2.0
#
#      Mandals  Population  Area(in sq.km)  Density(per sq.km)  \
# 19      31.0   2241105.0         10205.0              219.61
# 119     31.0   1872951.0          6855.0              273.22
# 168     20.0   1832332.0          2561.0              715.48
# 210     18.0   2091075.0          2443.0              855.95
# 322     25.0   1735079.0          3775.0              459.62
# 327     26.0   2271686.0          7980.0              284.67
# 408     38.0   2469712.0         10441.0              236.54
# 445     38.0   2288026.0         14322.0              159.76
# 549     30.0   2191471.0          4591.0              477.34
# 605     11.0   1959544.0          1048.0             1869.79
# 606     27.0   1930811.0          4122.0              468.42
# 614     19.0   1779935.0          2178.0              817.23
#
#      Cantidad de Personas en el programa
# 19                               18444.0
# 119                              49172.0
# 168                              58065.0
# 210                              60988.0
# 322                              45174.0
# 327                              33024.0
# 408                                  NaN
# 445                              16756.0
# 549                              16137.0
# 605                                  NaN
# 606                              13563.0
# 614                              23769.0

# %%
fig, ax = plt.subplots(1, figsize=(20,12))
df.plot(column='Cantidad de Personas en el programa', cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off');

# %% [markdown]
# ## Exportar Notebook
# Primero, obtenemos el nombre del archivo

# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %% [markdown]
# Exportamos todo el notebook. Código y resultados

# %%
# !jupyter nbconvert --TagRemovePreprocessor.enabled=True --to html $nb_name
# Out:
# [NbConvertApp] WARNING | pattern '6-NTR' matched no files
# [NbConvertApp] WARNING | pattern 'Vaidya' matched no files
# [NbConvertApp] WARNING | pattern 'Seva.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# =======
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
#     Equivalent to: [--JupyterApp.answer_yes=True]
# --execute
#     Execute the notebook prior to export.
#     Equivalent to: [--ExecutePreprocessor.enabled=True]
# --allow-errors
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
#     Equivalent to: [--ExecutePreprocessor.allow_errors=True]
# --stdin
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
#     Equivalent to: [--NbConvertApp.from_stdin=True]
# --stdout
#     Write notebook output to stdout instead of files.
#     Equivalent to: [--NbConvertApp.writer_class=StdoutWriter]
# --inplace
#     Run nbconvert in place, overwriting the existing notebook (only
#             relevant when converting to notebook format)
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory=]
# --clear-output
#     Clear output of current file and save in place,
#             overwriting the existing notebook.
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory= --ClearOutputPreprocessor.enabled=True]
# --no-prompt
#     Exclude input and output prompts from converted document.
#     Equivalent to: [--TemplateExporter.exclude_input_prompt=True --TemplateExporter.exclude_output_prompt=True]
# --no-input
#     Exclude input cells and output prompts from converted document.
#             This mode is ideal for generating code-free reports.
#     Equivalent to: [--TemplateExporter.exclude_output_prompt=True --TemplateExporter.exclude_input=True --TemplateExporter.exclude_input_prompt=True]
# --allow-chromium-download
#     Whether to allow downloading chromium if no suitable version is found on the system.
#     Equivalent to: [--WebPDFExporter.allow_chromium_download=True]
# --disable-chromium-sandbox
#     Disable chromium security sandbox when converting to PDF..
#     Equivalent to: [--WebPDFExporter.disable_sandbox=True]
# --show-input
#     Shows code input. This flag is only useful for dejavu users.
#     Equivalent to: [--TemplateExporter.exclude_input=False]
# --embed-images
#     Embed the images as base64 dataurls in the output. This flag is only useful for the HTML/WebPDF/Slides exports.
#     Equivalent to: [--HTMLExporter.embed_images=True]
# --sanitize-html
#     Whether the HTML in Markdown cells and cell outputs should be sanitized..
#     Equivalent to: [--HTMLExporter.sanitize_html=True]
# --log-level=<Enum>
#     Set the log level by value or name.
#     Choices: any of [0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL']
#     Default: 30
#     Equivalent to: [--Application.log_level]
# --config=<Unicode>
#     Full path of a config file.
#     Default: ''
#     Equivalent to: [--JupyterApp.config_file]
# --to=<Unicode>
#     The export format to be used, either one of the built-in formats
#             ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'slides', 'webpdf']
#             or a dotted object name that represents the import path for an
#             ``Exporter`` class
#     Default: ''
#     Equivalent to: [--NbConvertApp.export_format]
# --template=<Unicode>
#     Name of the template to use
#     Default: ''
#     Equivalent to: [--TemplateExporter.template_name]
# --template-file=<Unicode>
#     Name of the template file to use
#     Default: None
#     Equivalent to: [--TemplateExporter.template_file]
# --theme=<Unicode>
#     Template specific theme(e.g. the name of a JupyterLab CSS theme distributed
#     as prebuilt extension for the lab template)
#     Default: 'light'
#     Equivalent to: [--HTMLExporter.theme]
# --sanitize_html=<Bool>
#     Whether the HTML in Markdown cells and cell outputs should be sanitized.This
#     should be set to True by nbviewer or similar tools.
#     Default: False
#     Equivalent to: [--HTMLExporter.sanitize_html]
# --writer=<DottedObjectName>
#     Writer class used to write the
#                                         results of the conversion
#     Default: 'FilesWriter'
#     Equivalent to: [--NbConvertApp.writer_class]
# --post=<DottedOrNone>
#     PostProcessor class used to write the
#                                         results of the conversion
#     Default: ''
#     Equivalent to: [--NbConvertApp.postprocessor_class]
# --output=<Unicode>
#     overwrite base name use for output files.
#                 can only be used when converting one notebook at a time.
#     Default: ''
#     Equivalent to: [--NbConvertApp.output_base]
# --output-dir=<Unicode>
#     Directory to write output(s) to. Defaults
#                                   to output to the directory of each notebook. To recover
#                                   previous default behaviour (outputting to the current
#                                   working directory) use . as the flag value.
#     Default: ''
#     Equivalent to: [--FilesWriter.build_directory]
# --reveal-prefix=<Unicode>
#     The URL prefix for reveal.js (version 3.x).
#             This defaults to the reveal CDN, but can be any url pointing to a copy
#             of reveal.js.
#             For speaker notes to work, this must be a relative path to a local
#             copy of reveal.js: e.g., "reveal.js".
#             If a relative path is given, it must be a subdirectory of the
#             current directory (from which the server is run).
#             See the usage documentation
#             (https://nbconvert.readthedocs.io/en/latest/usage.html#reveal-js-html-slideshow)
#             for more details.
#     Default: ''
#     Equivalent to: [--SlidesExporter.reveal_url_prefix]
# --nbformat=<Enum>
#     The nbformat version to write.
#             Use this to downgrade notebooks.
#     Choices: any of [1, 2, 3, 4]
#     Default: 4
#     Equivalent to: [--NotebookExporter.nbformat_version]
#
# Examples
# --------
#
#     The simplest way to use nbconvert is
#
#             > jupyter nbconvert mynotebook.ipynb --to html
#
#             Options include ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'slides', 'webpdf'].
#
#             > jupyter nbconvert --to latex mynotebook.ipynb
#
#             Both HTML and LaTeX support multiple output templates. LaTeX includes
#             'base', 'article' and 'report'.  HTML includes 'basic', 'lab' and
#             'classic'. You can specify the flavor of the format used.
#
#             > jupyter nbconvert --to html --template lab mynotebook.ipynb
#
#             You can also pipe the output to stdout, rather than a file
#
#             > jupyter nbconvert mynotebook.ipynb --stdout
#
#             PDF is generated via latex
#
#             > jupyter nbconvert mynotebook.ipynb --to pdf
#
#             You can get (and serve) a Reveal.js-powered slideshow
#
#             > jupyter nbconvert myslides.ipynb --to slides --post serve
#
#             Multiple notebooks can be given at the command line in a couple of
#             different ways:
#
#             > jupyter nbconvert notebook*.ipynb
#             > jupyter nbconvert notebook1.ipynb notebook2.ipynb
#
#             or you can specify the notebooks list in a config file, containing::
#
#                 c.NbConvertApp.notebooks = ["my_notebook.ipynb"]
#
#             > jupyter nbconvert --config mycfg.py
#
# To see all available configurables, use `--help-all`.

# %% [markdown]
# Exportamos solo los resultados

# %%
# !jupyter nbconvert --TagRemovePreprocessor.enabled=True --no-input --to html $nb_name

# %% [markdown]
# Exportamos solo resultados, y sólo celdas que no tengan _tag=no_

# %%
# !jupyter nbconvert --TagRemovePreprocessor.enabled=True --TagRemovePreprocessor.remove_cell_tags='{"no"}' --no-input --to html $nb_name

# %% [markdown]
# ## Geolocalización de hospitales

# %%
data
# Out:
#         AGE     SEX      CASTE_NAME CATEGORY_CODE  \
# 0        56  Female  backward class            M6
# 1        37    Male  backward class            M6
# 2        50    Male  backward class            M6
# 3        45    Male  backward class            M6
# 4        54    Male  backward class            M6
# ...     ...     ...             ...           ...
# 479683   22  Female  backward class            S4
# 479684   60    Male  backward class           S12
# 479685   38    Male  other category           S15
# 479686   59    Male  other category            S3
# 479687   63    Male  other category            S3
#
#                               CATEGORY_NAME SURGERY_CODE  \
# 0                                NEPHROLOGY         M6.5
# 1                                NEPHROLOGY         M6.5
# 2                                NEPHROLOGY         M6.5
# 3                                NEPHROLOGY         M6.5
# 4                                NEPHROLOGY         M6.5
# ...                                     ...          ...
# 479683  GYNAECOLOGY AND OBSTETRICS  SURGERY       S4.2.2
# 479684                     MEDICAL ONCOLOGY   S12.16.2.2
# 479685                          POLY TRAUMA      S15.1.1
# 479686               OPHTHALMOLOGY  SURGERY       S3.3.1
# 479687               OPHTHALMOLOGY  SURGERY       S3.3.1
#
#                                                   SURGERY        VILLAGE  \
# 0                        Maintenance Hemodialysis For Crf         Lolugu
# 1                        Maintenance Hemodialysis For Crf      Borivanka
# 2                        Maintenance Hemodialysis For Crf    Kapasakuddi
# 3                        Maintenance Hemodialysis For Crf    Telikipenta
# 4                        Maintenance Hemodialysis For Crf  Thandemvalasa
# ...                                                   ...            ...
# 479683                            Laparoscopic Cystectomy  Kalayakagollu
# 479684  Chemotherapy for Non Hodgkin Lymphoma with  R ...      Rajupalem
# 479685           Surgical Correction Of Longbone Fracture         Yeturu
# 479686                                         Vitrectomy    Ganapavaram
# 479687                                         Vitrectomy    Savarigudem
#
#              MANDAL_NAME  DISTRICT_NAME  ... HOSP_DISTRICT  SURGERY_DATE  \
# 0                Ponduru     Srikakulam  ...    Srikakulam    2013-06-08
# 1                 Kaviti     Srikakulam  ...    Srikakulam    2013-08-08
# 2                 Kaviti     Srikakulam  ...    Srikakulam    2013-08-15
# 3            Sarubujjili     Srikakulam  ...    Srikakulam    2013-08-24
# 4             Srikakulam     Srikakulam  ...    Srikakulam    2013-08-31
# ...                  ...            ...  ...           ...           ...
# 479683  Butchireddipalem        Nellore  ...       Nellore    2017-11-15
# 479684       Kothapatnam       Prakasam  ...        Guntur    2017-11-17
# 479685          Chejerla        Nellore  ...       Nellore    2017-11-16
# 479686       Ganapavaram  West Godavari  ...        Guntur    2017-11-16
# 479687        Gannavaram        Krishna  ...        Guntur    2017-11-16
#
#        DISCHARGE_DATE  Mortality Y / N MORTALITY_DATE SRC_REGISTRATION  \
# 0          2013-07-09               NO            NaT                D
# 1          2013-09-09               NO            NaT                D
# 2          2013-10-18               NO            NaT                D
# 3          2013-09-27               NO            NaT                D
# 4          2013-02-10               NO            NaT                D
# ...               ...              ...            ...              ...
# 479683     2017-11-19               NO            NaT                D
# 479684     2017-11-18               NO            NaT                D
# 479685     2017-11-18               NO            NaT                D
# 479686     2017-11-18               NO            NaT                D
# 479687     2017-11-18               NO            NaT                D
#
#                                         CATEGORY  DIFF DISCOUNT_COST  \
# 0                                M6 - NEPHROLOGY -1500       11250.0
# 1                                M6 - NEPHROLOGY -1500           0.0
# 2                                M6 - NEPHROLOGY -1000       11250.0
# 3                                M6 - NEPHROLOGY -1500           0.0
# 4                                M6 - NEPHROLOGY -1500       11250.0
# ...                                          ...   ...           ...
# 479683  S4 - GYNAECOLOGY AND OBSTETRICS  SURGERY     0           0.0
# 479684                    S12 - MEDICAL ONCOLOGY     0       39023.5
# 479685                         S15 - POLY TRAUMA     0           0.0
# 479686               S3 - OPHTHALMOLOGY  SURGERY     0       20718.0
# 479687               S3 - OPHTHALMOLOGY  SURGERY     0       19567.0
#
#                                                       add
# 0       Rims Govt. General Hospital, Srikakulam, SRIKA...
# 1       Rims Govt. General Hospital, Srikakulam, SRIKA...
# 2       Rims Govt. General Hospital, Srikakulam, SRIKA...
# 3       Rims Govt. General Hospital, Srikakulam, SRIKA...
# 4       Rims Govt. General Hospital, Srikakulam, SRIKA...
# ...                                                   ...
# 479683  Krishna Institute of Medical Sciences Bollinen...
# 479684  Manipal Health Enterprises PVT LTD, GUNTUR, Gu...
# 479685  Krishna Institute of Medical Sciences Bollinen...
# 479686  Sankar Eye Hospital, GUNTUR, Guntur, Andhra Pr...
# 479687  Sankar Eye Hospital, GUNTUR, Guntur, Andhra Pr...
#
# [479688 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['AGE', 'SEX', 'CASTE_NAME', 'CATEGORY_CODE', 'CATEGORY_NAME',
#        'SURGERY_CODE', 'SURGERY', 'VILLAGE', 'MANDAL_NAME', 'DISTRICT_NAME',
#        'PREAUTH_DATE', 'PREAUTH_AMT', 'CLAIM_DATE', 'CLAIM_AMOUNT',
#        'HOSP_NAME', 'HOSP_TYPE', 'HOSP_LOCATION', 'HOSP_DISTRICT',
#        'SURGERY_DATE', 'DISCHARGE_DATE', 'Mortality Y / N', 'MORTALITY_DATE',
#        'SRC_REGISTRATION', 'CATEGORY', 'DIFF', 'DISCOUNT_COST'],
#       dtype='object')

# %%
data['add'] = data['HOSP_NAME'] +', ' + data['HOSP_LOCATION'] + ', ' + data['HOSP_DISTRICT'] + ', Andhra Pradesh, India'

# %%
hosp = data['add'].unique()

# %%
hosp.shape
# Out:
# (468,)

# %%
from geopandas.tools import geocode

# %%
geo = geocode(hosp, provider='nominatim', user_agent='test_flacso', timeout=4)

# %%
geo
# Out:
#                       geometry  \
# 3    POINT (80.45380 16.29855)
# 14   POINT (80.64680 16.24299)
# 16   POINT (80.45424 16.29602)
# 18   POINT (82.22731 16.95571)
# 22   POINT (78.50110 13.55704)
# ..                         ...
# 442  POINT (78.82429 14.46226)
# 456  POINT (80.46347 16.30720)
# 460  POINT (81.09550 16.71531)
# 463  POINT (78.04122 15.83567)
# 464  POINT (80.67153 16.48985)
#
#                                                address  \
# 3    Karumuri Super Speciality Hospital Pvt Ltd, Do...
# 14   Aswini Children's & Dental Hospital, Prakasam ...
# 16   Sailaja Multispeciality Hospital, Guntur - Han...
# 18   Government General Hospital, SH216, Kakinada, ...
# 22   Area Hospital,Madanapalli, Near Head Post Offi...
# ..                                                 ...
# 442  Komma Super Speciality Hospital, Arts College ...
# 456  Vedanta Hospitals, contaioner terminal, Guntur...
# 460  Prabha Hospital, RR Peta Road, Narasimha Rao P...
# 463  Health Care Noble Multi-Speciality Hospital, M...
# 464  Liberty Hospitals, Bandar Road, Vijayawada, Vi...
#
#                                               hospital
# 3    Karumuri Hospital, GUNTUR, Guntur, Andhra Prad...
# 14   Aswini Hospital, GUNTUR, Guntur, Andhra Prades...
# 16   SAILAJA MULTISPECIALITY HOSPITAL, GUNTUR, Gunt...
# 18   Government General Hospital,Kakinada, KAKINADA...
# 22   Area Hospital - Madanapalli, Chittoor, Chittoo...
# ..                                                 ...
# 442  KOMMA SUPER SPECIALITY HOSPITAL, KADAPA, YSR K...
# 456  VEDANTA HOSPITALS, GUNTUR, Guntur, Andhra Prad...
# 460  PRABHA HOSPITAL, ELURU, West Godavari, Andhra ...
# 463  NOBLE MULTI SPECIALITY HOSPITAL, KURNOOL, Kurn...
# 464  LIBERTY HOSPITALS, Vijayawada, Krishna, Andhra...
#
# [113 rows x 3 columns]

# %%
hospital = pd.DataFrame(hosp, columns = ['hospital'])

# %%
hospital
# Out:
#                                               hospital
# 0    Rims Govt. General Hospital, Srikakulam, SRIKA...
# 1    Govt General Hospital Kurnool, KURNOOL, Kurnoo...
# 2    Queens Nri Hospitals, Visakhapatnam, Vishakhap...
# 3    Karumuri Hospital, GUNTUR, Guntur, Andhra Prad...
# 4    Ent Nursing Home, GUNTUR, Guntur, Andhra Prade...
# ..                                                 ...
# 463  NOBLE MULTI SPECIALITY HOSPITAL, KURNOOL, Kurn...
# 464  LIBERTY HOSPITALS, Vijayawada, Krishna, Andhra...
# 465  Jnanananda Ophthalmic Institute, BHIMAVARAM, W...
# 466  Pradhama Multi Speciality Hospitals and Reasea...
# 467  ss medicare multispeciality hospital, ONGOLE, ...
#
# [468 rows x 1 columns]

# %%
geo = geo.join(hospital,rsuffix='_right')

# %%
geo = geo.loc[geo['address'].notna()]

# %%
type(geo)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
fig, ax = plt.subplots(1, figsize=(20,12))
df.plot(linewidth=1, ax=ax, edgecolor='0.9', legend = True)
geo.plot(ax=ax)
ax.axis('off')
# Out:
# (76.36042095019074, 85.16897052217516, 12.29517878738338, 19.49279635675621)

# %%
import altair as alt

# %%
geo['lon'] = geo['geometry'].x
geo['lat'] = geo['geometry'].y

# %%
geo
# Out:
#                       geometry  \
# 3    POINT (80.45380 16.29855)
# 14   POINT (80.64680 16.24299)
# 16   POINT (80.45424 16.29602)
# 18   POINT (82.22731 16.95571)
# 22   POINT (78.50110 13.55704)
# ..                         ...
# 442  POINT (78.82429 14.46226)
# 456  POINT (80.46347 16.30720)
# 460  POINT (81.09550 16.71531)
# 463  POINT (78.04122 15.83567)
# 464  POINT (80.67153 16.48985)
#
#                                                address  \
# 3    Karumuri Super Speciality Hospital Pvt Ltd, Do...
# 14   Aswini Children's & Dental Hospital, Prakasam ...
# 16   Sailaja Multispeciality Hospital, Guntur - Han...
# 18   Government General Hospital, SH216, Kakinada, ...
# 22   Area Hospital,Madanapalli, Near Head Post Offi...
# ..                                                 ...
# 442  Komma Super Speciality Hospital, Arts College ...
# 456  Vedanta Hospitals, contaioner terminal, Guntur...
# 460  Prabha Hospital, RR Peta Road, Narasimha Rao P...
# 463  Health Care Noble Multi-Speciality Hospital, M...
# 464  Liberty Hospitals, Bandar Road, Vijayawada, Vi...
#
#                                               hospital  \
# 3    Karumuri Hospital, GUNTUR, Guntur, Andhra Prad...
# 14   Aswini Hospital, GUNTUR, Guntur, Andhra Prades...
# 16   SAILAJA MULTISPECIALITY HOSPITAL, GUNTUR, Gunt...
# 18   Government General Hospital,Kakinada, KAKINADA...
# 22   Area Hospital - Madanapalli, Chittoor, Chittoo...
# ..                                                 ...
# 442  KOMMA SUPER SPECIALITY HOSPITAL, KADAPA, YSR K...
# 456  VEDANTA HOSPITALS, GUNTUR, Guntur, Andhra Prad...
# 460  PRABHA HOSPITAL, ELURU, West Godavari, Andhra ...
# 463  NOBLE MULTI SPECIALITY HOSPITAL, KURNOOL, Kurn...
# 464  LIBERTY HOSPITALS, Vijayawada, Krishna, Andhra...
#
#                                  name        lon        lat
# 3                   Karumuri Hospital  80.453795  16.298553
# 14                    Aswini Hospital  80.646799  16.242985
# 16   SAILAJA MULTISPECIALITY HOSPITAL  80.454239  16.296021
# 18        Government General Hospital  82.227313  16.955713
# 22        Area Hospital - Madanapalli  78.501104  13.557043
# ..                                ...        ...        ...
# 442   KOMMA SUPER SPECIALITY HOSPITAL  78.824293  14.462264
# 456                 VEDANTA HOSPITALS  80.463470  16.307198
# 460                   PRABHA HOSPITAL  81.095502  16.715308
# 463   NOBLE MULTI SPECIALITY HOSPITAL  78.041217  15.835671
# 464                 LIBERTY HOSPITALS  80.671525  16.489853
#
# [113 rows x 6 columns]

# %%
geo['name'] = geo['hospital'].str.split(pat = ',', expand=True)[0]

# %%
df_join = df.loc[df['Population']>0]
spatial_join = geopandas.sjoin(geo, df_join, op='within')
# Out:
# /home/mato/jupyter/jupyterenv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3338: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
spatial_join
# Out:
#                       geometry  \
# 3    POINT (80.45380 16.29855)
# 14   POINT (80.64680 16.24299)
# 16   POINT (80.45424 16.29602)
# 29   POINT (80.44354 16.29972)
# 65   POINT (80.45011 16.29834)
# ..                         ...
# 375  POINT (80.99250 16.43962)
# 464  POINT (80.67153 16.48985)
# 99   POINT (83.65838 18.46153)
# 194  POINT (84.23868 18.60156)
# 268  POINT (83.89300 18.30672)
#
#                                                address  \
# 3    Karumuri Super Speciality Hospital Pvt Ltd, Do...
# 14   Aswini Children's & Dental Hospital, Prakasam ...
# 16   Sailaja Multispeciality Hospital, Guntur - Han...
# 29   Government General Hospital's Blood Bank - Gun...
# 65   Yashaswi Hospital, Donka Road, Arundelpet, Gun...
# ..                                                 ...
# 375  Annapurna Multi Speciality Hospital, Machilipa...
# 464  Liberty Hospitals, Bandar Road, Vijayawada, Vi...
# 99   GMR Varalakshmi Care Hospital Blood Bank, Main...
# 194  Area Hospital,Tekkali, Naupada - Tekkali - Mel...
# 268  Sindhura Hospitals, Kalingapatnam - Srikakulam...
#
#                                               hospital  \
# 3    Karumuri Hospital, GUNTUR, Guntur, Andhra Prad...
# 14   Aswini Hospital, GUNTUR, Guntur, Andhra Prades...
# 16   SAILAJA MULTISPECIALITY HOSPITAL, GUNTUR, Gunt...
# 29   Government General Hospital, Guntur, GUNTUR, G...
# 65   YASHASWI HOSPITALS, GUNTUR, Guntur, Andhra Pra...
# ..                                                 ...
# 375  ANNAPURNA MULTI SPECIALITY HOSPITAL, GUDIVADA,...
# 464  LIBERTY HOSPITALS, Vijayawada, Krishna, Andhra...
# 99   GMR Varalakshmi CARE Hospital , SRIKAKULAM, Sr...
# 194  Area hospital - Tekkali, SRIKAKULAM, Srikakula...
# 268  Sindhura Hospitals, SRIKAKULAM, Srikakulam, An...
#
#                                     name        lon        lat  index_right  \
# 3                      Karumuri Hospital  80.453795  16.298553          210
# 14                       Aswini Hospital  80.646799  16.242985          210
# 16      SAILAJA MULTISPECIALITY HOSPITAL  80.454239  16.296021          210
# 29           Government General Hospital  80.443536  16.299715          210
# 65                    YASHASWI HOSPITALS  80.450111  16.298336          210
# ..                                   ...        ...        ...          ...
# 375  ANNAPURNA MULTI SPECIALITY HOSPITAL  80.992504  16.439625          322
# 464                    LIBERTY HOSPITALS  80.671525  16.489853          322
# 99        GMR Varalakshmi CARE Hospital   83.658377  18.461530          549
# 194              Area hospital - Tekkali  84.238677  18.601565          549
# 268                   Sindhura Hospitals  83.893002  18.306717          549
#
#        DISTRICT           ST_NM  ST_CEN_CD  ...  censuscode  Code[10]  \
# 3        Guntur  Andhra Pradesh         28  ...         548        GU
# 14       Guntur  Andhra Pradesh         28  ...         548        GU
# 16       Guntur  Andhra Pradesh         28  ...         548        GU
# 29       Guntur  Andhra Pradesh         28  ...         548        GU
# 65       Guntur  Andhra Pradesh         28  ...         548        GU
# ..          ...             ...        ...  ...         ...       ...
# 375     Krishna  Andhra Pradesh         28  ...         547        KR
# 464     Krishna  Andhra Pradesh         28  ...         547        KR
# 99   Srikakulam  Andhra Pradesh         28  ...         542        SR
# 194  Srikakulam  Andhra Pradesh         28  ...         542        SR
# 268  Srikakulam  Andhra Pradesh         28  ...         542        SR
#
#     Official name   Headquarters Revenuedivisions  Mandals  Population  \
# 3          Guntur         Guntur              2.0     18.0   2091075.0
# 14         Guntur         Guntur              2.0     18.0   2091075.0
# 16         Guntur         Guntur              2.0     18.0   2091075.0
# 29         Guntur         Guntur              2.0     18.0   2091075.0
# 65         Guntur         Guntur              2.0     18.0   2091075.0
# ..            ...            ...              ...      ...         ...
# 375       Krishna  Machilipatnam              3.0     25.0   1735079.0
# 464       Krishna  Machilipatnam              3.0     25.0   1735079.0
# 99     Srikakulam     Srikakulam              3.0     30.0   2191471.0
# 194    Srikakulam     Srikakulam              3.0     30.0   2191471.0
# 268    Srikakulam     Srikakulam              3.0     30.0   2191471.0
#
#      Area(in sq.km)  Density(per sq.km)  Cantidad de Personas en el programa
# 3            2443.0              855.95                              60988.0
# 14           2443.0              855.95                              60988.0
# 16           2443.0              855.95                              60988.0
# 29           2443.0              855.95                              60988.0
# 65           2443.0              855.95                              60988.0
# ..              ...                 ...                                  ...
# 375          3775.0              459.62                              45174.0
# 464          3775.0              459.62                              45174.0
# 99           4591.0              477.34                              16137.0
# 194          4591.0              477.34                              16137.0
# 268          4591.0              477.34                              16137.0
#
# [102 rows x 21 columns]

# %%
points = alt.Chart(spatial_join).mark_circle().encode(
    longitude='lon:Q',
    latitude='lat:Q',
    tooltip=['name'],
)

fondo = alt.Chart(df.loc[df['Population']>0]).mark_geoshape(stroke='white',
                            fill='lightgray').encode(tooltip =['DISTRICT']).properties(width=800,
                                                                 height=800).project('mercator')

fondo+points
# points
# Out:
# alt.LayerChart(...)

# %%
df_join
