# %% [markdown]
# # Webscrapping de datos de MercadoLibre

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

# %% [markdown]
# ## Scrappeamos una sóla página

# %%
# Definimos la URL para scrappear
# url = 'https://www.mercadolibre.com.ar/mas-vendidos#menu=categories' 
url = 'https://listado.mercadolibre.com.ar/notebook#trends_tracking_id=61b3c37c-e0da-4304-ac5f-cb66f17b876e&component_id=MOST_WANTED'

# Hacemos el request de la url, y luego lo metemos en BeautifulSoup
html = requests.get(url.strip(), headers={'User-Agent': 'Mozilla/5.0'}).text
soup = BeautifulSoup(html, "lxml")

# %%
# Definimos un dict en blanco para cargarle los resultados en cada iteración
# i es el identificador del producto como clave principal del diccionario
dict = {}
i = 0

# Obtenemos el cuadro principal de los resultados, donde se encuentran divs mas pequeños con 
# la especificación de cada producto
item_list = soup.find_all('div', class_="ui-search-result__content-wrapper shops__result-content-wrapper")

# Ahora en item vamos guardando cada div de cada producto, y le extraemos las variables de principal interés
for item in item_list:
    product_name = item.find('h2')
    product_name = product_name.text
    product_price_symbol = item.find('span', {'class' : 'price-tag-symbol'})
    product_price_number = item.find('span', {'class' : 'price-tag-fraction'})
    product_discount = item.find('span', {'class' : 'ui-search-price__discount shops__price-discount'})
    product_cuotas = item.find('span', {'class' : 'ui-search-item__group__element shops__items-group-details ui-search-installments ui-search-color--LIGHT_GREEN'})
    product_shipping = item.find('p', {'class' : 'ui-search-item__shipping ui-search-item__shipping--free shops__item-shipping-free'}).text
    product_reviews = item.find('span', {'class' : 'ui-search-reviews__amount'})
    product_seller = item.find('p', {'class' : 'ui-search-official-store-label ui-search-item__group__element shops__items-group-details ui-search-color--GRAY'})
    product_link = item.find('a').get('href')
    
#   If find_all() can’t find anything, it returns an empty list. If find() can’t find anything, it returns None
    
#   .text is just a property that calls get_text. Therefore, calling get_text without arguments is 
#   the same thing as .text. However, get_text can also support various keyword arguments to change how 
#   it behaves (separator, strip, types). If you need more control over the result, 
#   then you need the functional form.


#   Sacamos el text de las etiquetas

    if product_price_symbol is not None:
        product_price_symbol = product_price_symbol.get_text()
    if product_price_number is not None:
        product_price_number = product_price_number.get_text()
    if product_discount is not None:
        product_discount = product_discount.get_text()
    if product_cuotas is not None:
        product_cuotas = product_cuotas.get_text()
    if product_reviews is not None:
        product_reviews = product_reviews.get_text()
    if product_seller is not None:
        product_seller = product_seller.get_text()
    
# Guardamos los resultados a un diccionario anidado.
    dict.update({i:{
        'product_name': product_name,
        'price_tag_symbol': product_price_symbol,
        'product_price_number': product_price_number,
        'product_discount': product_discount,
        'product_cuotas': product_cuotas,
        'product_shipping': product_shipping,
        'product_reviews': product_reviews,
        'product_seller': product_seller,
        'product_link': product_link
    }})

# Aumentamos el valor de i, para que el próximo producto tenga un id mayor al corriente    
    i= i + 1

# %%
dict
# Out:
# {0: {'product_name': 'Notebook EXO Smart T33 gris 14", Intel Celeron N4020  4GB de RAM 64GB SSD, Intel UHD Graphics 600 1366x768px Windows 11',
#   'price_tag_symbol': '$',
#   'product_price_number': '75.000',
#   'product_discount': '13% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '22',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-exo-smart-t33-gris-14-intel-celeron-n4020-4gb-de-ram-64gb-ssd-intel-uhd-graphics-600-1366x768px-windows-11/p/MLA19535438?pdp_filters=category:MLA1652#searchVariation=MLA19535438&position=1&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  1: {'product_name': 'Notebook EXO Smart M33 gris 14.1", Intel Celeron N4020  4GB de RAM 64GB SSD, Intel UHD Graphics 600 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '108.999',
#   'product_discount': '25% OFF',
#   'product_cuotas': 'Hasta 12 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '58',
#   'product_seller': 'Vendido por EXO',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-exo-smart-m33-gris-141-intel-celeron-n4020-4gb-de-ram-64gb-ssd-intel-uhd-graphics-600-1920x1080px-windows-10-home/p/MLA19516729?pdp_filters=category:MLA1652#searchVariation=MLA19516729&position=2&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  2: {'product_name': 'Notebook Dell Inspiron 3515 plateada 15.5", AMD Ryzen 5 3450U  8GB de RAM 256GB SSD, AMD Radeon RX Vega 8 (Ryzen 2000/3000) 1366x768px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '169.999',
#   'product_discount': '7% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '185',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3515-plateada-155-amd-ryzen-5-3450u-8gb-de-ram-256gb-ssd-amd-radeon-rx-vega-8-ryzen-20003000-1366x768px-windows-11-home/p/MLA19034498?pdp_filters=category:MLA1652#searchVariation=MLA19034498&position=3&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  3: {'product_name': 'Notebook Lenovo 15,6  Amd Ryzen 5 5500u 8gb 256gb ',
#   'price_tag_symbol': '$',
#   'product_price_number': '149.999',
#   'product_discount': '9% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-156-amd-ryzen-5-5500u-8gb-256gb/p/MLA19624369?pdp_filters=category:MLA1652#searchVariation=MLA19624369&position=4&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  4: {'product_name': 'Notebook Dell Inspiron 3515 azul 15.5", AMD Ryzen 7 3700U  8GB de RAM 512GB SSD, AMD Radeon RX Vega 10 60 Hz 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '199.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '185',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3515-azul-155-amd-ryzen-7-3700u-8gb-de-ram-512gb-ssd-amd-radeon-rx-vega-10-60-hz-1920x1080px-windows-11-home/p/MLA19471951?pdp_filters=category:MLA1652#searchVariation=MLA19471951&position=5&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  5: {'product_name': 'Notebook Lenovo IdeaPad 14IIL05  platinum gray 14", Intel Core i5 1035G1  8GB de RAM 512GB SSD, Intel UHD Graphics G1 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '168.265',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '525',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-14iil05-platinum-gray-14-intel-core-i5-1035g1-8gb-de-ram-512gb-ssd-intel-uhd-graphics-g1-1920x1080px-windows-10-home/p/MLA17796660?pdp_filters=category:MLA1652#searchVariation=MLA17796660&position=6&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  6: {'product_name': 'Apple Macbook Air (13 pulgadas, 2020, Chip M1, 256 GB de SSD, 8 GB de RAM) - Gris espacial',
#   'price_tag_symbol': '$',
#   'product_price_number': '279.990',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '486',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/apple-macbook-air-13-pulgadas-2020-chip-m1-256-gb-de-ssd-8-gb-de-ram-gris-espacial/p/MLA17828518?pdp_filters=category:MLA1652#searchVariation=MLA17828518&position=7&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  7: {'product_name': 'Notebook Bangho 15,6 Core I7 8gb 480gb Ssd Bes T5 I7 Win Pro',
#   'price_tag_symbol': '$',
#   'product_price_number': '329.999',
#   'product_discount': '10% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': 'Vendido por Bangho',
#   'product_link': 'https://click1.mercadolibre.com.ar/mclics/clicks/external/MLA/count?a=E8ZO5vk8B3lSPfmcyx1Hw%2FdvUCAgvyWJtD%2BDnYlZkVzbrdJmF6j2f0Fxfqu6cQEV8iskWeFeF9MivC04Dv%2FznZrbeP8DzVzQ5WxYFSkLBh7HHlN06FB2%2Fy6JW38SSKf6Ek67ixDw1szoHBmL3AxvJmEtXcEE%2B1lRc3LbCKS8tIlKQfL7iSmALw8LEQGjT5v4t%2Bpt9B%2BmhwoeAtfhrFGuAA%2Fntitca6ZtVBnReDOUbm%2BT6yo9IVDFlnZm6vCTiIXy5aRaFDkC%2BHW0OsyLNPSTaNx8%2FCeD9b6ZZfaJO5Ic83VzfDC5vfZzWq6hN6Y5tzs%2BYxaVavwQAZytd3Yt6W%2FgXkbHhWqTVqkyxOzrIb%2BICHlcKm9Id0%2BEA6JS43RBXdh%2Bm9s7Yq08W1WPkeA%2BUcqJxIiA%2FfgdMZTq44ow6qlnOkhbqGRYcr%2FScuR%2FzSxUyfBJeK8wFBJ3VZtISeHHQB8SaIaiFfC4%2FZW0IVm2BrdoMSv0elMaCtwiP2w5IJg7pC8RwPaWgy3iTBN3zff%2FxQ%2B9icADHZvESNnlQm8hjKIcVPa8rPYTAc5eUhFRhhiFqwIfI4FKIgrAmftLGN7cXB1GBfIx%2Brs%2FicYAHjGXQIkHjLZMyjs9qx2f6t7TwHebLJkXuojSkAocmnYJDSFcZu%2B2TAS2tNbM5%2BE%2F4z%2BPOWQAO1btDENkjQLzXtTN%2F2KjSM%2FNVGfkoumIUoPis3ayPEM265NR1CdvtFbEIKaT4xgshRNUFZ5v8GoM1VK9vwD8VZSZDttb7ybZkg8o1Qx9owd3w7yBs21Q6lGaE6APG7PU&rb=x'},
#  8: {'product_name': 'Notebook Hp 245g8 Ryzen 5-5500u 8gb 512ssd 14 W11p',
#   'price_tag_symbol': '$',
#   'product_price_number': '159.900',
#   'product_discount': '11% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://click1.mercadolibre.com.ar/mclics/clicks/external/MLA/count?a=BO7Bpy3pZ16HodNVNXLoJBMa9PLe4R6NZauB0M12zIl%2FwEHRtxwEsUjIuIVRmlulPvNEnxnCEZ5YVMRJ4y8xHkbFpNMOqDNckc8T8DYd0mJetid4DtcbbqONU6X08yVR4mL0ZeXrvHosJut1seBdvY0rgPQ9cKX0lK%2BoFq%2FUm0qWpyPngy17yUU33%2By3YVDSyThcwWDWz6tefzzeCDpP3ZnP4qN8TO24j84LDyOBBjr0lZKGTnIKdiw6OGNANZ%2BVNKv9ZrgCdhnLalIFO87srKhX13byzQBov6BOtYLM4GI5V0vlBfAJs5AnoaKdHg6ERGdB3Kv6jS69Xi6UjgEmh5hgrIF1GnECCeLod0OWCgV2QFXDhye8KH3GVs%2F%2BWfdCwcNZrgnKbwHGEehi7Y6YP2WhON8ANBUAzeboOD3Cjkkb0xYA%2FPGAiOAHJDxA7qhuX%2B3lfkIOSK4AtoMEa5Mmzo2UzwcDW8cUEKlTBInlaQYV539oJSQ77knFesTf4Jn8F%2B0JX2P25xxezqvHDHPva%2FJgGpNdJ9zbJTKlXZyeRPN2d9LtJGILxzFx5yRg8y7LhjtsceYNhLQScXOYSObPGbmef5f4Yp6y01s8%2F5feufPbJocyAEMtWnr5RTaMuPd0iIJABe50lIZLdFM5dcVg12gvsvbPGDAvKuJL8RWs33BiB9bmbvKJOIAGtZ5uvswHSZRtwb4HV0QAXlQN7B0WdPtyr8aKfYpDpllxQ9%2Bpf02vvO12st4g22YyIcaasr7j1lUYMA8E4%2FjcFVzqX80rry2ovyITIdhW&rb=x'},
#  9: {'product_name': 'Notebook HP Pavilion 15-eh0004la plata natural 15.6", AMD Ryzen 3 4300U  8GB de RAM 256GB SSD, AMD Radeon RX Vega 5 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '139.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '69',
#   'product_seller': 'Vendido por HP Tienda Oficial',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-pavilion-15-eh0004la-plata-natural-156-amd-ryzen-3-4300u-8gb-de-ram-256gb-ssd-amd-radeon-rx-vega-5-1366x768px-windows-10-home/p/MLA19048705?pdp_filters=category:MLA1652#searchVariation=MLA19048705&position=10&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  10: {'product_name': 'Notebook Lenovo Ideapad 3 14iil05 Intel Core I3 1005g1, 8gb De Ram, 128gb Ssd, 14  Full Hd, Windows 11 S, Gris Platino',
#   'price_tag_symbol': '$',
#   'product_price_number': '104.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '35',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-3-14iil05-intel-core-i3-1005g1-8gb-de-ram-128gb-ssd-14-full-hd-windows-11-s-gris-platino/p/MLA19525764?pdp_filters=category:MLA1652#searchVariation=MLA19525764&position=11&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  11: {'product_name': 'Notebook HP 14-dq2029la plata natural 14", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '179.999',
#   'product_discount': None,
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '119',
#   'product_seller': 'Vendido por HP Tienda Oficial',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-dq2029la-plata-natural-14-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-1366x768px-windows-10-home/p/MLA18953578?pdp_filters=category:MLA1652#searchVariation=MLA18953578&position=12&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  12: {'product_name': 'Notebook Kelyx Kl3350 Gris 14 , Intel Celeron N3350 4gb De Ram 64gb Ssd, Intel Hd Graphics 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '46.247',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '92',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-kelyx-kl3350-gris-14-intel-celeron-n3350-4gb-de-ram-64gb-ssd-intel-hd-graphics-1920x1080px-windows-10-home/p/MLA19525749?pdp_filters=category:MLA1652#searchVariation=MLA19525749&position=13&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  13: {'product_name': 'Notebook Asus X515EA slate gray 15.6", Intel Core i3 1115G4  4GB de RAM 256GB SSD, Intel UHD Graphics Xe G4 48EUs 1920x1080px FreeDOS',
#   'price_tag_symbol': '$',
#   'product_price_number': '114.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '879',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-x515ea-slate-gray-156-intel-core-i3-1115g4-4gb-de-ram-256gb-ssd-intel-uhd-graphics-xe-g4-48eus-1920x1080px-freedos/p/MLA18641991?pdp_filters=category:MLA1652#searchVariation=MLA18641991&position=14&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  14: {'product_name': 'Notebook HP 14-cf2531la negra 14", Intel Celeron N4020  4GB de RAM 128GB SSD, Intel UHD Graphics 600 1366x768px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '99.999',
#   'product_discount': None,
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '35',
#   'product_seller': 'Vendido por HP Tienda Oficial',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-cf2531la-negra-14-intel-celeron-n4020-4gb-de-ram-128gb-ssd-intel-uhd-graphics-600-1366x768px-windows-11-home/p/MLA19156449?pdp_filters=category:MLA1652#searchVariation=MLA19156449&position=15&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  15: {'product_name': 'Notebook Asus X515EA slate gray 15.6", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 1920x1080px',
#   'price_tag_symbol': '$',
#   'product_price_number': '153.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '879',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-x515ea-slate-gray-156-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-1920x1080px/p/MLA18964745?pdp_filters=category:MLA1652#searchVariation=MLA18964745&position=16&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  16: {'product_name': 'Notebook EXO Smart L33E gris 14", Intel Celeron N4020  4GB de RAM 64GB SSD, Intel UHD Graphics 600 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '64.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '241',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-exo-smart-l33e-gris-14-intel-celeron-n4020-4gb-de-ram-64gb-ssd-intel-uhd-graphics-600-1366x768px-windows-10-home/p/MLA18330430?pdp_filters=category:MLA1652#searchVariation=MLA18330430&position=17&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  17: {'product_name': 'Notebook Lenovo IdeaPad 15IIL05  almond 15.6", Intel Core i3 1005G1  8GB de RAM 256GB SSD, Intel UHD Graphics G1 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '137.623',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '487',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-15iil05-almond-156-intel-core-i3-1005g1-8gb-de-ram-256gb-ssd-intel-uhd-graphics-g1-1366x768px-windows-10-home/p/MLA18619162?pdp_filters=category:MLA1652#searchVariation=MLA18619162&position=18&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  18: {'product_name': 'Notebook Banghó Max L5 15,6 Core I7 8gb 480gb Win 11 +office',
#   'price_tag_symbol': '$',
#   'product_price_number': '289.999',
#   'product_discount': '5% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': 'Vendido por Bangho',
#   'product_link': 'https://click1.mercadolibre.com.ar/mclics/clicks/external/MLA/count?a=4iVF3pwInglfucRzL28TAMPBkd9tvHdTRwKafZ%2FXuOJ2dsa7IVQz3tR4oJ7cLBlP5JX%2BUG%2FTfWxMGE2zPHgPhsG9e5rVhzxib45rHc%2FVcAUQQ0VwTcl0OtCGIxB0akCCQtqUauBZKjoJmAi8D%2FSIFnqdMxR7IMpKxoWguWmg9OHZqx26VPEUygw1wWeIxMPorUCmYfP8sWiguzpX7R%2BrDUhOALgMAZEW4hBFKSH0beYPkUgH8r1lWD%2F3OcrdgswGyB%2FixOjxU3WsVtlcdbu0Udve2dspE%2FXe3lsAGWCtiRTyQ7BMW36pQj83%2F9hz%2FxJMZbipUtdhpmE5wg46mrnfGhKgmv%2BALyjtF37X0wbO4HuwWKvm%2Fpr3Zd6UkzFJLJLvojcI61yPP7xT4ueMBWHNWxmHOau0vpkX30EK83tppEvO3Xq%2F9LI11%2F%2FygwGTBHIBS%2BUM4F1ng8ZjzjSqcUqT%2BuwsKgfD%2FxdscBDUD45fJSngnty%2FbKZBr5xfkfyH%2Fz96Atpl5r5tyIAiBKxXf0GJg6WRKfC5M%2Fhf1MWCekj4%2B0elSq%2B7IH5rO5QUqZxdV9c%2BsWoEGlOCkaqfGQHM8AfheOsTNvE9h8aWveBiMP0i3CKcWYpTPgB434Km4P1Tp9mAbKCRuAqbdnqu3%2B%2FtSbQhkJiXKGed6IeR1x17fAP6vX%2Fu52I7u3HEPkzi%2F8XtLmFgey1nm%2FJDt%2FqyAMpjJ3WMH%2F%2BaQ7x49jJOEhydbFAxOmBSA6c7oiB2HrQSv2YiOGsueuXN%2Bt62WGbMOuH2FcGQcNSkzlgcdhJW7zqZLr0O9sAnh4A%3D&rb=x'},
#  19: {'product_name': 'Apple Macbook Air M2 2022 8gb Ram 256gb Ssd Space Gray 13.6 ',
#   'price_tag_symbol': '$',
#   'product_price_number': '366.599',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://click1.mercadolibre.com.ar/mclics/clicks/external/MLA/count?a=cQ6ap%2FI1f2Na%2B0BrhrWq1R6Jm82JlkTBcdYgI98v75Kc9h3dJXF7%2F1jIM7R0lbu2FizbzG2Q6APAmZSU0cpQ2WNpBJiu%2FJbvBdWu2NElz5j23IwBdOULczSZtwKyeLnPOKkN%2BNbDYZFfzld2xytss4Q0wlwMSSJfv8G27pp4uN6VjmIpUi0MWnAC%2Fi4wX0hMxClqPQlsDfhuLBu%2Bf79ve8lZx%2FfdQaAKQnSSozebfbk8zGWcCaIFPKSkH0ZMwujYHdI1Jxv7G3sVy5aGEZjTNOnjLqUd4jrgF%2BCRH73GTRnG1v9MHCe4uecEzLZUJCIgL3cOJR24ZnfwUp5wxV1DURvsINbTkggvVGr2qV%2F1JwhPQwK2WJ8pQZTs%2BjinJyf9AXjV8FTBgcIYpeCS3ZKaX2ibI%2FCC0djpIufwPFDjo0phHaAcjEaE%2Bf1JdFnZ8J9xH7jEBfqM7p4MOwg4EounmorAFWerW5jSNkKWRJZ%2BB13gCO6SD1Jz5ynLPiQ5znQg3QKT2USvFdW2KUNGL3jo5yRoBz9Qg%2BttLGQlNqPY%2B%2FIKEMlyPyJRvMtUbNarRvK9wxeDv9RsLYamjLxmFSkrh0MZA1JOuXKceVHYqTRaNlH5Qr0ES8N%2FWr6vBtALokbvFUyC6q18Wsf4dV9y4V8EFb2HTaJvV6ZVl7ekqgybuhMq1%2BGEmxWSduHylUoqNP0iFP6NIoCZ%2BuyFcn98zJ0Qm%2F%2B6x9YFi66j1hJg6PijFuwvZFlh2d9LeZmi9suoFhciHRjbfcm%2FR7UvC4h4Pbu7PmA9RlNQzoUAKL%2BXh55KQWCiTVRq&rb=x'},
#  20: {'product_name': 'Notebook HP 15-ef2513la azul índigo 15.6", AMD Ryzen 5 5500U  8GB de RAM 256GB SSD, AMD Radeon RX Vega 7 1366x768px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '162.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '20',
#   'product_seller': 'Vendido por HP Tienda Oficial',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-15-ef2513la-azul-indigo-156-amd-ryzen-5-5500u-8gb-de-ram-256gb-ssd-amd-radeon-rx-vega-7-1366x768px-windows-11-home/p/MLA19167862?pdp_filters=category:MLA1652#searchVariation=MLA19167862&position=21&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  21: {'product_name': 'Notebook EXO Smart P33 gris 14.1", Intel Celeron N4020  4GB de RAM 64GB SSD, Intel UHD Graphics 600 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '64.999',
#   'product_discount': '5% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '141',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-exo-smart-p33-gris-141-intel-celeron-n4020-4gb-de-ram-64gb-ssd-intel-uhd-graphics-600-1920x1080px-windows-11-home/p/MLA18648558?pdp_filters=category:MLA1652#searchVariation=MLA18648558&position=22&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  22: {'product_name': 'Notebook Asus ZenBook 14 UM425QA pine gray 14", AMD Ryzen 5 4500U  8GB de RAM 512GB SSD, AMD Radeon RX Vega 6 (Ryzen 4000/5000) 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '219.999',
#   'product_discount': None,
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '13',
#   'product_seller': 'Vendido por Mercado Libre Electronica',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-zenbook-14-um425qa-pine-gray-14-amd-ryzen-5-4500u-8gb-de-ram-512gb-ssd-amd-radeon-rx-vega-6-ryzen-40005000-1920x1080px-windows-11-home/p/MLA19488544?pdp_filters=category:MLA1652#searchVariation=MLA19488544&position=23&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  23: {'product_name': 'Notebook Dell Inspiron 3505 silver 15.6", AMD Ryzen 5 3450U  8GB de RAM 256GB SSD, AMD Radeon RX Vega 8 (Ryzen 2000/3000) 60 Hz 1366x768px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '318.449',
#   'product_discount': '37% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '1033',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3505-silver-156-amd-ryzen-5-3450u-8gb-de-ram-256gb-ssd-amd-radeon-rx-vega-8-ryzen-20003000-60-hz-1366x768px-windows-11-home/p/MLA16537306?pdp_filters=category:MLA1652#searchVariation=MLA16537306&position=24&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  24: {'product_name': 'Notebook Dell Inspiron 5510 azul 15.6", Intel Core i7 11370H  12GB de RAM 512GB SSD, Intel Iris Xe Graphics G7 96EU 60 Hz 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '331.995',
#   'product_discount': '5% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '86',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-5510-azul-156-intel-core-i7-11370h-12gb-de-ram-512gb-ssd-intel-iris-xe-graphics-g7-96eu-60-hz-1920x1080px-windows-10-home/p/MLA18953644?pdp_filters=category:MLA1652#searchVariation=MLA18953644&position=25&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  25: {'product_name': 'Notebook Acer Aspire 5 A514-54 dorada 14", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 60 Hz 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '139.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '11',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-acer-aspire-5-a514-54-dorada-14-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-60-hz-1920x1080px-windows-10-home/p/MLA18584529?pdp_filters=category:MLA1652#searchVariation=MLA18584529&position=26&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  26: {'product_name': 'Notebook Banghó Max L4 i1 gris oscura 14", Intel Celeron N4000  4GB de RAM 120GB SSD, Intel UHD Graphics 600 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '84.998',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '352',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-bangho-max-l4-i1-gris-oscura-14-intel-celeron-n4000-4gb-de-ram-120gb-ssd-intel-uhd-graphics-600-1366x768px-windows-10-home/p/MLA16273683?pdp_filters=category:MLA1652#searchVariation=MLA16273683&position=27&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  27: {'product_name': 'Notebook HP Pavilion 13-bb0003la plata natural 13.3", Intel Core i5 1135G7  8GB de RAM 256GB SSD 16GB Optane, Intel Iris Xe Graphics G7 80EUs 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '219.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '37',
#   'product_seller': 'Vendido por HP Tienda Oficial',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-pavilion-13-bb0003la-plata-natural-133-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-16gb-optane-intel-iris-xe-graphics-g7-80eus-1920x1080px-windows-10-home/p/MLA18608726?pdp_filters=category:MLA1652#searchVariation=MLA18608726&position=28&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  28: {'product_name': 'Notebook HP 240 G7 plateado ceniza oscuro 14", Intel Core i3 1005G1  8GB de RAM 1TB HDD, Intel UHD Graphics G1 (Ice Lake 32 EU) 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '123.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '1718',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-240-g7-plateado-ceniza-oscuro-14-intel-core-i3-1005g1-8gb-de-ram-1tb-hdd-intel-uhd-graphics-g1-ice-lake-32-eu-1366x768px-windows-10-home/p/MLA18169995?pdp_filters=category:MLA1652#searchVariation=MLA18169995&position=29&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  29: {'product_name': 'Notebook Hp New Elite I7 11va 32gb 17.3 1tb Ssd 16gb Video',
#   'price_tag_symbol': '$',
#   'product_price_number': '568.999',
#   'product_discount': '15% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://click1.mercadolibre.com.ar/mclics/clicks/external/MLA/count?a=tE4BAuq1B2GLHf7AOJHRFmaYJLhjGkXI9GlepNgGhIUNYQWO6VT%2FtZSmFILy7%2BEGZfrFU2V2O8OHHvDrxmDqvKFyJXtehM6Y10rKjidYtNLDAZcyI%2FJWOCRnl0IVkh%2FN3%2FOHvNx8DEDtm6q1QY%2BUQN3pVV1jKPP9CEidwdC%2FKYe8Uka7NFHbrhOrjmCrQtHpuGt2rQJNtp7iU4uhM6DgFel3irVEwk7hz7ugbw7jDe%2BPKbU9LIkV5xXkAthp710WbApLiobbTdM7yR7YRgeXoBQ8cItkDghFlEfURgFN2aFT%2F2TUqaUNhBgakaS755aRALLVZ2fgM3qPxw0bfekoCBKvIVkVgGZh3kAc3imukN9n4vXdEdAPM3nv2v0oiOrxkgvzIrc43qJIu8wi8yksbAIxP4LBcA34A9d4v4vj1QqvOK3J56kEszW992XISVk7yEFTFWdCCFZNoa6%2F17aHK13Oa8LPYYEm%2BSBrIaHehuSpZAOxlos3Gf%2BXqUQjlegyasbhi0EEAlbf517qoYfgQldfFWzQA6U1Z5Uoez%2FaXuIC7AQj9BnLmh%2BSvU097xddAhqF6VfOz9cHRJK6I3N58ARMWk%2BPfDsH%2Bxnf3KGluXQqOvRLJpsqwv%2BG52cxpwUmn5FBn6459pNvM8W8DrE3DbigVtTuOFglSv5HaPd%2FNiTRR08fOJbj%2BfPdm1LSxImKhtsNUDhJEyG3%2F5dg9IxNfYdzaeSHedrX7AblrvlCq8RH8Js%2FLbuh3%2F%2FCCFqAeBiYYgcL4XoZ%2FMljmmYBzVB1bI7MwHCys24lrFtbcgShPyZiUg%3D%3D&rb=x'},
#  30: {'product_name': 'Notebook Bangho 15,6 Core I5 8gb 480gb Ssd Bes T5 I5 Win Pro',
#   'price_tag_symbol': '$',
#   'product_price_number': '279.999',
#   'product_discount': '10% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': 'Vendido por Bangho',
#   'product_link': 'https://click1.mercadolibre.com.ar/mclics/clicks/external/MLA/count?a=RLYSgDQ3h8K04uu%2B%2BR6pNNbg%2BEcxKYGsPawCRoAuAyYTCO72Moyuc8yCaJX4gSq0qbKZFXd7P82fknGXcYnuWr6jkAqceZoH4SXeiKY2rzjB%2BUMnO6XkOm47GDo2L1FUxuwnyui0H6zFf1jkKwrCP4AA9Rdhz5uxR3VdId%2B4avMyJ5lIXnX2WVJ1tgKSHsTVhg1G2aapsdqhrJJSsKtVwzpuZu7eiDBfFBhmsjPOss69xUEpDZkQ%2FUTEldk6qznQXeaLwaRD8xWuYaMD9CnA%2Fc8whAqGwd7lowDl7%2BSn5aoABTeLr0T6i9n46wcwvygjGAJM1F3k4kS9mTDtFJHFTyYgI4UfZFiJvNV9%2FzKhbj%2BS2o%2BCcT4SW3nISgvwkOqDgVEwkQ3nvoNN8JGwQEWO9zUJ2bVOaFMpGdWadOyMbtxsuV3eBpu7jHDSKMv1ORlmXzwAX%2BVhCvL%2FgLR0voOj33nDJuDXjm5p32zMoUFHwVdm1ZzLb2cCdmVkMojUnAManIMIvvySrwzlwd9RDsilmZdEGdts1GzTf8M5fel1eRe3sxTgIntYHdTKTzroTIOwwYY1DYCK92FrbUP5pdYAzBHgpG3w4CpgwMq7ypJP3DUO5Ax4qbs3DLlLf1B8veLxjLNo3m12pVPN8lFc9yZHrcPyimZfs32Y%2FHlwsA3WrBZKoo%2FsGAiczVyr%2FAyV4kdna%2FWVP1rKX4ql3HzDS6aSP2CBKXtiiQvz6O8QWJiKIZ9VrakGTafESSaAqJ3QhWTFO1m5J%2BQNcPPrGu5grllsL4KW9puH9iHSvxfpyOsxxM1%2FDE%2F%2B%2Fg%3D%3D&rb=x'},
#  31: {'product_name': 'Apple Macbook Air (13 pulgadas, 2020, Chip M1, 256 GB de SSD, 8 GB de RAM) - Plata',
#   'price_tag_symbol': '$',
#   'product_price_number': '287.000',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '486',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/apple-macbook-air-13-pulgadas-2020-chip-m1-256-gb-de-ssd-8-gb-de-ram-plata/p/MLA17828520?pdp_filters=category:MLA1652#searchVariation=MLA17828520&position=32&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  32: {'product_name': 'Notebook Dell Latitude 3190 11  Hd Intel Celeron N4120 4 Gb Ddr4-sdram 128 Gb Ssd Wi-fi 5 (802.11ac) Windows 10 Home Negro',
#   'price_tag_symbol': '$',
#   'product_price_number': '141.549',
#   'product_discount': '38% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '154',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-latitude-3190-11-hd-intel-celeron-n4120-4-gb-ddr4-sdram-128-gb-ssd-wi-fi-5-80211ac-windows-10-home-negro/p/MLA18560984?pdp_filters=category:MLA1652#searchVariation=MLA18560984&position=33&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  33: {'product_name': 'Notebook HP 14-cf2533la plata natural 14", Intel Core i3 10110U  4GB de RAM 256GB SSD, Intel UHD Graphics 620 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '119.999',
#   'product_discount': '12% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '85',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-cf2533la-plata-natural-14-intel-core-i3-10110u-4gb-de-ram-256gb-ssd-intel-uhd-graphics-620-1366x768px-windows-10-home/p/MLA18723081?pdp_filters=category:MLA1652#searchVariation=MLA18723081&position=34&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  34: {'product_name': 'Notebook HP 240 G7 plateado ceniza oscuro 14", Intel Celeron N4000  4GB de RAM 500GB HDD, Intel UHD Graphics 600 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '99.799',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '1718',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-240-g7-plateado-ceniza-oscuro-14-intel-celeron-n4000-4gb-de-ram-500gb-hdd-intel-uhd-graphics-600-1366x768px-windows-10-home/p/MLA16950784?pdp_filters=category:MLA1652#searchVariation=MLA16950784&position=35&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  35: {'product_name': 'Notebook HP 14-dk1022wm natural silver 14", AMD Ryzen 3 3250U  4GB de RAM 128GB SSD, AMD Radeon Vega 3 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '81.599',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '212',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-dk1022wm-natural-silver-14-amd-ryzen-3-3250u-4gb-de-ram-128gb-ssd-amd-radeon-vega-3-1366x768px-windows-10-home/p/MLA16041765?pdp_filters=category:MLA1652#searchVariation=MLA16041765&position=36&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  36: {'product_name': 'Notebook Asus X515EA gris 15.6", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 1920x1080px FreeDOS',
#   'price_tag_symbol': '$',
#   'product_price_number': '286.149',
#   'product_discount': '37% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '879',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-x515ea-gris-156-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-1920x1080px-freedos/p/MLA18500496?pdp_filters=category:MLA1652#searchVariation=MLA18500496&position=37&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  37: {'product_name': 'Notebook HP Pavilion 15-eh0009la verde azulado 15.6", AMD Ryzen 7 4700U  8GB de RAM 512GB SSD, AMD Radeon RX Vega 7 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '252.999',
#   'product_discount': None,
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '22',
#   'product_seller': 'Vendido por Megatone',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-pavilion-15-eh0009la-verde-azulado-156-amd-ryzen-7-4700u-8gb-de-ram-512gb-ssd-amd-radeon-rx-vega-7-1920x1080px-windows-10-home/p/MLA19101523?pdp_filters=category:MLA1652#searchVariation=MLA19101523&position=38&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  38: {'product_name': 'Notebook EXO Smart XQ3H-S3182 plateada 15.6", Intel Core i3 1115G4  8GB de RAM 256GB SSD, Intel UHD Graphics Xe G4 48EUs 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '245.999',
#   'product_discount': '34% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '189',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-exo-smart-xq3h-s3182-plateada-156-intel-core-i3-1115g4-8gb-de-ram-256gb-ssd-intel-uhd-graphics-xe-g4-48eus-1920x1080px-windows-11-home/p/MLA18997588?pdp_filters=category:MLA1652#searchVariation=MLA18997588&position=39&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  39: {'product_name': 'Notebook HP 14-cf2051la plata natural 14", Intel Core i3 10110U  4GB de RAM 256GB SSD, Intel UHD Graphics 620 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '104.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': 'Vendido por HP Tienda Oficial',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-cf2051la-plata-natural-14-intel-core-i3-10110u-4gb-de-ram-256gb-ssd-intel-uhd-graphics-620-1366x768px-windows-10-home/p/MLA18939421?pdp_filters=category:MLA1652#searchVariation=MLA18939421&position=40&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  40: {'product_name': 'Notebook Acer Aspire 3 A315-34 negra 15.6", Intel Celeron N4000  4GB de RAM 500GB HDD, Intel HD Graphics 620 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '99.000',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '27',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-acer-aspire-3-a315-34-negra-156-intel-celeron-n4000-4gb-de-ram-500gb-hdd-intel-hd-graphics-620-1366x768px-windows-10-home/p/MLA17322521?pdp_filters=category:MLA1652#searchVariation=MLA17322521&position=41&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  41: {'product_name': 'Notebook Lenovo V-Series V15-G2-ITL  iron gray 15.6", Intel Core i7 1165G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 96EUs 1920x1080px',
#   'price_tag_symbol': '$',
#   'product_price_number': '199.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '77',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-v-series-v15-g2-itl-iron-gray-156-intel-core-i7-1165g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-96eus-1920x1080px/p/MLA18717227?pdp_filters=category:MLA1652#searchVariation=MLA18717227&position=42&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  42: {'product_name': 'Notebook gamer MSI Thin GF63 negra 15.6", Intel Core i5 9300H  8GB de RAM 256GB SSD, NVIDIA GeForce GTX 1650 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '217.899',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '55',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-gamer-msi-thin-gf63-negra-156-intel-core-i5-9300h-8gb-de-ram-256gb-ssd-nvidia-geforce-gtx-1650-1920x1080px-windows-10-home/p/MLA15279469?pdp_filters=category:MLA1652#searchVariation=MLA15279469&position=43&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  43: {'product_name': 'Notebook Dell Inspiron 3505 gris 15.6", AMD Ryzen 5 3450U  16GB de RAM 256GB SSD, AMD Radeon RX Vega 8 (Ryzen 2000/3000) 60 Hz 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '284.599',
#   'product_discount': '34% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '1033',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3505-gris-156-amd-ryzen-5-3450u-16gb-de-ram-256gb-ssd-amd-radeon-rx-vega-8-ryzen-20003000-60-hz-1366x768px-windows-10-home/p/MLA16999018?pdp_filters=category:MLA1652#searchVariation=MLA16999018&position=44&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  44: {'product_name': 'Notebook Asus VivoBook F512DA plata 15.6", AMD Ryzen 3 3200U  4GB de RAM 128GB SSD, AMD Radeon RX Vega 3 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '149.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '208',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-vivobook-f512da-plata-156-amd-ryzen-3-3200u-4gb-de-ram-128gb-ssd-amd-radeon-rx-vega-3-1920x1080px-windows-10-home/p/MLA15248658?pdp_filters=category:MLA1652#searchVariation=MLA15248658&position=45&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  45: {'product_name': 'Notebook Hp Amd Ryzen 7 5700u 12gb 256gb Ssd 15.6  Touchscreen Tactil Windows 11 (15-ef2081ms)',
#   'price_tag_symbol': '$',
#   'product_price_number': '194.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '8',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-amd-ryzen-7-5700u-12gb-256gb-ssd-156-touchscreen-tactil-windows-11-15-ef2081ms/p/MLA19569670?pdp_filters=category:MLA1652#searchVariation=MLA19569670&position=46&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  46: {'product_name': 'Notebook Asus Vivobook X712JA plata 17.3", Intel Core i7 1065G7  16GB de RAM 1 TB SSD, Intel Iris Plus Graphics G7 1600x900px Windows Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '359.998',
#   'product_discount': '17% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '35',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-vivobook-x712ja-plata-173-intel-core-i7-1065g7-16gb-de-ram-1-tb-ssd-intel-iris-plus-graphics-g7-1600x900px-windows-home/p/MLA18519896?pdp_filters=category:MLA1652#searchVariation=MLA18519896&position=47&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  47: {'product_name': 'Notebook Noblex 15.6” Full HD Intel Core i3 4GB/256GB SSD',
#   'price_tag_symbol': '$',
#   'product_price_number': '104.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '72',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-noblex-156-full-hd-intel-core-i3-4gb256gb-ssd/p/MLA18547225?pdp_filters=category:MLA1652#searchVariation=MLA18547225&position=48&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  48: {'product_name': 'Notebook Asus VivoBook F415EA slate gray 14", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 60 Hz 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '169.828',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '32',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-vivobook-f415ea-slate-gray-14-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-60-hz-1920x1080px-windows-10-home/p/MLA18927766?pdp_filters=category:MLA1652#searchVariation=MLA18927766&position=49&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  49: {'product_name': 'Notebook HP 14-dq2055wm silver 14", Intel Core i3 1115G4  4GB de RAM 256GB SSD, Intel UHD Graphics Xe G4 48EUs 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '111.880',
#   'product_discount': '10% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '64',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-dq2055wm-silver-14-intel-core-i3-1115g4-4gb-de-ram-256gb-ssd-intel-uhd-graphics-xe-g4-48eus-1920x1080px-windows-10-home/p/MLA18648554?pdp_filters=category:MLA1652#searchVariation=MLA18648554&position=50&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  50: {'product_name': 'Notebook Dell Inspiron 3515 plateada 15.5", AMD Ryzen 5 3450U  16GB de RAM 1TB HDD 256GB SSD, AMD Radeon RX Vega 8 (Ryzen 2000/3000) 1366x768px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '204.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '185',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3515-plateada-155-amd-ryzen-5-3450u-16gb-de-ram-1tb-hdd-256gb-ssd-amd-radeon-rx-vega-8-ryzen-20003000-1366x768px-windows-11-home/p/MLA19472483?pdp_filters=category:MLA1652#searchVariation=MLA19472483&position=51&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  51: {'product_name': 'Notebook Lenovo IdeaPad 15ALC6  arctic gray 15.6", AMD Ryzen 5 5500U  8GB de RAM 256GB SSD, AMD Radeon RX Vega 7 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '145.498',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '164',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-15alc6-arctic-gray-156-amd-ryzen-5-5500u-8gb-de-ram-256gb-ssd-amd-radeon-rx-vega-7-1920x1080px-windows-10-home/p/MLA18518417?pdp_filters=category:MLA1652#searchVariation=MLA18518417&position=52&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  52: {'product_name': 'Notebook Asus X515EA gris 15.6", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 1920x1080px Windows 10',
#   'price_tag_symbol': '$',
#   'product_price_number': '159.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '879',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-x515ea-gris-156-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-1920x1080px-windows-10/p/MLA18554118?pdp_filters=category:MLA1652#searchVariation=MLA18554118&position=53&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  53: {'product_name': 'Notebook Enova Intel Celeron 4gb 128gb W10',
#   'price_tag_symbol': '$',
#   'product_price_number': '71.999',
#   'product_discount': '12% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '53',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-enova-intel-celeron-4gb-128gb-w10/p/MLA19435091?pdp_filters=category:MLA1652#searchVariation=MLA19435091&position=54&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  54: {'product_name': 'Apple Macbook Air (13 pulgadas, 2020, Chip M1, 256 GB de SSD, 8 GB de RAM) - Oro',
#   'price_tag_symbol': '$',
#   'product_price_number': '289.499',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '486',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/apple-macbook-air-13-pulgadas-2020-chip-m1-256-gb-de-ssd-8-gb-de-ram-oro/p/MLA17828522?pdp_filters=category:MLA1652#searchVariation=MLA17828522&position=55&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  55: {'product_name': 'Notebook Banghó Max L5 i7 gris oscura 15.6", Intel Core i7 10510U  8GB de RAM 480GB SSD, Intel Graphics UHD 620 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '172.990',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '220',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-bangho-max-l5-i7-gris-oscura-156-intel-core-i7-10510u-8gb-de-ram-480gb-ssd-intel-graphics-uhd-620-1366x768px-windows-10-home/p/MLA18259066?pdp_filters=category:MLA1652#searchVariation=MLA18259066&position=56&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  56: {'product_name': 'Notebook EXO Smart T33 gris 14", Intel Celeron N4020  4GB de RAM 64GB SSD, Intel UHD Graphics 600 1366x768px Windows 11',
#   'price_tag_symbol': '$',
#   'product_price_number': '75.000',
#   'product_discount': '13% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '22',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-exo-smart-t33-gris-14-intel-celeron-n4020-4gb-de-ram-64gb-ssd-intel-uhd-graphics-600-1366x768px-windows-11/p/MLA19535438?pdp_filters=category:MLA1652#searchVariation=MLA19535438&position=1&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  57: {'product_name': 'Notebook EXO Smart M33 gris 14.1", Intel Celeron N4020  4GB de RAM 64GB SSD, Intel UHD Graphics 600 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '108.999',
#   'product_discount': '25% OFF',
#   'product_cuotas': 'Hasta 12 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '58',
#   'product_seller': 'Vendido por EXO',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-exo-smart-m33-gris-141-intel-celeron-n4020-4gb-de-ram-64gb-ssd-intel-uhd-graphics-600-1920x1080px-windows-10-home/p/MLA19516729?pdp_filters=category:MLA1652#searchVariation=MLA19516729&position=2&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  58: {'product_name': 'Notebook Dell Inspiron 3515 plateada 15.5", AMD Ryzen 5 3450U  8GB de RAM 256GB SSD, AMD Radeon RX Vega 8 (Ryzen 2000/3000) 1366x768px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '169.999',
#   'product_discount': '7% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '185',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3515-plateada-155-amd-ryzen-5-3450u-8gb-de-ram-256gb-ssd-amd-radeon-rx-vega-8-ryzen-20003000-1366x768px-windows-11-home/p/MLA19034498?pdp_filters=category:MLA1652#searchVariation=MLA19034498&position=3&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  59: {'product_name': 'Notebook Lenovo 15,6  Amd Ryzen 5 5500u 8gb 256gb ',
#   'price_tag_symbol': '$',
#   'product_price_number': '149.999',
#   'product_discount': '9% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-156-amd-ryzen-5-5500u-8gb-256gb/p/MLA19624369?pdp_filters=category:MLA1652#searchVariation=MLA19624369&position=4&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  60: {'product_name': 'Notebook Dell Inspiron 3515 azul 15.5", AMD Ryzen 7 3700U  8GB de RAM 512GB SSD, AMD Radeon RX Vega 10 60 Hz 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '199.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '185',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3515-azul-155-amd-ryzen-7-3700u-8gb-de-ram-512gb-ssd-amd-radeon-rx-vega-10-60-hz-1920x1080px-windows-11-home/p/MLA19471951?pdp_filters=category:MLA1652#searchVariation=MLA19471951&position=5&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  61: {'product_name': 'Notebook Lenovo IdeaPad 14IIL05  platinum gray 14", Intel Core i5 1035G1  8GB de RAM 512GB SSD, Intel UHD Graphics G1 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '168.265',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '525',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-14iil05-platinum-gray-14-intel-core-i5-1035g1-8gb-de-ram-512gb-ssd-intel-uhd-graphics-g1-1920x1080px-windows-10-home/p/MLA17796660?pdp_filters=category:MLA1652#searchVariation=MLA17796660&position=6&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
# ...
#  202: {'product_name': 'Notebook HP 240 G7 plateado ceniza oscuro 14", Intel Celeron N4000  4GB de RAM 500GB HDD, Intel UHD Graphics 600 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '99.799',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '1718',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-240-g7-plateado-ceniza-oscuro-14-intel-celeron-n4000-4gb-de-ram-500gb-hdd-intel-uhd-graphics-600-1366x768px-windows-10-home/p/MLA16950784?pdp_filters=category:MLA1652#searchVariation=MLA16950784&position=35&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  203: {'product_name': 'Notebook HP 14-dk1022wm natural silver 14", AMD Ryzen 3 3250U  4GB de RAM 128GB SSD, AMD Radeon Vega 3 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '81.599',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '212',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-dk1022wm-natural-silver-14-amd-ryzen-3-3250u-4gb-de-ram-128gb-ssd-amd-radeon-vega-3-1366x768px-windows-10-home/p/MLA16041765?pdp_filters=category:MLA1652#searchVariation=MLA16041765&position=36&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  204: {'product_name': 'Notebook Asus X515EA gris 15.6", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 1920x1080px FreeDOS',
#   'price_tag_symbol': '$',
#   'product_price_number': '286.149',
#   'product_discount': '37% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '879',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-x515ea-gris-156-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-1920x1080px-freedos/p/MLA18500496?pdp_filters=category:MLA1652#searchVariation=MLA18500496&position=37&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  205: {'product_name': 'Notebook HP Pavilion 15-eh0009la verde azulado 15.6", AMD Ryzen 7 4700U  8GB de RAM 512GB SSD, AMD Radeon RX Vega 7 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '252.999',
#   'product_discount': None,
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '22',
#   'product_seller': 'Vendido por Megatone',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-pavilion-15-eh0009la-verde-azulado-156-amd-ryzen-7-4700u-8gb-de-ram-512gb-ssd-amd-radeon-rx-vega-7-1920x1080px-windows-10-home/p/MLA19101523?pdp_filters=category:MLA1652#searchVariation=MLA19101523&position=38&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  206: {'product_name': 'Notebook EXO Smart XQ3H-S3182 plateada 15.6", Intel Core i3 1115G4  8GB de RAM 256GB SSD, Intel UHD Graphics Xe G4 48EUs 1920x1080px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '245.999',
#   'product_discount': '34% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '189',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-exo-smart-xq3h-s3182-plateada-156-intel-core-i3-1115g4-8gb-de-ram-256gb-ssd-intel-uhd-graphics-xe-g4-48eus-1920x1080px-windows-11-home/p/MLA18997588?pdp_filters=category:MLA1652#searchVariation=MLA18997588&position=39&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  207: {'product_name': 'Notebook HP 14-cf2051la plata natural 14", Intel Core i3 10110U  4GB de RAM 256GB SSD, Intel UHD Graphics 620 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '104.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': None,
#   'product_seller': 'Vendido por HP Tienda Oficial',
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-cf2051la-plata-natural-14-intel-core-i3-10110u-4gb-de-ram-256gb-ssd-intel-uhd-graphics-620-1366x768px-windows-10-home/p/MLA18939421?pdp_filters=category:MLA1652#searchVariation=MLA18939421&position=40&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  208: {'product_name': 'Notebook Acer Aspire 3 A315-34 negra 15.6", Intel Celeron N4000  4GB de RAM 500GB HDD, Intel HD Graphics 620 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '99.000',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '27',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-acer-aspire-3-a315-34-negra-156-intel-celeron-n4000-4gb-de-ram-500gb-hdd-intel-hd-graphics-620-1366x768px-windows-10-home/p/MLA17322521?pdp_filters=category:MLA1652#searchVariation=MLA17322521&position=41&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  209: {'product_name': 'Notebook Lenovo V-Series V15-G2-ITL  iron gray 15.6", Intel Core i7 1165G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 96EUs 1920x1080px',
#   'price_tag_symbol': '$',
#   'product_price_number': '199.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '77',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-v-series-v15-g2-itl-iron-gray-156-intel-core-i7-1165g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-96eus-1920x1080px/p/MLA18717227?pdp_filters=category:MLA1652#searchVariation=MLA18717227&position=42&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  210: {'product_name': 'Notebook gamer MSI Thin GF63 negra 15.6", Intel Core i5 9300H  8GB de RAM 256GB SSD, NVIDIA GeForce GTX 1650 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '217.899',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '55',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-gamer-msi-thin-gf63-negra-156-intel-core-i5-9300h-8gb-de-ram-256gb-ssd-nvidia-geforce-gtx-1650-1920x1080px-windows-10-home/p/MLA15279469?pdp_filters=category:MLA1652#searchVariation=MLA15279469&position=43&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  211: {'product_name': 'Notebook Dell Inspiron 3505 gris 15.6", AMD Ryzen 5 3450U  16GB de RAM 256GB SSD, AMD Radeon RX Vega 8 (Ryzen 2000/3000) 60 Hz 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '284.599',
#   'product_discount': '34% OFF',
#   'product_cuotas': 'Hasta 6 cuotas sin interés',
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '1033',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3505-gris-156-amd-ryzen-5-3450u-16gb-de-ram-256gb-ssd-amd-radeon-rx-vega-8-ryzen-20003000-60-hz-1366x768px-windows-10-home/p/MLA16999018?pdp_filters=category:MLA1652#searchVariation=MLA16999018&position=44&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  212: {'product_name': 'Notebook Asus VivoBook F512DA plata 15.6", AMD Ryzen 3 3200U  4GB de RAM 128GB SSD, AMD Radeon RX Vega 3 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '149.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '208',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-vivobook-f512da-plata-156-amd-ryzen-3-3200u-4gb-de-ram-128gb-ssd-amd-radeon-rx-vega-3-1920x1080px-windows-10-home/p/MLA15248658?pdp_filters=category:MLA1652#searchVariation=MLA15248658&position=45&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  213: {'product_name': 'Notebook Hp Amd Ryzen 7 5700u 12gb 256gb Ssd 15.6  Touchscreen Tactil Windows 11 (15-ef2081ms)',
#   'price_tag_symbol': '$',
#   'product_price_number': '194.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '8',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-amd-ryzen-7-5700u-12gb-256gb-ssd-156-touchscreen-tactil-windows-11-15-ef2081ms/p/MLA19569670?pdp_filters=category:MLA1652#searchVariation=MLA19569670&position=46&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  214: {'product_name': 'Notebook Asus Vivobook X712JA plata 17.3", Intel Core i7 1065G7  16GB de RAM 1 TB SSD, Intel Iris Plus Graphics G7 1600x900px Windows Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '359.998',
#   'product_discount': '17% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '35',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-vivobook-x712ja-plata-173-intel-core-i7-1065g7-16gb-de-ram-1-tb-ssd-intel-iris-plus-graphics-g7-1600x900px-windows-home/p/MLA18519896?pdp_filters=category:MLA1652#searchVariation=MLA18519896&position=47&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  215: {'product_name': 'Notebook Noblex 15.6” Full HD Intel Core i3 4GB/256GB SSD',
#   'price_tag_symbol': '$',
#   'product_price_number': '104.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '72',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-noblex-156-full-hd-intel-core-i3-4gb256gb-ssd/p/MLA18547225?pdp_filters=category:MLA1652#searchVariation=MLA18547225&position=48&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  216: {'product_name': 'Notebook Asus VivoBook F415EA slate gray 14", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 60 Hz 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '169.828',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '32',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-vivobook-f415ea-slate-gray-14-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-60-hz-1920x1080px-windows-10-home/p/MLA18927766?pdp_filters=category:MLA1652#searchVariation=MLA18927766&position=49&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  217: {'product_name': 'Notebook HP 14-dq2055wm silver 14", Intel Core i3 1115G4  4GB de RAM 256GB SSD, Intel UHD Graphics Xe G4 48EUs 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '111.880',
#   'product_discount': '10% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '64',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-hp-14-dq2055wm-silver-14-intel-core-i3-1115g4-4gb-de-ram-256gb-ssd-intel-uhd-graphics-xe-g4-48eus-1920x1080px-windows-10-home/p/MLA18648554?pdp_filters=category:MLA1652#searchVariation=MLA18648554&position=50&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  218: {'product_name': 'Notebook Dell Inspiron 3515 plateada 15.5", AMD Ryzen 5 3450U  16GB de RAM 1TB HDD 256GB SSD, AMD Radeon RX Vega 8 (Ryzen 2000/3000) 1366x768px Windows 11 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '204.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '185',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-dell-inspiron-3515-plateada-155-amd-ryzen-5-3450u-16gb-de-ram-1tb-hdd-256gb-ssd-amd-radeon-rx-vega-8-ryzen-20003000-1366x768px-windows-11-home/p/MLA19472483?pdp_filters=category:MLA1652#searchVariation=MLA19472483&position=51&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  219: {'product_name': 'Notebook Lenovo IdeaPad 15ALC6  arctic gray 15.6", AMD Ryzen 5 5500U  8GB de RAM 256GB SSD, AMD Radeon RX Vega 7 1920x1080px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '145.498',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '164',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-lenovo-ideapad-15alc6-arctic-gray-156-amd-ryzen-5-5500u-8gb-de-ram-256gb-ssd-amd-radeon-rx-vega-7-1920x1080px-windows-10-home/p/MLA18518417?pdp_filters=category:MLA1652#searchVariation=MLA18518417&position=52&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  220: {'product_name': 'Notebook Asus X515EA gris 15.6", Intel Core i5 1135G7  8GB de RAM 256GB SSD, Intel Iris Xe Graphics G7 80EUs 1920x1080px Windows 10',
#   'price_tag_symbol': '$',
#   'product_price_number': '159.999',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '879',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-asus-x515ea-gris-156-intel-core-i5-1135g7-8gb-de-ram-256gb-ssd-intel-iris-xe-graphics-g7-80eus-1920x1080px-windows-10/p/MLA18554118?pdp_filters=category:MLA1652#searchVariation=MLA18554118&position=53&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  221: {'product_name': 'Notebook Enova Intel Celeron 4gb 128gb W10',
#   'price_tag_symbol': '$',
#   'product_price_number': '71.999',
#   'product_discount': '12% OFF',
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '53',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-enova-intel-celeron-4gb-128gb-w10/p/MLA19435091?pdp_filters=category:MLA1652#searchVariation=MLA19435091&position=54&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  222: {'product_name': 'Apple Macbook Air (13 pulgadas, 2020, Chip M1, 256 GB de SSD, 8 GB de RAM) - Oro',
#   'price_tag_symbol': '$',
#   'product_price_number': '289.499',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '486',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/apple-macbook-air-13-pulgadas-2020-chip-m1-256-gb-de-ssd-8-gb-de-ram-oro/p/MLA17828522?pdp_filters=category:MLA1652#searchVariation=MLA17828522&position=55&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'},
#  223: {'product_name': 'Notebook Banghó Max L5 i7 gris oscura 15.6", Intel Core i7 10510U  8GB de RAM 480GB SSD, Intel Graphics UHD 620 1366x768px Windows 10 Home',
#   'price_tag_symbol': '$',
#   'product_price_number': '172.990',
#   'product_discount': None,
#   'product_cuotas': None,
#   'product_shipping': 'Envío gratis',
#   'product_reviews': '220',
#   'product_seller': None,
#   'product_link': 'https://www.mercadolibre.com.ar/notebook-bangho-max-l5-i7-gris-oscura-156-intel-core-i7-10510u-8gb-de-ram-480gb-ssd-intel-graphics-uhd-620-1366x768px-windows-10-home/p/MLA18259066?pdp_filters=category:MLA1652#searchVariation=MLA18259066&position=56&search_layout=stack&type=product&tracking_id=dc241f19-caed-4e55-9c7d-ba3b40b75737'}}

# %%
# Creamos un dataframe a partir de un dict. Tenemos que aplicar transpose para que cambie filas por columnas 
df = pd.DataFrame(dict).transpose()

# %%
df
# Out:
#                                           product_name price_tag_symbol  \
# 0    Notebook EXO Smart T33 gris 14", Intel Celeron...                $
# 1    Notebook EXO Smart M33 gris 14.1", Intel Celer...                $
# 2    Notebook Dell Inspiron 3515 plateada 15.5", AM...                $
# 3    Notebook Lenovo 15,6  Amd Ryzen 5 5500u 8gb 25...                $
# 4    Notebook Dell Inspiron 3515 azul 15.5", AMD Ry...                $
# ..                                                 ...              ...
# 219  Notebook Lenovo IdeaPad 15ALC6  arctic gray 15...                $
# 220  Notebook Asus X515EA gris 15.6", Intel Core i5...                $
# 221         Notebook Enova Intel Celeron 4gb 128gb W10                $
# 222  Apple Macbook Air (13 pulgadas, 2020, Chip M1,...                $
# 223  Notebook Banghó Max L5 i7 gris oscura 15.6", I...                $
#
#     product_price_number product_discount               product_cuotas  \
# 0                 75.000          13% OFF                         None
# 1                108.999          25% OFF  Hasta 12 cuotas sin interés
# 2                169.999           7% OFF   Hasta 6 cuotas sin interés
# 3                149.999           9% OFF                         None
# 4                199.999             None                         None
# ..                   ...              ...                          ...
# 219              145.498             None                         None
# 220              159.999             None                         None
# 221               71.999          12% OFF                         None
# 222              289.499             None                         None
# 223              172.990             None                         None
#
#     product_shipping product_reviews   product_seller  \
# 0       Envío gratis              22             None
# 1       Envío gratis              58  Vendido por EXO
# 2       Envío gratis             185             None
# 3       Envío gratis            None             None
# 4       Envío gratis             185             None
# ..               ...             ...              ...
# 219     Envío gratis             164             None
# 220     Envío gratis             879             None
# 221     Envío gratis              53             None
# 222     Envío gratis             486             None
# 223     Envío gratis             220             None
#
#                                           product_link
# 0    https://www.mercadolibre.com.ar/notebook-exo-s...
# 1    https://www.mercadolibre.com.ar/notebook-exo-s...
# 2    https://www.mercadolibre.com.ar/notebook-dell-...
# 3    https://www.mercadolibre.com.ar/notebook-lenov...
# 4    https://www.mercadolibre.com.ar/notebook-dell-...
# ..                                                 ...
# 219  https://www.mercadolibre.com.ar/notebook-lenov...
# 220  https://www.mercadolibre.com.ar/notebook-asus-...
# 221  https://www.mercadolibre.com.ar/notebook-enova...
# 222  https://www.mercadolibre.com.ar/apple-macbook-...
# 223  https://www.mercadolibre.com.ar/notebook-bangh...
#
# [224 rows x 9 columns]

# %% [markdown]
# ## Scrappeamos página por página

# %%
# Función de request. Vamos a llamarla cuando se necesite cambiar de página. Sólo le pasamos la URL

def request_url(url):
    html = requests.get(url.strip(), headers={'User-Agent': 'Mozilla/5.0'}).text
    soup = BeautifulSoup(html, "lxml")
    return soup

# %%
dict = {}
i = 0

# identificador de página en la url de MercadoLibre
pages = [1, 51, 101, 151, 201, 251, 301]

# La única diferencia respecto al anterior, es que ahora creamos un bucle por encima para que cargue una nuevapágina
# una vez que obtuvo la información de todos los productos de un página.
for page in pages:
    
    url = 'https://listado.mercadolibre.com.ar/computacion/laptops-accesorios/notebooks/notebook_Desde_' + str(page) + '_NoIndex_True' 
    soup = request_url(url)
    
    item_list = soup.find_all('div', class_="ui-search-result__content-wrapper shops__result-content-wrapper")
    
    for item in item_list:
        product_name = item.find('h2')
        product_price_symbol = item.find('span', {'class' : 'price-tag-symbol'})
        product_price_number = item.find('span', {'class' : 'price-tag-fraction'})
        product_discount = item.find('span', {'class' : 'ui-search-price__discount shops__price-discount'})
        product_cuotas = item.find('span', {'class' : 'ui-search-item__group__element shops__items-group-details ui-search-installments ui-search-color--LIGHT_GREEN'})
        product_shipping = item.find('p', {'class' : 'ui-search-item__shipping ui-search-item__shipping--free shops__item-shipping-free'})
        product_reviews = item.find('span', {'class' : 'ui-search-reviews__amount'})
        product_seller = item.find('p', {'class' : 'ui-search-official-store-label ui-search-item__group__element shops__items-group-details ui-search-color--GRAY'})
        product_label = item.find('label', {'class': 'ui-search-styled-label ui-search-item__highlight-label__text'})
        product_link = item.find('a').get('href')
        product_old_price = item.find('span', {'class':'price-tag-text-sr-only'})
        product_name = product_name.text

    #     If find_all() can’t find anything, it returns an empty list. If find() can’t find anything, it returns None

    #   .text is just a property that calls get_text. Therefore, calling get_text without arguments is 
    #   the same thing as .text. However, get_text can also support various keyword arguments to change how 
    #   it behaves (separator, strip, types). If you need more control over the result, 
    #   then you need the functional form.

        if product_price_symbol is not None:
            product_price_symbol = product_price_symbol.get_text()
        if product_price_number is not None:
            product_price_number = product_price_number.get_text()
        if product_discount is not None:
            product_discount = product_discount.get_text()
        if product_cuotas is not None:
            product_cuotas = product_cuotas.get_text()
        if product_shipping is not None:
            product_shipping = product_shipping.get_text()
        if product_reviews is not None:
            product_reviews = product_reviews.get_text()
        if product_seller is not None:
            product_seller = product_seller.get_text()
        if product_label is not None:
            product_label = product_label.get_text()
        if product_old_price is not None:
            product_old_price = product_old_price.get_text()
            

        dict.update({i:{
            'product_name': product_name,
            'price_tag_symbol': product_price_symbol,
            'product_price_number': product_price_number,
            'product_label': product_label,
            'product_old_price':product_old_price,
            'product_discount': product_discount,
            'product_cuotas': product_cuotas,
            'product_shipping': product_shipping,
            'product_reviews': product_reviews,
            'product_seller': product_seller,
            'product_link': product_link
        }})

        i= i + 1

# %%
df = pd.DataFrame(dict).transpose()

# %%
df
# Out:
#                                           product_name price_tag_symbol  \
# 0    Notebook HP 14-dq2029la plata natural 14", Int...                $
# 1    Notebook EXO Smart M33 gris 14.1", Intel Celer...                $
# 2    Notebook EXO Smart T33 gris 14", Intel Celeron...                $
# 3    Notebook Dell Inspiron 3515 plateada 15.5", AM...                $
# 4    Notebook Lenovo IdeaPad 14IIL05  platinum gray...                $
# ..                                                 ...              ...
# 381  Notebook Hp Amd Ryzen 5 5500 8gb 256gb Ssd 15....                $
# 382  Notebook Xpg Xenia I7 11800h 32gb 1tb Rtx 3070...                $
# 383  Notebook HP 240 G7 plateado ceniza oscuro 14",...                $
# 384  Notebook Asus Core I5 X515 11° 12gb 15.6 500gb...                $
# 385  Notebook Hp 240 G8 Intel Core I5 10ma 8gb 256g...                $
#
#     product_price_number   product_label    product_old_price  \
# 0                179.999            None         179999 pesos
# 1                108.999  OFERTA DEL DÍA  Antes: 108999 pesos
# 2                 75.000  OFERTA DEL DÍA   Antes: 75000 pesos
# 3                169.999            None  Antes: 169999 pesos
# 4                149.999            None         149999 pesos
# ..                   ...             ...                  ...
# 381              179.990            None         179990 pesos
# 382              487.026            None         487026 pesos
# 383              123.999            None         123999 pesos
# 384              187.999            None         187999 pesos
# 385              148.999            None         148999 pesos
#
#     product_discount               product_cuotas product_shipping  \
# 0               None   Hasta 6 cuotas sin interés             None
# 1            25% OFF  Hasta 12 cuotas sin interés     Envío gratis
# 2            13% OFF                         None             None
# 3             7% OFF   Hasta 6 cuotas sin interés             None
# 4               None                         None             None
# ..               ...                          ...              ...
# 381             None   Hasta 6 cuotas sin interés     Envío gratis
# 382             None                         None     Envío gratis
# 383             None                         None     Envío gratis
# 384             None                         None     Envío gratis
# 385             None                         None     Envío gratis
#
#     product_reviews                 product_seller  \
# 0               119  Vendido por HP Tienda Oficial
# 1                58                Vendido por EXO
# 2                22                           None
# 3               185                           None
# 4               525                           None
# ..              ...                            ...
# 381            None                           None
# 382            None                           None
# 383            1718                           None
# 384            None                           None
# 385            None                           None
#
#                                           product_link
# 0    https://click1.mercadolibre.com.ar/mclics/clic...
# 1    https://click1.mercadolibre.com.ar/mclics/clic...
# 2    https://www.mercadolibre.com.ar/notebook-exo-s...
# 3    https://www.mercadolibre.com.ar/notebook-dell-...
# 4    https://www.mercadolibre.com.ar/notebook-lenov...
# ..                                                 ...
# 381  https://articulo.mercadolibre.com.ar/MLA-11264...
# 382  https://articulo.mercadolibre.com.ar/MLA-11440...
# 383  https://www.mercadolibre.com.ar/notebook-hp-24...
# 384  https://articulo.mercadolibre.com.ar/MLA-11142...
# 385  https://articulo.mercadolibre.com.ar/MLA-11339...
#
# [386 rows x 11 columns]
