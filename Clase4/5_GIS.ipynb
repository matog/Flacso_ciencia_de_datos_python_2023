# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/matog/Flacso_ciencia_de_datos_python_2022/blob/main/Clase4/5%20-%20GIS.ipynb)

# %% [markdown]
# # GIS con GEOPANDAS

# %% [markdown]
# https://www.ign.gob.ar/NuestrasActividades/InformacionGeoespacial/CapasSIG

# %% [markdown]
# Intro a sistemas de coordenadas y proyecciones:
# - [Video](https://www.youtube.com/watch?v=mNG2vIBs7bU)
# - [ArcGis](https://pro.arcgis.com/es/pro-app/latest/help/mapping/properties/coordinate-systems-and-projections.htm)
# - [MappingGis](https://mappinggis.com/2022/02/diferencias-entre-los-sistemas-de-coordenadas-geograficas-y-proyectadas/)

# %% [markdown]
# ### Carga de módulos

# %%
# Librerias necesarias para librerías de goepython
# !apt install gdal-bin python-gdal python3-gdal gdal-bin
# Instalamos rtree (requerimiento de Geopandas)
# !apt install python3-rtree 
# Instalamos Geopandas desde el repositorio, para tomar la última versión
# !pip install git+git://github.com/geopandas/geopandas.git
# !pip install geopandas
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package python-gdal is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
# However the following packages replace it:
#   gdal-bin
#
# E: Package 'python-gdal' has no installation candidate
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3-rtree is already the newest version (0.9.4-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.5.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from munch>=2.3.2->fiona>=1.8.19->geopandas) (1.16.0)

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# Geopandas (http://geopandas.org/) hace posible trabajar con información geospacial en python de una forma relativamente sencilla. Combina la capacidad de analisis de Pandas con la de otros paquetes como shapely, para manegar información espacial.
#
# Las estructuras de datos mas importantes en geopandas son las GeoSeries y los GeoDataframe, que extienda las posibildades de las Series y los DataFrames de pandas. Esto significa que podemos usar todos nuestros skills de pandas incluso cuando trabajamos con geopandas!
#
# La diferencia entre el geodataframe y el dataframe es que el geodataframe debe contener una columna para guardar las geometrias. Por defecto, el nombre de la columna es 'geometry'. Esta columna es una geoserie que contiene las geometrias (puntos, lineas, poligonos, multipoligonoes, etc) como objetos de shapely.
#
# La carga es similar a un dataframe, con el comando `.read_file`.

# %%
# Departamentos de Argentina
gdf_depart = gpd.read_file('https://github.com/matog/Flacso_ciencia_de_datos_python_2023/raw/main/Clase4/data/departamento.zip')
# Limites provinciales
gdf_prov = gpd.read_file('https://github.com/matog/Flacso_ciencia_de_datos_python_2023/raw/main/Clase4/data/provincia.zip')

# %%
type(gdf_depart)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf_prov
# Out:
#     gid  entidad     objeto  \
# 0     1      0.0  Provincia
# 1     2      0.0  Provincia
# 2     3      0.0  Provincia
# 3     4      0.0  Provincia
# 4     5      0.0  Provincia
# 5     6      0.0  Provincia
# 6     7      0.0  Provincia
# 7     8      0.0  Provincia
# 8     9      0.0  Provincia
# 9    10      0.0  Provincia
# 10   11      0.0  Provincia
# 11   12      0.0  Provincia
# 12   13      0.0  Provincia
# 13   14      0.0  Provincia
# 14   15      0.0  Provincia
# 15   16      0.0  Provincia
# 16   17      0.0  Provincia
# 17   18      0.0  Provincia
# 18   19      0.0  Provincia
# 19   20      0.0  Provincia
# 20   21      0.0  Provincia
# 21   22      0.0  Provincia
# 22   23      0.0  Provincia
# 23   24      0.0  Provincia
#
#                                                   fna              gna  \
# 0                     Ciudad Autónoma de Buenos Aires  Ciudad Autónoma
# 1                               Provincia del Neuquén        Provincia
# 2                               Provincia de San Luis        Provincia
# 3                               Provincia de Santa Fe        Provincia
# 4                               Provincia de La Rioja        Provincia
# 5                              Provincia de Catamarca        Provincia
# 6                                Provincia de Tucumán        Provincia
# 7                                 Provincia del Chaco        Provincia
# 8                                Provincia de Formosa        Provincia
# 9                             Provincia de Santa Cruz        Provincia
# 10                               Provincia del Chubut        Provincia
# 11                               Provincia de Mendoza        Provincia
# 12                               Provincia de Córdoba        Provincia
# 13                            Provincia de Entre Ríos        Provincia
# 14                              Provincia de San Juan        Provincia
# 15                                 Provincia de Jujuy        Provincia
# 16                   Provincia de Santiago del Estero        Provincia
# 17                             Provincia de Río Negro        Provincia
# 18                            Provincia de Corrientes        Provincia
# 19                              Provincia de Misiones        Provincia
# 20                                 Provincia de Salta        Provincia
# 21                              Provincia de La Pampa        Provincia
# 22  Provincia de Tierra del Fuego, Antártida e Isl...        Provincia
# 23                          Provincia de Buenos Aires        Provincia
#
#                                                   nam in1        fdc  sag  \
# 0                     Ciudad Autónoma de Buenos Aires  02  Geografía  IGN
# 1                                             Neuquén  58  Geografía  IGN
# 2                                            San Luis  74  Geografía  IGN
# 3                                            Santa Fe  82  Geografía  IGN
# 4                                            La Rioja  46  Geografía  IGN
# 5                                           Catamarca  10  Geografía  IGN
# 6                                             Tucumán  90  Geografía  IGN
# 7                                               Chaco  22  Geografía  IGN
# 8                                             Formosa  34  Geografía  IGN
# 9                                          Santa Cruz  78  Geografía  IGN
# 10                                             Chubut  26  Geografía  IGN
# 11                                            Mendoza  50  Geografía  IGN
# 12                                            Córdoba  14  Geografía  IGN
# 13                                         Entre Ríos  30  Geografía  IGN
# 14                                           San Juan  70  Geografía  IGN
# 15                                              Jujuy  38  Geografía  IGN
# 16                                Santiago del Estero  86  Geografía  IGN
# 17                                          Río Negro  62  Geografía  IGN
# 18                                         Corrientes  18  Geografía  IGN
# 19                                           Misiones  54  Geografía  IGN
# 20                                              Salta  66  Geografía  IGN
# 21                                           La Pampa  42  Geografía  IGN
# 22  Tierra del Fuego, Antártida e Islas del Atlánt...  94  Geografía  IGN
# 23                                       Buenos Aires  06  Geografía  IGN
#
#                                              geometry
# 0   MULTIPOLYGON (((-58.34189 -34.63110, -58.34240...
# 1   MULTIPOLYGON (((-68.25000 -37.57478, -68.25000...
# 2   MULTIPOLYGON (((-66.66179 -31.92054, -66.60454...
# 3   MULTIPOLYGON (((-58.88082 -28.06682, -58.88360...
# 4   MULTIPOLYGON (((-65.42299 -30.11960, -65.49056...
# 5   MULTIPOLYGON (((-66.09976 -26.22049, -66.10088...
# 6   MULTIPOLYGON (((-64.49532 -26.21937, -64.49723...
# 7   MULTIPOLYGON (((-58.37735 -26.87223, -58.37764...
# 8   MULTIPOLYGON (((-58.37735 -26.87223, -58.37935...
# 9   MULTIPOLYGON (((-71.54709 -45.99975, -71.54573...
# 10  MULTIPOLYGON (((-70.99068 -41.99996, -70.20898...
# 11  MULTIPOLYGON (((-67.31774 -32.38203, -67.31763...
# 12  MULTIPOLYGON (((-62.13060 -30.47993, -62.10369...
# 13  MULTIPOLYGON (((-59.72664 -33.60389, -59.72830...
# 14  MULTIPOLYGON (((-69.62981 -28.39369, -69.62956...
# 15  MULTIPOLYGON (((-65.18657 -22.08535, -65.18670...
# 16  MULTIPOLYGON (((-61.71126 -27.99942, -61.71135...
# 17  MULTIPOLYGON (((-68.23910 -37.58496, -68.23829...
# 18  MULTIPOLYGON (((-57.97099 -27.27499, -57.96509...
# 19  MULTIPOLYGON (((-55.83511 -27.41013, -55.83220...
# 20  MULTIPOLYGON (((-62.34230 -22.46084, -62.34230...
# 21  MULTIPOLYGON (((-63.38575 -35.00013, -63.38597...
# 22  MULTIPOLYGON (((-25.00000 -75.87687, -25.00000...
# 23  MULTIPOLYGON (((-62.15339 -40.45148, -62.15339...

# %%
# gdf_prov.loc[gdf_prov['fna'].str.contains('Provincia')]
# # gdf_prov.plot()

# %% [markdown]
# ### Geopandas Atributos

# %% [markdown]
#     - area: superficie (en unidades de la proyección, ver https://geopandas.org/en/stable/docs/user_guide/projections.html)
#     - bounds: tupla de las coordinadas max y min de cada eje
#     - total_bounds: tupla de coordinadas max y min en cada eje, para el total de la geoserie
#     - geom_type: tipo de geometría.
#     - is_valid: testea si las coordinadsa forman una figura qeu es una figura geométrica razonable (de acuerdo a https://www.ogc.org/standards/sfa)

# %%
gdf_prov.loc[gdf_prov['nam'] == 'Catamarca'].is_valid
# Out:
# 5    True
# dtype: bool

# %%
gdf_prov.loc[gdf_prov['nam'] == 'Catamarca'].is_valid
# Out:
# 5    True
# dtype: bool

# %% [markdown]
# ### Geopandas Métodos:

# %% [markdown]
#     - distance(): Devuelve una serie con la distancia mínima entre cada registro
#     - centroid: devuelve una GeoSeries de centroides
#     - representative_point(): devuelve una GeoSeries con puntos que se encuentran dentro de cada geometria. No devuelve centroides.
#     - to_crs(): cambia el sistema de coordenadas
#     - plot(): Grafica la geoserie.

# %%
gdf_prov.loc[gdf_prov['nam'] == 'Catamarca'].centroid
# Out:
# <ipython-input-25-8808915dbbe2>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_prov.loc[gdf_prov['nam'] == 'Catamarca'].centroid
# 5    POINT (-66.94769 -27.33589)
# dtype: geometry

# %% [markdown]
# Vamos a intentar graficar un mapa [coropletico](https://es.wikipedia.org/wiki/Mapa_coropl%C3%A9tico), con la población 2010 de los departamentos de la provincia de Mendoza.
#
# Mas arriba en este notebook cargamos los departamentos de toda la Argentina. Vamos a quedarnos solo con los de Mendoza

# %%
gdf_depart
# Out:
#      gid        objeto                            fna           gna  \
# 0      2  Departamento           Departamento Federal  Departamento
# 1      3  Departamento      Departamento Gualeguaychú  Departamento
# 2      4  Departamento  Departamento Islas del Ibicuy  Departamento
# 3      5  Departamento          Departamento Victoria  Departamento
# 4      6  Departamento          Departamento Diamante  Departamento
# ..   ...           ...                            ...           ...
# 524  502  Departamento           Departamento Iglesia  Departamento
# 525  503  Departamento            Departamento Jáchal  Departamento
# 526  504  Departamento      Departamento Valle Fértil  Departamento
# 527  505  Departamento            Partido de La Plata       Partido
# 528  506  Departamento          Departamento Mercedes  Departamento
#
#                   nam    in1                                       fdc  sag  \
# 0             Federal  30035                 ATER - Direc. de Catastro  IGN
# 1        Gualeguaychú  30056                 ATER - Direc. de Catastro  IGN
# 2    Islas del Ibicuy  30063                 ATER - Direc. de Catastro  IGN
# 3            Victoria  30105                 ATER - Direc. de Catastro  IGN
# 4            Diamante  30021                 ATER - Direc. de Catastro  IGN
# ..                ...    ...                                       ...  ...
# 524           Iglesia  70049                        Direc. de Catastro  IGN
# 525            Jáchal  70056                        Direc. de Catastro  IGN
# 526      Valle Fértil  70119                        Direc. de Catastro  IGN
# 527          La Plata  06441  ARBA - Gerencia de Servicios Catastrales  IGN
# 528          Mercedes  18105                                       IGN  IGN
#
#                                               geometry
# 0    MULTIPOLYGON (((-58.57731 -30.69016, -58.57512...
# 1    MULTIPOLYGON (((-58.13011 -33.02912, -58.13087...
# 2    MULTIPOLYGON (((-58.57589 -34.02675, -58.57593...
# 3    MULTIPOLYGON (((-59.77158 -32.58791, -59.77198...
# 4    MULTIPOLYGON (((-60.25784 -32.05170, -60.25723...
# ..                                                 ...
# 524  MULTIPOLYGON (((-69.62981 -28.39369, -69.62956...
# 525  MULTIPOLYGON (((-68.25879 -29.74673, -68.26262...
# 526  MULTIPOLYGON (((-67.99199 -29.97924, -67.99151...
# 527  MULTIPOLYGON (((-57.99667 -34.87535, -57.99087...
# 528  MULTIPOLYGON (((-57.17516 -28.57960, -57.17528...
#
# [529 rows x 9 columns]

# %%
gdf_mendoza = gdf_depart.loc[gdf_depart['fdc'] == 'IDE Mendoza']

# %%
plt.figure(figsize=(30,18))
gdf_mendoza.plot();

# %%
tables = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Municipios_de_la_provincia_de_Mendoza', encoding='utf-8')

# %%
type(tables)
# Out:
# list

# %%
tables[0]
# Out:
#                        Municipio (departamento)          Cabecera  \
# 0                                General Alvear    General Alvear
# 1                                    Godoy Cruz        Godoy Cruz
# 2                                    Guaymallén       Villa Nueva
# 3                                         Junín             Junín
# 4                                        La Paz            La Paz
# 5                                     Las Heras         Las Heras
# 6                                       Lavalle    Villa Tulumaya
# 7                                 Luján de Cuyo     Luján de Cuyo
# 8                                         Maipú             Maipú
# 9                                      Malargüe          Malargüe
# 10  Mendoza (municipio)/ Capital (departamento)           Mendoza
# 11                                    Rivadavia         Rivadavia
# 12                                   San Carlos  Villa San Carlos
# 13                                   San Martín        San Martín
# 14                                   San Rafael        San Rafael
# 15                                   Santa Rosa        Santa Rosa
# 16                                      Tunuyán           Tunuyán
# 17                                    Tupungato         Tupungato
#
#                    Fecha de creación del departamento  \
# 0              12 de agosto de 1914 (ley n.º 635)[5]​
# 1                                  11 de mayo de 1855
# 2                    14 de mayo de 1858 (decreto)[8]​
# 3                            18 de enero de 1859[10]​
# 4   18 de noviembre de 1855 (promulgación de la co...
# 5                       31 de enero de 1871 (decreto)
# 6                       18 de enero de 1859 (decreto)
# 7   18 de noviembre de 1855 (promulgación de la co...
# 8                                  14 de mayo de 1858
# 9                             16 de noviembre de 1850
# 10                            20 de diciembre de 1869
# 11          18 de abril de 1884 (sanción de ley)[22]​
# 12  18 de noviembre de 1855 (promulgación de la co...
# 13                                18 de enero de 1859
# 14                               2 de octubre de 1903
# 15   25 de febrero de 1885 (promulgación de ley)[26]​
# 16      30 de noviembre de 1880 (promulgación de ley)
# 17                   8 de noviembre de 1858 (decreto)
#
#                                                Origen  \
# 0             Con tierras del departamento San Rafael
# 1   Sus nombres anteriores fueron San Vicente y Be...
# 2                                                 NaN
# 3                                                 NaN
# 4            Es uno de los 4 departamentos originales
# 5                Con tierras del departamento Capital
# 6   Hasta 1889 su nombre fue Rosario de las Laguna...
# 7   Es uno de los 4 departamentos originales, con ...
# 8                                                 NaN
# 9             Con tierras del departamento San Rafael
# 10     Sus nombres anteriores fueron Ciudad y Mendoza
# 11  Con tierras de los departamentos Junín y San M...
# 12  Es uno de los 4 departamentos originales. Entr...
# 13                                                NaN
# 14                                                NaN
# 15  Por división del departamento Junín. Se llamó ...
# 16            Por división del departamento Tupungato
# 17           Por división del departamento San Carlos
#
#    Códigos INDEC: divisiones político-administrativas/ gobiernos locales[2]​[3]​  \
# 0                                        50014/500014
# 1                                        50021/500021
# 2                                        50028/500028
# 3                                        50035/500035
# 4                                        50042/500042
# 5                                        50049/500049
# 6                                        50056/500056
# 7                                        50063/500063
# 8                                        50070/500070
# 9                                        50077/500077
# 10                                       50007/500007
# 11                                       50084/500084
# 12                                       50091/500091
# 13                                       50098/500098
# 14                                       50105/500105
# 15                                       50112/500112
# 16                                       50119/500119
# 17                                       50126/500126
#
#    Población (2010)[4]​ Superficie (km²)  Densidad (hab./km²)       Distritos  \
# 0                46 429           14 448                 3.21               4
# 1               191 903               75              2558.71           9[7]​
# 2               283 803              164              1730.51              21
# 3                37 859              263               143.95              10
# 4                10 012             7105                 1.41               6
# 5               203 666             8955                22.74              14
# 6                36 738           10 212                 3.60              24
# 7               119 888             4847                24.73              15
# 8               172 332              617               279.31              12
# 9                27 660           41 317                 0.67               4
# 10              115 041               57              2018.26  12 (secciones)
# 11               56 373             2141                26.33              13
# 12               32 631           11 578                 2.82               6
# 13              118 220             1504                78.60              15
# 14              188 018           31 235                 6.02              18
# 15               16 374             8510                 1.92               6
# 16               49 458             3317                14.91              12
# 17               32 524             2485                13.09              13
#
#                              Delegaciones municipales  Mapa  \
# 0    * Alvear Oeste * Bowen * San Pedro del Atuel[6]​   NaN
# 1                                                 NaN   NaN
# 2   * Dorrego * Rodeo de la Cruz, Kilómetro 8 y Ki...   NaN
# 3   * La Colonia * Los Barriales * Medrano * Phill...   NaN
# 4                                                 NaN   NaN
# 5   * El Borbollón[12]​ * El Challao * El Algarrob...   NaN
# 6   * Alto del Olvido[14]​ (distritos: Alto del Ol...   NaN
# 7   * Agrelo * Cacheuta y Potrerillos * Carrodilla...   NaN
# 8   * Coquimbito[18]​ * Fray Luis Beltrán  * Gener...   NaN
# 9   * Agua Escondida (distrito Agua Escondida)[19]...   NaN
# 10                                                NaN   NaN
# 11                                        No hay[23]​   NaN
# 12  * Chilecito  * Eugenio Bustos * La Consulta  *...   NaN
# 13  * Montecaseros * Nueva California * Palmira * ...   NaN
# 14  * Cañada Seca * Cuadro Benegas * Cuadro Nacion...   NaN
# 15  * Doce de Octubre * El Marcado * La Dormida * ...   NaN
# 16  * Colonia Las Rosas * El Algarrobo * Los Árbol...   NaN
# 17                 * Cordón del Plata * San José[28]​   NaN
#
#    Número de concejales
# 0                    10
# 1                    12
# 2                    12
# 3                    10
# 4                    10
# 5                    12
# 6                    10
# 7               12[17]​
# 8                    12
# 9                    10
# 10              12[21]​
# 11                   10
# 12                   10
# 13                   12
# 14                   12
# 15                   10
# 16                   10
# 17                   10

# %%
table = tables[0]

# %%
table.rename(columns = {
                      'Municipio (departamento)': 'departamento',
                      'Población (2010)[4]​': 'poblacion_2010',
                      'Superficie (km²)': 'Superficie_km2', 
                      'Densidad (hab./km²)':'densidad',
                      'Distritos':'distritos',
                      'Número de concejales':'concejales'}, 
                inplace = True)

# %%
table.columns
# Out:
# Index(['departamento', 'Cabecera', 'Fecha de creación del departamento',
#        'Origen',
#        'Códigos INDEC: divisiones político-administrativas/ gobiernos locales[2]​[3]​',
#        'poblacion_2010', 'Superficie_km2', 'densidad', 'distritos',
#        'Delegaciones municipales', 'Mapa', 'concejales'],
#       dtype='object')

# %%
table = table[['departamento', 'poblacion_2010', 'Superficie_km2', 'densidad', 'distritos', 'concejales']]

# %%
gdf_mendoza = pd.merge(gdf_mendoza, 
               table,
               left_on = 'nam',
               right_on = 'departamento',
               how= 'left')

# %%
gdf_mendoza
# Out:
#     gid        objeto                          fna           gna  \
# 0   220  Departamento       Departamento Las Heras  Departamento
# 1   213  Departamento      Departamento San Carlos  Departamento
# 2   214  Departamento         Departamento Tunuyán  Departamento
# 3    92  Departamento       Departamento Tupungato  Departamento
# 4    52  Departamento      Departamento Santa Rosa  Departamento
# 5    53  Departamento       Departamento Rivadavia  Departamento
# 6    55  Departamento          Departamento La Paz  Departamento
# 7   111  Departamento  Departamento General Alvear  Departamento
# 8   113  Departamento      Departamento San Rafael  Departamento
# 9   215  Departamento   Departamento Luján de Cuyo  Departamento
# 10  221  Departamento         Departamento Lavalle  Departamento
# 11  222  Departamento        Departamento Malargüe  Departamento
# 12  337  Departamento      Departamento Godoy Cruz  Departamento
# 13  329  Departamento      Departamento Guaymallén  Departamento
# 14  334  Departamento           Departamento Maipú  Departamento
# 15  336  Departamento         Departamento Capital  Departamento
# 16  339  Departamento      Departamento San Martín  Departamento
# 17  340  Departamento           Departamento Junín  Departamento
#
#                nam    in1          fdc  sag  \
# 0        Las Heras  50049  IDE Mendoza  IGN
# 1       San Carlos  50091  IDE Mendoza  IGN
# 2          Tunuyán  50119  IDE Mendoza  IGN
# 3        Tupungato  50126  IDE Mendoza  IGN
# 4       Santa Rosa  50112  IDE Mendoza  IGN
# 5        Rivadavia  50084  IDE Mendoza  IGN
# 6           La Paz  50042  IDE Mendoza  IGN
# 7   General Alvear  50014  IDE Mendoza  IGN
# 8       San Rafael  50105  IDE Mendoza  IGN
# 9    Luján de Cuyo  50063  IDE Mendoza  IGN
# 10         Lavalle  50056  IDE Mendoza  IGN
# 11        Malargüe  50077  IDE Mendoza  IGN
# 12      Godoy Cruz  50021  IDE Mendoza  IGN
# 13      Guaymallén  50028  IDE Mendoza  IGN
# 14           Maipú  50070  IDE Mendoza  IGN
# 15         Capital  50007  IDE Mendoza  IGN
# 16      San Martín  50098  IDE Mendoza  IGN
# 17           Junín  50035  IDE Mendoza  IGN
#
#                                              geometry    departamento  \
# 0   MULTIPOLYGON (((-69.12645 -32.00191, -69.12570...       Las Heras
# 1   MULTIPOLYGON (((-68.45348 -34.21255, -68.45584...      San Carlos
# 2   MULTIPOLYGON (((-68.99859 -33.54164, -68.99862...         Tunuyán
# 3   MULTIPOLYGON (((-68.79835 -33.39054, -68.79835...       Tupungato
# 4   MULTIPOLYGON (((-67.95776 -32.84504, -67.95774...      Santa Rosa
# 5   MULTIPOLYGON (((-68.28922 -33.23243, -68.29025...       Rivadavia
# 6   MULTIPOLYGON (((-67.17696 -33.07321, -67.17605...          La Paz
# 7   MULTIPOLYGON (((-66.75741 -34.51179, -66.75688...  General Alvear
# 8   MULTIPOLYGON (((-66.77655 -34.29767, -66.77665...      San Rafael
# 9   MULTIPOLYGON (((-68.86869 -32.96118, -68.86828...   Luján de Cuyo
# 10  MULTIPOLYGON (((-67.31774 -32.38203, -67.31763...         Lavalle
# 11  MULTIPOLYGON (((-68.27123 -35.99955, -68.29615...        Malargüe
# 12  MULTIPOLYGON (((-68.83759 -32.90452, -68.83808...      Godoy Cruz
# 13  MULTIPOLYGON (((-68.65114 -32.85840, -68.65113...      Guaymallén
# 14  MULTIPOLYGON (((-68.45615 -32.86930, -68.45716...           Maipú
# 15  MULTIPOLYGON (((-68.82047 -32.87394, -68.82549...             NaN
# 16  MULTIPOLYGON (((-67.95776 -32.84504, -68.12220...      San Martín
# 17  MULTIPOLYGON (((-68.28781 -33.18864, -68.28871...           Junín
#
#    poblacion_2010 Superficie_km2  densidad distritos concejales
# 0         203 666           8955     22.74        14         12
# 1          32 631         11 578      2.82         6         10
# 2          49 458           3317     14.91        12         10
# 3          32 524           2485     13.09        13         10
# 4          16 374           8510      1.92         6         10
# 5          56 373           2141     26.33        13         10
# 6          10 012           7105      1.41         6         10
# 7          46 429         14 448      3.21         4         10
# 8         188 018         31 235      6.02        18         12
# 9         119 888           4847     24.73        15    12[17]​
# 10         36 738         10 212      3.60        24         10
# 11         27 660         41 317      0.67         4         10
# 12        191 903             75   2558.71     9[7]​         12
# 13        283 803            164   1730.51        21         12
# 14        172 332            617    279.31        12         12
# 15            NaN            NaN       NaN       NaN        NaN
# 16        118 220           1504     78.60        15         12
# 17         37 859            263    143.95        10         10

# %%
gdf_mendoza.loc[gdf_mendoza['departamento'].isna()]
# Out:
#     gid        objeto                   fna           gna      nam    in1  \
# 15  336  Departamento  Departamento Capital  Departamento  Capital  50007
#
#             fdc  sag                                           geometry  \
# 15  IDE Mendoza  IGN  MULTIPOLYGON (((-68.82047 -32.87394, -68.82549...
#
#    departamento poblacion_2010 Superficie_km2  densidad distritos concejales
# 15          NaN            NaN            NaN       NaN       NaN        NaN

# %%
table.loc[table['departamento'] == 'Mendoza (municipio)/ Capital (departamento)' , 'departamento'] = 'Capital'

# %%
gdf_mendoza.columns
# Out:
# Index(['gid', 'objeto', 'fna', 'gna', 'nam', 'in1', 'fdc', 'sag', 'geometry',
#        'departamento', 'poblacion_2010', 'Superficie_km2', 'densidad',
#        'distritos', 'concejales'],
#       dtype='object')

# %%
# gdf_mendoza = gdf_mendoza[['gid', 'nam', 'geometry','poblacion_2010', 'Superficie_km2', 'densidad',
#        'distritos', 'concejales']]
gdf_mendoza = gdf_mendoza[['gid', 'nam', 'geometry']]

# %%
gdf_mendoza = pd.merge(gdf_mendoza, 
               table,
               left_on = 'nam',
               right_on = 'departamento',
               how= 'left')

# %%
gdf_mendoza
# Out:
#     gid             nam                                           geometry  \
# 0   220       Las Heras  MULTIPOLYGON (((-69.12645 -32.00191, -69.12570...
# 1   213      San Carlos  MULTIPOLYGON (((-68.45348 -34.21255, -68.45584...
# 2   214         Tunuyán  MULTIPOLYGON (((-68.99859 -33.54164, -68.99862...
# 3    92       Tupungato  MULTIPOLYGON (((-68.79835 -33.39054, -68.79835...
# 4    52      Santa Rosa  MULTIPOLYGON (((-67.95776 -32.84504, -67.95774...
# 5    53       Rivadavia  MULTIPOLYGON (((-68.28922 -33.23243, -68.29025...
# 6    55          La Paz  MULTIPOLYGON (((-67.17696 -33.07321, -67.17605...
# 7   111  General Alvear  MULTIPOLYGON (((-66.75741 -34.51179, -66.75688...
# 8   113      San Rafael  MULTIPOLYGON (((-66.77655 -34.29767, -66.77665...
# 9   215   Luján de Cuyo  MULTIPOLYGON (((-68.86869 -32.96118, -68.86828...
# 10  221         Lavalle  MULTIPOLYGON (((-67.31774 -32.38203, -67.31763...
# 11  222        Malargüe  MULTIPOLYGON (((-68.27123 -35.99955, -68.29615...
# 12  337      Godoy Cruz  MULTIPOLYGON (((-68.83759 -32.90452, -68.83808...
# 13  329      Guaymallén  MULTIPOLYGON (((-68.65114 -32.85840, -68.65113...
# 14  334           Maipú  MULTIPOLYGON (((-68.45615 -32.86930, -68.45716...
# 15  336         Capital  MULTIPOLYGON (((-68.82047 -32.87394, -68.82549...
# 16  339      San Martín  MULTIPOLYGON (((-67.95776 -32.84504, -68.12220...
# 17  340           Junín  MULTIPOLYGON (((-68.28781 -33.18864, -68.28871...
#
#       departamento poblacion_2010 Superficie_km2  densidad       distritos  \
# 0        Las Heras        203 666           8955     22.74              14
# 1       San Carlos         32 631         11 578      2.82               6
# 2          Tunuyán         49 458           3317     14.91              12
# 3        Tupungato         32 524           2485     13.09              13
# 4       Santa Rosa         16 374           8510      1.92               6
# 5        Rivadavia         56 373           2141     26.33              13
# 6           La Paz         10 012           7105      1.41               6
# 7   General Alvear         46 429         14 448      3.21               4
# 8       San Rafael        188 018         31 235      6.02              18
# 9    Luján de Cuyo        119 888           4847     24.73              15
# 10         Lavalle         36 738         10 212      3.60              24
# 11        Malargüe         27 660         41 317      0.67               4
# 12      Godoy Cruz        191 903             75   2558.71           9[7]​
# 13      Guaymallén        283 803            164   1730.51              21
# 14           Maipú        172 332            617    279.31              12
# 15         Capital        115 041             57   2018.26  12 (secciones)
# 16      San Martín        118 220           1504     78.60              15
# 17           Junín         37 859            263    143.95              10
#
#    concejales
# 0          12
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          12
# 9     12[17]​
# 10         10
# 11         10
# 12         12
# 13         12
# 14         12
# 15    12[21]​
# 16         12
# 17         10

# %%
gdf_mendoza.loc[gdf_mendoza['poblacion_2010'].str.replace(' ', '')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-325a78faaf56> in <cell line: 1>()
# ----> 1 gdf_mendoza.loc[gdf_mendoza['poblacion_2010'].str.replace(' ', '')]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1299                     raise ValueError("Cannot index with multidimensional key")
#    1300
# -> 1301                 return self._getitem_iterable(key, axis=axis)
#    1302
#    1303             # nested tuple slicing
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1237
#    1238         # A collection of keys
# -> 1239         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240         return self.obj._reindex_with_indexers(
#    1241             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1430         axis_name = self.obj._get_axis_name(axis)
#    1431
# -> 1432         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1433
#    1434         return keyarr, indexer
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6128                 if use_interval_msg:
#    6129                     key = list(key)
# -> 6130                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['203\xa0666', '32\xa0631', '49\xa0458', '32\xa0524', '16\xa0374', '56\xa0373', '10\xa0012',\n       '46\xa0429', '188\xa0018', '119\xa0888', '36\xa0738', '27\xa0660', '191\xa0903',\n       '283\xa0803', '172\xa0332', '115\xa0041', '118\xa0220', '37\xa0859'],\n      dtype='object')] are in the [index]"

# %%
gdf_mendoza['poblacion_2010'] = gdf_mendoza['poblacion_2010'].str.replace('\xa0', '')

# %%
gdf_mendoza['poblacion_2010'] = gdf_mendoza['poblacion_2010'].astype('int')

# %%
gdf_mendoza.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 18 entries, 0 to 17
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gid             18 non-null     int64
#  1   nam             18 non-null     object
#  2   geometry        18 non-null     geometry
#  3   departamento    18 non-null     object
#  4   poblacion_2010  18 non-null     int64
#  5   Superficie_km2  18 non-null     object
#  6   densidad        18 non-null     float64
#  7   distritos       18 non-null     object
#  8   concejales      18 non-null     object
# dtypes: float64(1), geometry(1), int64(2), object(5)
# memory usage: 1.9+ KB

# %%
gdf_mendoza.plot(column = 'poblacion_2010',
         legend = True,
         figsize=(10, 10),
         cmap='YlGnBu',
        );

# %%
# Colormaps = https://matplotlib.org/stable/tutorials/colors/colormaps.html# plt.set_cmap('jet')
fig, ax = plt.subplots(figsize=(10, 10))

gdf_mendoza.plot(column = 'poblacion_2010',
             legend = True,
             cmap='YlGnBu',
             ax = ax
            );
ax.set(title='Mapa coroplético de la  población por departamento - Mendoza (2010)')

ax.set_axis_off()
plt.show()

# %% [markdown]
# #### Localidades censales

# %% [markdown]
# https://datos.gob.ar/ar/dataset/jgm-servicio-normalizacion-datos-geograficos/archivo/jgm_8.9

# %% [markdown]
# Cargamos un csv con localidades censales. No es GDF, a pesar que contiene columnas con latitud y longitud, son columnas de un dataframe estandar.

# %%
localidades = pd.read_csv('https://infra.datos.gob.ar/catalog/modernizacion/dataset/7/distribution/7.29/download/localidades-censales.csv')

# %%
localidades.head(3)
# Out:
#           categoria  centroide_lat  centroide_lon  departamento_id  \
# 0  Localidad simple     -37.823387     -60.484640           6014.0
# 1  Localidad simple     -37.625498     -58.746186           6063.0
# 2  Localidad simple     -37.542635     -58.340719           6063.0
#
#       departamento_nombre fuente funcion       id  municipio_id  \
# 0  Adolfo Gonzales Chaves  INDEC     NaN  6014030       60014.0
# 1                Balcarce  INDEC     NaN  6063030       60063.0
# 2                Balcarce  INDEC     NaN  6063040       60063.0
#
#          municipio_nombre         nombre  provincia_id provincia_nombre
# 0  Adolfo Gonzales Chaves  Juan E. Barra             6     Buenos Aires
# 1                Balcarce      Napaleofú             6     Buenos Aires
# 2                Balcarce    Ramos Otero             6     Buenos Aires

# %% [markdown]
# Nos quedamos sólo con los registros de Mendoza

# %%
localidades = localidades.loc[localidades['provincia_nombre']=='Mendoza']

# %% [markdown]
# Y con tres columnas. La latitud y longitud del centroide de la localidad, y su nombre.

# %%
localidades = localidades[['centroide_lat','centroide_lon', 'nombre']]

# %%
localidades.head()
# Out:
#       centroide_lat  centroide_lon          nombre
# 2053     -32.886969     -68.854308         Mendoza
# 2054     -35.000912     -67.516182           Bowen
# 2055     -35.144906     -67.662955        Carmensa
# 2056     -34.980469     -67.700995  General Alvear
# 2057     -34.979260     -67.659089   Los Compartos

# %% [markdown]
# Ahora convertimos el dataframe tradicional en un GDF, indicandole que columna indica la latitud, y cual la longitud.

# %%
gdf_localidades = gpd.GeoDataFrame(localidades, 
                                   geometry=gpd.points_from_xy(localidades['centroide_lon'], 
                                                               localidades['centroide_lat']),
                                   crs='EPSG:4326')

# %%
gdf_localidades.head(3)
# Out:
#       centroide_lat  centroide_lon    nombre                     geometry
# 2053     -32.886969     -68.854308   Mendoza  POINT (-68.85431 -32.88697)
# 2054     -35.000912     -67.516182     Bowen  POINT (-67.51618 -35.00091)
# 2055     -35.144906     -67.662955  Carmensa  POINT (-67.66296 -35.14491)

# %%
gdf_localidades.plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 10))

gdf_mendoza.plot(ax = ax);

gdf_localidades.plot(marker='o', color='red', markersize=15, ax = ax);

ax.set(title='Localidades Censales - Mendoza (2010)')

# Eliminamos los ejes
ax.set_axis_off()
plt.show()

# %% [markdown]
# ### Contextily

# %% [markdown]
# http://darribas.org/gds19/content/labs/lab_03.html

# %%
# !pip install contextily
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contextily
#   Downloading contextily-1.3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from contextily) (2.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from contextily) (3.7.1)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from contextily) (8.4.0)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.3.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 64.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from contextily) (2.27.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from contextily) (1.2.0)
# Collecting xyzservices (from contextily)
#   Downloading xyzservices-2023.2.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.10/dist-packages (from mercantile->contextily) (8.1.3)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (2022.12.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio->contextily)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (67.7.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Installing collected packages: xyzservices, snuggs, mercantile, affine, rasterio, contextily
# Successfully installed affine-2.4.0 contextily-1.3.0 mercantile-1.2.1 rasterio-1.3.6 snuggs-1.4.7 xyzservices-2023.2.0

# %%
import contextily as cx

# %%
gdf_mendoza_crs = gdf_mendoza.to_crs(epsg=3857)
gdf_loc = gdf_localidades.to_crs(epsg=3857)

# %%
gdf_mendoza
# Out:
#     gid             nam                                           geometry  \
# 0   220       Las Heras  MULTIPOLYGON (((-69.12645 -32.00191, -69.12570...
# 1   213      San Carlos  MULTIPOLYGON (((-68.45348 -34.21255, -68.45584...
# 2   214         Tunuyán  MULTIPOLYGON (((-68.99859 -33.54164, -68.99862...
# 3    92       Tupungato  MULTIPOLYGON (((-68.79835 -33.39054, -68.79835...
# 4    52      Santa Rosa  MULTIPOLYGON (((-67.95776 -32.84504, -67.95774...
# 5    53       Rivadavia  MULTIPOLYGON (((-68.28922 -33.23243, -68.29025...
# 6    55          La Paz  MULTIPOLYGON (((-67.17696 -33.07321, -67.17605...
# 7   111  General Alvear  MULTIPOLYGON (((-66.75741 -34.51179, -66.75688...
# 8   113      San Rafael  MULTIPOLYGON (((-66.77655 -34.29767, -66.77665...
# 9   215   Luján de Cuyo  MULTIPOLYGON (((-68.86869 -32.96118, -68.86828...
# 10  221         Lavalle  MULTIPOLYGON (((-67.31774 -32.38203, -67.31763...
# 11  222        Malargüe  MULTIPOLYGON (((-68.27123 -35.99955, -68.29615...
# 12  337      Godoy Cruz  MULTIPOLYGON (((-68.83759 -32.90452, -68.83808...
# 13  329      Guaymallén  MULTIPOLYGON (((-68.65114 -32.85840, -68.65113...
# 14  334           Maipú  MULTIPOLYGON (((-68.45615 -32.86930, -68.45716...
# 15  336         Capital  MULTIPOLYGON (((-68.82047 -32.87394, -68.82549...
# 16  339      San Martín  MULTIPOLYGON (((-67.95776 -32.84504, -68.12220...
# 17  340           Junín  MULTIPOLYGON (((-68.28781 -33.18864, -68.28871...
#
#       departamento  poblacion_2010 Superficie_km2  densidad       distritos  \
# 0        Las Heras          203666           8955     22.74              14
# 1       San Carlos           32631         11 578      2.82               6
# 2          Tunuyán           49458           3317     14.91              12
# 3        Tupungato           32524           2485     13.09              13
# 4       Santa Rosa           16374           8510      1.92               6
# 5        Rivadavia           56373           2141     26.33              13
# 6           La Paz           10012           7105      1.41               6
# 7   General Alvear           46429         14 448      3.21               4
# 8       San Rafael          188018         31 235      6.02              18
# 9    Luján de Cuyo          119888           4847     24.73              15
# 10         Lavalle           36738         10 212      3.60              24
# 11        Malargüe           27660         41 317      0.67               4
# 12      Godoy Cruz          191903             75   2558.71           9[7]​
# 13      Guaymallén          283803            164   1730.51              21
# 14           Maipú          172332            617    279.31              12
# 15         Capital          115041             57   2018.26  12 (secciones)
# 16      San Martín          118220           1504     78.60              15
# 17           Junín           37859            263    143.95              10
#
#    concejales
# 0          12
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          12
# 9     12[17]​
# 10         10
# 11         10
# 12         12
# 13         12
# 14         12
# 15    12[21]​
# 16         12
# 17         10

# %%
# Filtramos departamentos del Gran Mendoza: Capital, Godoy Cruz, Guaymallén , Las Heras, Lavalle, Luján y Maipú
gdf_dep_gm = gdf_mendoza.loc[(gdf_mendoza['nam']=='Las Heras') | 
                             (gdf_mendoza['nam']=='Capital') | 
                             (gdf_mendoza['nam']=='Godoy Cruz') |
                             (gdf_mendoza['nam']=='Guaymallén') |
                             (gdf_mendoza['nam']=='Lavalle') |
                             (gdf_mendoza['nam']=='Luján de Cuyo') |
                             (gdf_mendoza['nam']=='Maipú')]

# %%
f, ax = plt.subplots(1, figsize=(9, 9))

gdf_mendoza.plot(ax = ax, alpha=0.5)
gdf_dep_gm.plot(ax=ax, facecolor = 'green', alpha = 0.5)
gdf_localidades.plot(alpha=0.3, marker='o', color='red', markersize=15, ax=ax)

cx.add_basemap(ax, crs=gdf_localidades.crs)

ax.set(title='Localidades Censales - Mendoza (2010) - Resaltado: Gran Mendoza');
ax.set_axis_off()

# %% [markdown]
# ### Geocoding

# %% [markdown]
# [Documentacion](https://automating-gis-processes.github.io/site/notebooks/L3/geocoding_in_geopandas.html)
#
# Que ocurre si no tenés la latitud y la longitud de los puntos que queremos marcar, pero si su dirección postal?
#
# Podemos utilizar algún servicio de _geocodificación_, al cual le pasamos las direcciones lo mas completas posibles, y nos devuelve la latitud y la longitud del punto.
#
# Geopandas tiene una herramienta para eso, que permite utilizar varios servicios como nominatim, google, bing, yahoo, y openmapquest.
#
# Nosotrs vamos a utilizar el servicio de `nominatim` ([link](https://nominatim.org)), que se basa en [OpenStreetMap](https://www.openstreetmap.org) para geocodificar.
#
# Existen otros paquete que prestan servicios similares, con una mayor cantidad de proveedores gratuitos o pagos, como [geocoder](https://geocoder.readthedocs.io/)

# %%
from geopandas.tools import geocode

# %%
tabla = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Universidades_nacionales_de_Argentina')

# %%
tabla[1]
# Out:
#                                                     º   Unnamed: 1  \
# 0                                              Nombre     Acrónimo
# 1                         Universidad de Buenos Aires          UBA
# 2                         Universidad de Buenos Aires          UBA
# 3      Universidad Nacional Almirante Guillermo Brown         UNAB
# 4               Universidad Nacional Arturo Jauretche         UNAJ
# 5                  Universidad Nacional de Avellaneda        UNDAV
# 6                   Universidad Nacional de Catamarca         UNCa
# 7                   Universidad Nacional de Chilecito  UNChi UNdeC
# 8                     Universidad Nacional de Córdoba          UNC
# 9                        Universidad Nacional de Cuyo  UNCu UNCuyo
# 10                 Universidad Nacional de Entre Ríos         UNER
# 11                    Universidad Nacional de Formosa          UNF
# 12           Universidad Nacional de Gral. San Martín   UNSM UNSaM
# 13            Universidad Nacional de Gral. Sarmiento         UNGS
# 14                 Universidad Nacional de Hurlingham       UNAHUR
# 15                Universidad Nacional de José C. Paz   UNJP UNPAZ
# 16                      Universidad Nacional de Jujuy         UNJu
# 17                 Universidad Nacional de La Matanza   UNLM UNLaM
# 18                   Universidad Nacional de La Pampa       UNLPam
# 19       Universidad Nacional de la Patagonia Austral         UNPA
# 20  Universidad Nacional de la Patagonia San Juan ...   UNP UNPSJB
# 21                   Universidad Nacional de La Plata         UNLP
# 22                   Universidad Nacional de La Rioja        UNLaR
# 23                  Universidad Nacional de las Artes          UNA
# 24                      Universidad Nacional de Lanús         UNLa
# 25            Universidad Nacional de Lomas de Zamora         UNLZ
# 26          Universidad Nacional de los Comechingones         UNLC
# 27                      Universidad Nacional de Luján         UNLu
# 28              Universidad Nacional de Mar del Plata        UNMDP
# 29                   Universidad Nacional de Misiones     UNM UNaM
# 30                     Universidad Nacional de Moreno     UNM UNMo
# 31                    Universidad Nacional de Quilmes          UNQ
# 32                    Universidad Nacional de Rafaela        UNRaf
# 33                 Universidad Nacional de Río Cuarto         UNRC
# 34                  Universidad Nacional de Río Negro         UNRN
# 35                    Universidad Nacional de Rosario          UNR
# 36                      Universidad Nacional de Salta         UNSa
# 37                   Universidad Nacional de San Juan         UNSJ
# 38                   Universidad Nacional de San Luis         UNSL
# 39       Universidad Nacional de San Antonio de Areco       UNSAdA
# 40        Universidad Nacional de Santiago del Estero         UNSE
# 41  Universidad Nacional de Tierra del Fuego, Antá...        UNTDF
# 42            Universidad Nacional de Tres de Febrero       UNTREF
# 43                    Universidad Nacional de Tucumán          UNT
# 44                Universidad Nacional de Villa María         UNVM
# 45             Universidad Nacional de Villa Mercedes       UNViMe
# 46              Universidad Nacional del Alto Uruguay         UNAU
# 47  Universidad Nacional del Centro de la Provinci...       UNICEN
# 48             Universidad Nacional del Chaco Austral       UNCAus
# 49                   Universidad Nacional del Comahue  UNCOMA UNCo
# 50                   Universidad Nacional del Litoral          UNL
# 51                  Universidad Nacional del Nordeste         UNNE
# 52  Universidad Nacional del Noroeste de la Provin...       UNNOBA
# 53                     Universidad Nacional del Oeste          UNO
# 54                       Universidad Nacional del Sur          UNS
# 55         Universidad Nacional Raúl Scalabrini Ortiz         UNSO
# 56                   Universidad Tecnológica Nacional          UTN
#
#                                  Unnamed: 2              Unnamed: 3  \
# 0                                 Dirección                  Ciudad
# 1                              Viamonte 430            Buenos Aires
# 2                              Viamonte 430            Buenos Aires
# 3                     Av. Tomás Espora 4320                 Burzaco
# 4                       Av. San Martín 2002        Florencio Varela
# 5                     España 350 esq. Colón              Avellaneda
# 6                                Esquiú 612               Catamarca
# 7                             9 de Julio 22               Chilecito
# 8   Haya de la Torre s/n Pabellón Argentina                 Córdoba
# 9                      Centro Universitario                 Mendoza
# 10                             Eva Perón 24  Concepción del Uruguay
# 11                        Av. Gutnisky 3200                 Formosa
# 12                 Av. 25 de Mayo y Francia              San Martín
# 13                   Juan M. Gutiérrez 1150          Los Polvorines
# 14              Teniente Manuel Origone 151             Villa Tesei
# 15                     Leandro N. Alem 4731             José C. Paz
# 16                         Av. Bolivia 1239   San Salvador de Jujuy
# 17                    Florencio Varela 1903               San Justo
# 18                          Coronel Gil 353              Santa Rosa
# 19                Lisandro de la Torre 1070            Río Gallegos
# 20                     Ciudad Universitaria      Comodoro Rivadavia
# 21                             Av. 7 N° 776                La Plata
# 22                Av. Dr. René Favaloro S/N                La Rioja
# 23                           Azcuénaga 1129            Buenos Aires
# 24                 29 de septiembre de 3901    Remedios de Escalada
# 25                       Ruta Prov. 4, km 2         Lomas de Zamora
# 26                         Poeta Agüero 380          Villa de Merlo
# 27                Ruta 5 y Av. Constitución                   Luján
# 28               Diagonal J.B. Alberdi 2695           Mar del Plata
# 29                    Ruta Nac. 12, km. 7,5                 Posadas
# 30                 Av. Bartolomé Mitre 1891                  Moreno
# 31                     Roque Sáenz Peña 352                 Quilmes
# 32                             Bv. Roca 989                 Rafaela
# 33                    Ruta Nac. 36, km. 601              Río Cuarto
# 34                                Colón 450                  Viedma
# 35                              Córdoba 181                 Rosario
# 36                         Av. Bolivia 5150                   Salta
# 37                              Mitre 396 E                San Juan
# 38                Ejército de los Andes 950                San Luis
# 39                        Av. Güiraldes 689    San Antonio de Areco
# 40                        Av. Belgrano 1912     Santiago del Estero
# 41                        Fuegia Basket 251                 Ushuaia
# 42                             Mosconi 2736              Saenz Peña
# 43                             Ayacucho 491   San Miguel de Tucumán
# 44                          Entre Ríos 1425             Villa María
# 45                            Las Heras 383          Villa Mercedes
# 46                                      NaN             San Vicente
# 47                          Gral. Pinto 399                  Tandil
# 48                       Cte. Fernández 755        Roque Sáenz Peña
# 49                        Buenos Aires 1400                 Neuquén
# 50                      Bv. Pellegrini 2750                Santa Fe
# 51                           25 de Mayo 868              Corrientes
# 52                           Sáenz Peña 456                   Junín
# 53                             Belgrano 369    San Antonio de Padua
# 54                            Av. Alem 1253            Bahía Blanca
# 55                                      NaN              San Isidro
# 56                            Sarmiento 440            Buenos Aires
#
#                 Unnamed: 4                                         Unnamed: 5  \
# 0                Provincia                                        Otras sedes
# 1   Ciudad de Buenos Aires                                                NaN
# 2   Ciudad de Buenos Aires                                                NaN
# 3             Buenos Aires                                                NaN
# 4             Buenos Aires                          Castelli, Lobos, Brandsen
# 5             Buenos Aires                                            Piñeyro
# 6                Catamarca                                                NaN
# 7                 La Rioja                                                NaN
# 8                  Córdoba                                                NaN
# 9                  Mendoza                                                NaN
# 10              Entre Ríos  Concordia, Gualeguaychú, Oro Verde, Paraná, Vi...
# 11                 Formosa                                                NaN
# 12            Buenos Aires                                                NaN
# 13            Buenos Aires                               Moreno, San Fernando
# 14            Buenos Aires                                                NaN
# 15            Buenos Aires                                                NaN
# 16                   Jujuy                                          San Pedro
# 17            Buenos Aires                           San Justo,  Buenos Aires
# 18                La Pampa                                       General Pico
# 19              Santa Cruz       Caleta Olivia, Puerto San Julián, Río Turbio
# 20                  Chubut                      Esquel, Puerto Madryn, Trelew
# 21            Buenos Aires                                                NaN
# 22                La Rioja           Aimogasta, Chamical, Chepes, Villa Unión
# 23  Ciudad de Buenos Aires                                                NaN
# 24            Buenos Aires                                                NaN
# 25            Buenos Aires                                                NaN
# 26                San Luis                                                NaN
# 27            Buenos Aires                     San Miguel, Chivilcoy, Campana
# 28            Buenos Aires                                                NaN
# 29                Misiones                                    Eldorado, Oberá
# 30            Buenos Aires                                                NaN
# 31            Buenos Aires                                                NaN
# 32                Santa Fe                                                NaN
# 33                 Córdoba                                                NaN
# 34               Río Negro  Allen, Bariloche, Choele Choel, Cinco Saltos, ...
# 35                Santa Fe                                                NaN
# 36                   Salta      Metán, Orán, Rosario de la Frontera, Tartagal
# 37                San Juan                                                NaN
# 38                San Luis                              Merlo, Villa Mercedes
# 39            Buenos Aires                                           Baradero
# 40     Santiago del Estero                                                NaN
# 41        Tierra del Fuego                                         Río Grande
# 42            Buenos Aires     Caseros, El Palomar, Buenos Aires, Villa Lynch
# 43                 Tucumán                                        Yerba Buena
# 44                 Córdoba  Córdoba, Villa del Rosario, San Francisco, Vil...
# 45                San Luis                                                NaN
# 46                Misiones                                                NaN
# 47            Buenos Aires                           Azul, Olavarría, Quequén
# 48                   Chaco                                                NaN
# 49                 Neuquén  Allen, Bariloche, Choele Choel, Cinco Saltos, ...
# 50                Santa Fe            Rafaela, Esperanza, Reconquista, Gálvez
# 51              Corrientes  Resistencia, Presidencia Roque Sáenz Peña, Cur...
# 52            Buenos Aires                                          Pergamino
# 53            Buenos Aires                                              Merlo
# 54            Buenos Aires                                                NaN
# 55            Buenos Aires                                                NaN
# 56  Ciudad de Buenos Aires  Avellaneda, Bahía Blanca, Campana, Concepción ...
#
#            Unnamed: 6              Unnamed: 7 Unnamed: 8
# 0       Sitio oficial  Estudiantes (2019)[9]​   Creación
# 1          www.uba.ar                  318935       1821
# 2          www.uba.ar                  318935       1821
# 3     www.unab.edu.ar                     267       2016
# 4     www.unaj.edu.ar                   24900       2009
# 5    www.undav.edu.ar                   17019       2009
# 6     www.unca.edu.ar                   15237       1972
# 7    www.undec.edu.ar                    3453       2002
# 8      www.unc.edu.ar                  151846       1613
# 9     www.uncu.edu.ar                   35621       1939
# 10    www.uner.edu.ar                   19370       1973
# 11     www.unf.edu.ar                   11979       1988
# 12   www.unsam.edu.ar                   17578       1992
# 13    www.ungs.edu.ar                   15575       1993
# 14  www.unahur.edu.ar                   12406       2014
# 15   www.unpaz.edu.ar                   14997       2009
# 16    www.unju.edu.ar                   24754       1973
# 17   www.unlam.edu.ar                   41042       1989
# 18  www.unlpam.edu.ar                   12004       1973
# 19    www.unpa.edu.ar                    8639       1994
# 20     www.unp.edu.ar                   17790       1980
# 21    www.unlp.edu.ar                  109874       1897
# 22   www.unlar.edu.ar                   26692       1993
# 23     www.una.edu.ar                   19331       2014
# 24    www.unla.edu.ar                   14710       1995
# 25    www.unlz.edu.ar                   38663       1972
# 26    www.unlc.edu.ar                     NaN       2014
# 27    www.unlu.edu.ar                   24281       1973
# 28     www.mdp.edu.ar                   33899       1975
# 29    www.unam.edu.ar                   26435       1973
# 30     www.unm.edu.ar                    9722       2009
# 31     www.unq.edu.ar                   26998       1989
# 32   www.unraf.edu.ar                    1018       2014
# 33    www.unrc.edu.ar                   16311       1971
# 34    www.unrn.edu.ar                    9970       2008
# 35     www.unr.edu.ar                   86279       1968
# 36    www.unsa.edu.ar                   34052       1972
# 37    www.unsj.edu.ar                   22864       1973
# 38    www.unsl.edu.ar                   17104       1973
# 39  www.unsada.edu.ar                    1335       2015
# 40    www.unse.edu.ar                   14345       1973
# 41   www.untdf.edu.ar                    3946       2010
# 42  www.untref.edu.ar                   16848       1995
# 43     www.unt.edu.ar                   69273       1914
# 44    www.unvm.edu.ar                    8249       1995
# 45  www.unvime.edu.ar                    2496       2009
# 46    www.unau.edu.ar                     435       2015
# 47  www.unicen.edu.ar                   15747       1974
# 48  www.uncaus.edu.ar                   19051       2007
# 49  www.uncoma.edu.ar                   32048       1971
# 50     www.unl.edu.ar                   48036       1889
# 51    www.unne.edu.ar                   52163       1956
# 52  www.unnoba.edu.ar                    7908       2002
# 53     www.uno.edu.ar                    6556       2009
# 54     www.uns.edu.ar                   21836       1956
# 55    www.unso.edu.ar                     440       2015
# 56     www.utn.edu.ar                   91510       1948

# %%
universidades  = tabla[1]

# %%
# La segunda fila es el nombre de la columna, por lo que la vamos a poner como encabeza pisando los nombres actuales
# La segunda fila es el nombre de la columna, por lo que la vamos a poner como encabeza pisando los nombres actuales
universidades = universidades.rename(columns=universidades.iloc[0]).drop(universidades.index[0]).reset_index(drop=True)

# %%
universidades
# Out:
#                                                Nombre     Acrónimo  \
# 0                                              Nombre     Acrónimo
# 1                         Universidad de Buenos Aires          UBA
# 2      Universidad Nacional Almirante Guillermo Brown         UNAB
# 3               Universidad Nacional Arturo Jauretche         UNAJ
# 4                  Universidad Nacional de Avellaneda        UNDAV
# 5                   Universidad Nacional de Catamarca         UNCa
# 6                   Universidad Nacional de Chilecito  UNChi UNdeC
# 7                     Universidad Nacional de Córdoba          UNC
# 8                        Universidad Nacional de Cuyo  UNCu UNCuyo
# 9                  Universidad Nacional de Entre Ríos         UNER
# 10                    Universidad Nacional de Formosa          UNF
# 11           Universidad Nacional de Gral. San Martín   UNSM UNSaM
# 12            Universidad Nacional de Gral. Sarmiento         UNGS
# 13                 Universidad Nacional de Hurlingham       UNAHUR
# 14                Universidad Nacional de José C. Paz   UNJP UNPAZ
# 15                      Universidad Nacional de Jujuy         UNJu
# 16                 Universidad Nacional de La Matanza   UNLM UNLaM
# 17                   Universidad Nacional de La Pampa       UNLPam
# 18       Universidad Nacional de la Patagonia Austral         UNPA
# 19  Universidad Nacional de la Patagonia San Juan ...   UNP UNPSJB
# 20                   Universidad Nacional de La Plata         UNLP
# 21                   Universidad Nacional de La Rioja        UNLaR
# 22                  Universidad Nacional de las Artes          UNA
# 23                      Universidad Nacional de Lanús         UNLa
# 24            Universidad Nacional de Lomas de Zamora         UNLZ
# 25          Universidad Nacional de los Comechingones         UNLC
# 26                      Universidad Nacional de Luján         UNLu
# 27              Universidad Nacional de Mar del Plata        UNMDP
# 28                   Universidad Nacional de Misiones     UNM UNaM
# 29                     Universidad Nacional de Moreno     UNM UNMo
# 30                    Universidad Nacional de Quilmes          UNQ
# 31                    Universidad Nacional de Rafaela        UNRaf
# 32                 Universidad Nacional de Río Cuarto         UNRC
# 33                  Universidad Nacional de Río Negro         UNRN
# 34                    Universidad Nacional de Rosario          UNR
# 35                      Universidad Nacional de Salta         UNSa
# 36                   Universidad Nacional de San Juan         UNSJ
# 37                   Universidad Nacional de San Luis         UNSL
# 38       Universidad Nacional de San Antonio de Areco       UNSAdA
# 39        Universidad Nacional de Santiago del Estero         UNSE
# 40  Universidad Nacional de Tierra del Fuego, Antá...        UNTDF
# 41            Universidad Nacional de Tres de Febrero       UNTREF
# 42                    Universidad Nacional de Tucumán          UNT
# 43                Universidad Nacional de Villa María         UNVM
# 44             Universidad Nacional de Villa Mercedes       UNViMe
# 45              Universidad Nacional del Alto Uruguay         UNAU
# 46  Universidad Nacional del Centro de la Provinci...       UNICEN
# 47             Universidad Nacional del Chaco Austral       UNCAus
# 48                   Universidad Nacional del Comahue  UNCOMA UNCo
# 49                   Universidad Nacional del Litoral          UNL
# 50                  Universidad Nacional del Nordeste         UNNE
# 51  Universidad Nacional del Noroeste de la Provin...       UNNOBA
# 52                     Universidad Nacional del Oeste          UNO
# 53                       Universidad Nacional del Sur          UNS
# 54         Universidad Nacional Raúl Scalabrini Ortiz         UNSO
# 55                   Universidad Tecnológica Nacional          UTN
#
#                                   Dirección                  Ciudad  \
# 0                                 Dirección                  Ciudad
# 1                              Viamonte 430            Buenos Aires
# 2                     Av. Tomás Espora 4320                 Burzaco
# 3                       Av. San Martín 2002        Florencio Varela
# 4                     España 350 esq. Colón              Avellaneda
# 5                                Esquiú 612               Catamarca
# 6                             9 de Julio 22               Chilecito
# 7   Haya de la Torre s/n Pabellón Argentina                 Córdoba
# 8                      Centro Universitario                 Mendoza
# 9                              Eva Perón 24  Concepción del Uruguay
# 10                        Av. Gutnisky 3200                 Formosa
# 11                 Av. 25 de Mayo y Francia              San Martín
# 12                   Juan M. Gutiérrez 1150          Los Polvorines
# 13              Teniente Manuel Origone 151             Villa Tesei
# 14                     Leandro N. Alem 4731             José C. Paz
# 15                         Av. Bolivia 1239   San Salvador de Jujuy
# 16                    Florencio Varela 1903               San Justo
# 17                          Coronel Gil 353              Santa Rosa
# 18                Lisandro de la Torre 1070            Río Gallegos
# 19                     Ciudad Universitaria      Comodoro Rivadavia
# 20                             Av. 7 N° 776                La Plata
# 21                Av. Dr. René Favaloro S/N                La Rioja
# 22                           Azcuénaga 1129            Buenos Aires
# 23                 29 de septiembre de 3901    Remedios de Escalada
# 24                       Ruta Prov. 4, km 2         Lomas de Zamora
# 25                         Poeta Agüero 380          Villa de Merlo
# 26                Ruta 5 y Av. Constitución                   Luján
# 27               Diagonal J.B. Alberdi 2695           Mar del Plata
# 28                    Ruta Nac. 12, km. 7,5                 Posadas
# 29                 Av. Bartolomé Mitre 1891                  Moreno
# 30                     Roque Sáenz Peña 352                 Quilmes
# 31                             Bv. Roca 989                 Rafaela
# 32                    Ruta Nac. 36, km. 601              Río Cuarto
# 33                                Colón 450                  Viedma
# 34                              Córdoba 181                 Rosario
# 35                         Av. Bolivia 5150                   Salta
# 36                              Mitre 396 E                San Juan
# 37                Ejército de los Andes 950                San Luis
# 38                        Av. Güiraldes 689    San Antonio de Areco
# 39                        Av. Belgrano 1912     Santiago del Estero
# 40                        Fuegia Basket 251                 Ushuaia
# 41                             Mosconi 2736              Saenz Peña
# 42                             Ayacucho 491   San Miguel de Tucumán
# 43                          Entre Ríos 1425             Villa María
# 44                            Las Heras 383          Villa Mercedes
# 45                                      NaN             San Vicente
# 46                          Gral. Pinto 399                  Tandil
# 47                       Cte. Fernández 755        Roque Sáenz Peña
# 48                        Buenos Aires 1400                 Neuquén
# 49                      Bv. Pellegrini 2750                Santa Fe
# 50                           25 de Mayo 868              Corrientes
# 51                           Sáenz Peña 456                   Junín
# 52                             Belgrano 369    San Antonio de Padua
# 53                            Av. Alem 1253            Bahía Blanca
# 54                                      NaN              San Isidro
# 55                            Sarmiento 440            Buenos Aires
#
#                  Provincia                                        Otras sedes  \
# 0                Provincia                                        Otras sedes
# 1   Ciudad de Buenos Aires                                                NaN
# 2             Buenos Aires                                                NaN
# 3             Buenos Aires                          Castelli, Lobos, Brandsen
# 4             Buenos Aires                                            Piñeyro
# 5                Catamarca                                                NaN
# 6                 La Rioja                                                NaN
# 7                  Córdoba                                                NaN
# 8                  Mendoza                                                NaN
# 9               Entre Ríos  Concordia, Gualeguaychú, Oro Verde, Paraná, Vi...
# 10                 Formosa                                                NaN
# 11            Buenos Aires                                                NaN
# 12            Buenos Aires                               Moreno, San Fernando
# 13            Buenos Aires                                                NaN
# 14            Buenos Aires                                                NaN
# 15                   Jujuy                                          San Pedro
# 16            Buenos Aires                           San Justo,  Buenos Aires
# 17                La Pampa                                       General Pico
# 18              Santa Cruz       Caleta Olivia, Puerto San Julián, Río Turbio
# 19                  Chubut                      Esquel, Puerto Madryn, Trelew
# 20            Buenos Aires                                                NaN
# 21                La Rioja           Aimogasta, Chamical, Chepes, Villa Unión
# 22  Ciudad de Buenos Aires                                                NaN
# 23            Buenos Aires                                                NaN
# 24            Buenos Aires                                                NaN
# 25                San Luis                                                NaN
# 26            Buenos Aires                     San Miguel, Chivilcoy, Campana
# 27            Buenos Aires                                                NaN
# 28                Misiones                                    Eldorado, Oberá
# 29            Buenos Aires                                                NaN
# 30            Buenos Aires                                                NaN
# 31                Santa Fe                                                NaN
# 32                 Córdoba                                                NaN
# 33               Río Negro  Allen, Bariloche, Choele Choel, Cinco Saltos, ...
# 34                Santa Fe                                                NaN
# 35                   Salta      Metán, Orán, Rosario de la Frontera, Tartagal
# 36                San Juan                                                NaN
# 37                San Luis                              Merlo, Villa Mercedes
# 38            Buenos Aires                                           Baradero
# 39     Santiago del Estero                                                NaN
# 40        Tierra del Fuego                                         Río Grande
# 41            Buenos Aires     Caseros, El Palomar, Buenos Aires, Villa Lynch
# 42                 Tucumán                                        Yerba Buena
# 43                 Córdoba  Córdoba, Villa del Rosario, San Francisco, Vil...
# 44                San Luis                                                NaN
# 45                Misiones                                                NaN
# 46            Buenos Aires                           Azul, Olavarría, Quequén
# 47                   Chaco                                                NaN
# 48                 Neuquén  Allen, Bariloche, Choele Choel, Cinco Saltos, ...
# 49                Santa Fe            Rafaela, Esperanza, Reconquista, Gálvez
# 50              Corrientes  Resistencia, Presidencia Roque Sáenz Peña, Cur...
# 51            Buenos Aires                                          Pergamino
# 52            Buenos Aires                                              Merlo
# 53            Buenos Aires                                                NaN
# 54            Buenos Aires                                                NaN
# 55  Ciudad de Buenos Aires  Avellaneda, Bahía Blanca, Campana, Concepción ...
#
#         Sitio oficial  Estudiantes (2019)[9]​  Creación
# 0       Sitio oficial  Estudiantes (2019)[9]​  Creación
# 1          www.uba.ar                  318935      1821
# 2     www.unab.edu.ar                     267      2016
# 3     www.unaj.edu.ar                   24900      2009
# 4    www.undav.edu.ar                   17019      2009
# 5     www.unca.edu.ar                   15237      1972
# 6    www.undec.edu.ar                    3453      2002
# 7      www.unc.edu.ar                  151846      1613
# 8     www.uncu.edu.ar                   35621      1939
# 9     www.uner.edu.ar                   19370      1973
# 10     www.unf.edu.ar                   11979      1988
# 11   www.unsam.edu.ar                   17578      1992
# 12    www.ungs.edu.ar                   15575      1993
# 13  www.unahur.edu.ar                   12406      2014
# 14   www.unpaz.edu.ar                   14997      2009
# 15    www.unju.edu.ar                   24754      1973
# 16   www.unlam.edu.ar                   41042      1989
# 17  www.unlpam.edu.ar                   12004      1973
# 18    www.unpa.edu.ar                    8639      1994
# 19     www.unp.edu.ar                   17790      1980
# 20    www.unlp.edu.ar                  109874      1897
# 21   www.unlar.edu.ar                   26692      1993
# 22     www.una.edu.ar                   19331      2014
# 23    www.unla.edu.ar                   14710      1995
# 24    www.unlz.edu.ar                   38663      1972
# 25    www.unlc.edu.ar                     NaN      2014
# 26    www.unlu.edu.ar                   24281      1973
# 27     www.mdp.edu.ar                   33899      1975
# 28    www.unam.edu.ar                   26435      1973
# 29     www.unm.edu.ar                    9722      2009
# 30     www.unq.edu.ar                   26998      1989
# 31   www.unraf.edu.ar                    1018      2014
# 32    www.unrc.edu.ar                   16311      1971
# 33    www.unrn.edu.ar                    9970      2008
# 34     www.unr.edu.ar                   86279      1968
# 35    www.unsa.edu.ar                   34052      1972
# 36    www.unsj.edu.ar                   22864      1973
# 37    www.unsl.edu.ar                   17104      1973
# 38  www.unsada.edu.ar                    1335      2015
# 39    www.unse.edu.ar                   14345      1973
# 40   www.untdf.edu.ar                    3946      2010
# 41  www.untref.edu.ar                   16848      1995
# 42     www.unt.edu.ar                   69273      1914
# 43    www.unvm.edu.ar                    8249      1995
# 44  www.unvime.edu.ar                    2496      2009
# 45    www.unau.edu.ar                     435      2015
# 46  www.unicen.edu.ar                   15747      1974
# 47  www.uncaus.edu.ar                   19051      2007
# 48  www.uncoma.edu.ar                   32048      1971
# 49     www.unl.edu.ar                   48036      1889
# 50    www.unne.edu.ar                   52163      1956
# 51  www.unnoba.edu.ar                    7908      2002
# 52     www.uno.edu.ar                    6556      2009
# 53     www.uns.edu.ar                   21836      1956
# 54    www.unso.edu.ar                     440      2015
# 55     www.utn.edu.ar                   91510      1948

# %%
universidades['addr'] = universidades['Dirección'] + ', ' + universidades['Ciudad'] + ', ' + universidades['Provincia'] + ', Argentina'

# %%
universidades.columns
# Out:
# Index(['Nombre', 'Acrónimo', 'Dirección', 'Ciudad', 'Provincia', 'Otras sedes',
#        'Sitio oficial', 'Estudiantes (2019)[9]​', 'Creación', 'addr'],
#       dtype='object')

# %%
universidades = universidades[['Nombre', 'Acrónimo', 'addr']]

# %%
universidades.head(3)
# Out:
#                                            Nombre  Acrónimo  \
# 0                                          Nombre  Acrónimo
# 1                     Universidad de Buenos Aires       UBA
# 2  Universidad Nacional Almirante Guillermo Brown      UNAB
#
#                                                 addr
# 0            Dirección, Ciudad, Provincia, Argentina
# 1  Viamonte 430, Buenos Aires, Ciudad de Buenos A...
# 2  Av. Tomás Espora 4320, Burzaco, Buenos Aires, ...

# %% [markdown]
# Geocodificamos las direcciones con Nominatim. En el parámetro `user_agent` se debería poner el nombre de la app a modo de descripción.

# %%
geo = geocode(universidades['addr'], provider='nominatim', user_agent='test_flacso', timeout=4)

# %%
geo
# Out:
#                        geometry  \
# 0   POINT (-67.52736 -46.45274)
# 1   POINT (-58.37312 -34.59977)
# 2                   POINT EMPTY
# 3   POINT (-58.28136 -34.77437)
# 4                   POINT EMPTY
# 5   POINT (-65.76807 -28.46589)
# 6   POINT (-67.49450 -29.16495)
# 7                   POINT EMPTY
# 8   POINT (-68.47269 -33.20158)
# 9                   POINT EMPTY
# 10                  POINT EMPTY
# 11                  POINT EMPTY
# 12                  POINT EMPTY
# 13                  POINT EMPTY
# 14  POINT (-58.74525 -34.52117)
# 15  POINT (-65.32194 -24.18106)
# 16  POINT (-58.56288 -34.67011)
# 17  POINT (-64.28942 -36.62042)
# 18  POINT (-69.23447 -51.62015)
# 19                  POINT EMPTY
# 20                  POINT EMPTY
# 21                  POINT EMPTY
# 22  POINT (-58.39955 -34.59481)
# 23                  POINT EMPTY
# 24                  POINT EMPTY
# 25  POINT (-65.01602 -32.34715)
# 26                  POINT EMPTY
# 27                  POINT EMPTY
# 28                  POINT EMPTY
# 29  POINT (-58.79316 -34.64814)
# 30  POINT (-58.27852 -34.70638)
# 31                  POINT EMPTY
# 32                  POINT EMPTY
# 33  POINT (-62.99168 -40.81003)
# 34  POINT (-60.66420 -32.94178)
# 35  POINT (-65.40763 -24.72713)
# 36  POINT (-68.54016 -31.57883)
# 37  POINT (-68.59579 -33.02817)
# 38  POINT (-59.47969 -34.25720)
# 39  POINT (-64.24569 -27.73680)
# 40  POINT (-68.34171 -54.82130)
# 41  POINT (-58.52824 -34.60169)
# 42  POINT (-65.21122 -26.83639)
# 43  POINT (-63.23820 -32.41073)
# 44  POINT (-65.46379 -33.66606)
# 45    POINT (11.04803 46.31448)
# 46                  POINT EMPTY
# 47                  POINT EMPTY
# 48  POINT (-68.05034 -38.93949)
# 49                  POINT EMPTY
# 50  POINT (-58.83943 -27.46412)
# 51                  POINT EMPTY
# 52  POINT (-58.69986 -34.66539)
# 53  POINT (-62.26936 -38.70142)
# 54    POINT (11.04803 46.31448)
# 55  POINT (-58.37299 -34.60463)
#
#                                               address
# 0   Dirección de transito, San José Obrero, Oeste,...
# 1   430, Viamonte, Microcentro, San Nicolás, Bueno...
# 2                                                None
# 3   Avenida San Martín, San Emilio, Florencio Vare...
# 4                                                None
# 5   Esquiú, Jardín, Jorge Bermudez, San Fernando d...
# 6   22, 9 de Julio, Barrio Mayo, Chilecito, Depart...
# 7                                                None
# 8   Centro universitario Rivadavia, Jose Hernandez...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  Universidad Nacional de José Clemante Paz, 473...
# 15  Avenida Bolivia, Regimiento de Infanteria de M...
# 16  1903, Florencio Varela, San Justo, Partido de ...
# 17  Universidad Nacional de La Pampa, 353, Coronel...
# 18  Lisandro de la Torre, Gregores, Río Gallegos, ...
# 19                                               None
# 20                                               None
# 21                                               None
# 22  Universidad Nacional de las Artes, 1129, Azcué...
# 23                                               None
# 24                                               None
# 25  Poeta Agüero, Barrio San Agustín, Villa de Mer...
# 26                                               None
# 27                                               None
# 28                                               None
# 29  Avenida Bartolomé Mitre, El Obrero, Moreno Cen...
# 30  Universidad Nacional de Quilmes, 352, Roque Sá...
# 31                                               None
# 32                                               None
# 33  Universidad Nacional de Río Negro, 450, Colón,...
# 34  Córdoba, Alberto Olmedo, Distrito Centro, Rosa...
# 35  Universidad Nacional de Salta - Campo General ...
# 36  Mitre, Barrio Los Olivos Fontana, Villa Krause...
# 37  Ejército De Los Andes, Barrio Loma Verde, Dist...
# 38  689, Avenida Güiraldes, San Antonio de Areco, ...
# 39  Avenida Belgrano, Centro, La Banda, Departamen...
# 40  Fuegia Basket, Belgrano, Ushuaia, Departamento...
# 41  UNTREF - Sede Rectorado, 2736, 414 - General E...
# 42  Rectorado Universidad Nacional de Tucumán, 491...
# 43  1425, Entre Ríos, Centro Sur, Villa María, Mun...
# 44  Las Heras, Teodoro Fels, Villa Mercedes, Munic...
# 45  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 46                                               None
# 47                                               None
# 48  Universidad Nacional del Comahue, 1400, Buenos...
# 49                                               None
# 50  Rectorado UNNE, 868, 25 de Mayo, Barrio Deport...
# 51                                               None
# 52  369, General Manuel Belgrano, San Antonio de P...
# 53  Universidad Nacional del Sur, 1253, Avenida Al...
# 54  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 55  Rectorado Universidad Tecnológica Nacional, 44...

# %% [markdown]
# "al costado" de la base de universidades, le pegamos los parametros geolocalizados mediante un `join`

# %%
gdf_uni = geo.join(universidades)

# %%
type(gdf_uni)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# Graficamos las universidades:

# %%
gdf_uni.plot();

# %% [markdown]
# Vamos a graficar la capa universidades arriba de la capa de límites provinciales.

# %%
f, ax = plt.subplots(1, figsize=(9, 9))
gdf_prov.plot(ax = ax, alpha=0.5)
# dep.plot(ax=ax, facecolor = 'green', alpha = 0.5)
gdf_uni.plot(alpha=0.3, marker='o', color='red', markersize=15, ax=ax)

ax.set_axis_off();

# %% [markdown]
# Claramente un punto no se logró geocodificar correctamente, devolviendo valores erroneos de lat y lon para la dirección registrada. Existe algunas formas de lidiar con esto:

# %% [markdown]
# #### **Acotando el mapa a la superficie del mapa de Argentina (es todo el cuadro, no sólo el territorio):**

# %%
f, ax = plt.subplots(1, figsize=(9, 9))

# Graficamos las provincias
gdf_prov.plot(ax = ax, alpha=0.5)

# Graficamos las universidades
gdf_uni.plot(alpha=0.3, marker='o', color='red', markersize=15, ax=ax)

# Titulo
ax.set(title='Localidades Censales - Mendoza (2010)')

# Limites del mapa de provincias
ax.set_ylim(gdf_prov.bounds.miny.min(), gdf_prov.bounds.maxy.max())
ax.set_xlim(gdf_prov.bounds.minx.min(), gdf_prov.bounds.maxx.max())

# Borramos los ejes
ax.set_axis_off();

# %% [markdown]
# El punto que estaba fuera de Argentina sigue estando en el geodataframe de las universidades, pero no lo mostramos porque está fuera de los límites del mapa de provincias. Para tener una solución definitiva deberíamos eliminarlo del GDF.
# Podemos hacerlo teniendo en cuenta que su latitud y su longitud están por afuera de los límites del mapa de Argentina

# %%
# Limites del mapa de Argentina
prov_miny = gdf_prov.bounds.miny.min()
prov_maxy = gdf_prov.bounds.maxy.max()
prov_minx = gdf_prov.bounds.minx.min()
prov_maxx = gdf_prov.bounds.maxx.max()

# %%
# Nos quedamos con las universidades geocodificadas, incluso con las que están fuera de los límites. 
# Pero eliminamos las que devolvieron Nan
gdf_uni = gdf_uni.loc[gdf_uni['address'].notna()]

# %%
gdf_uni
# Out:
#                        geometry  \
# 0   POINT (-67.52736 -46.45274)
# 1   POINT (-58.37312 -34.59977)
# 3   POINT (-58.28136 -34.77437)
# 5   POINT (-65.76807 -28.46589)
# 6   POINT (-67.49450 -29.16495)
# 8   POINT (-68.47269 -33.20158)
# 14  POINT (-58.74525 -34.52117)
# 15  POINT (-65.32194 -24.18106)
# 16  POINT (-58.56288 -34.67011)
# 17  POINT (-64.28942 -36.62042)
# 18  POINT (-69.23447 -51.62015)
# 22  POINT (-58.39955 -34.59481)
# 25  POINT (-65.01602 -32.34715)
# 29  POINT (-58.79316 -34.64814)
# 30  POINT (-58.27852 -34.70638)
# 33  POINT (-62.99168 -40.81003)
# 34  POINT (-60.66420 -32.94178)
# 35  POINT (-65.40763 -24.72713)
# 36  POINT (-68.54016 -31.57883)
# 37  POINT (-68.59579 -33.02817)
# 38  POINT (-59.47969 -34.25720)
# 39  POINT (-64.24569 -27.73680)
# 40  POINT (-68.34171 -54.82130)
# 41  POINT (-58.52824 -34.60169)
# 42  POINT (-65.21122 -26.83639)
# 43  POINT (-63.23820 -32.41073)
# 44  POINT (-65.46379 -33.66606)
# 45    POINT (11.04803 46.31448)
# 48  POINT (-68.05034 -38.93949)
# 50  POINT (-58.83943 -27.46412)
# 52  POINT (-58.69986 -34.66539)
# 53  POINT (-62.26936 -38.70142)
# 54    POINT (11.04803 46.31448)
# 55  POINT (-58.37299 -34.60463)
#
#                                               address  \
# 0   Dirección de transito, San José Obrero, Oeste,...
# 1   430, Viamonte, Microcentro, San Nicolás, Bueno...
# 3   Avenida San Martín, San Emilio, Florencio Vare...
# 5   Esquiú, Jardín, Jorge Bermudez, San Fernando d...
# 6   22, 9 de Julio, Barrio Mayo, Chilecito, Depart...
# 8   Centro universitario Rivadavia, Jose Hernandez...
# 14  Universidad Nacional de José Clemante Paz, 473...
# 15  Avenida Bolivia, Regimiento de Infanteria de M...
# 16  1903, Florencio Varela, San Justo, Partido de ...
# 17  Universidad Nacional de La Pampa, 353, Coronel...
# 18  Lisandro de la Torre, Gregores, Río Gallegos, ...
# 22  Universidad Nacional de las Artes, 1129, Azcué...
# 25  Poeta Agüero, Barrio San Agustín, Villa de Mer...
# 29  Avenida Bartolomé Mitre, El Obrero, Moreno Cen...
# 30  Universidad Nacional de Quilmes, 352, Roque Sá...
# 33  Universidad Nacional de Río Negro, 450, Colón,...
# 34  Córdoba, Alberto Olmedo, Distrito Centro, Rosa...
# 35  Universidad Nacional de Salta - Campo General ...
# 36  Mitre, Barrio Los Olivos Fontana, Villa Krause...
# 37  Ejército De Los Andes, Barrio Loma Verde, Dist...
# 38  689, Avenida Güiraldes, San Antonio de Areco, ...
# 39  Avenida Belgrano, Centro, La Banda, Departamen...
# 40  Fuegia Basket, Belgrano, Ushuaia, Departamento...
# 41  UNTREF - Sede Rectorado, 2736, 414 - General E...
# 42  Rectorado Universidad Nacional de Tucumán, 491...
# 43  1425, Entre Ríos, Centro Sur, Villa María, Mun...
# 44  Las Heras, Teodoro Fels, Villa Mercedes, Munic...
# 45  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 48  Universidad Nacional del Comahue, 1400, Buenos...
# 50  Rectorado UNNE, 868, 25 de Mayo, Barrio Deport...
# 52  369, General Manuel Belgrano, San Antonio de P...
# 53  Universidad Nacional del Sur, 1253, Avenida Al...
# 54  Nanno, Ville d'Anaunia, Comunità della Val di ...
# 55  Rectorado Universidad Tecnológica Nacional, 44...
#
#                                                Nombre     Acrónimo  \
# 0                                              Nombre     Acrónimo
# 1                         Universidad de Buenos Aires          UBA
# 3               Universidad Nacional Arturo Jauretche         UNAJ
# 5                   Universidad Nacional de Catamarca         UNCa
# 6                   Universidad Nacional de Chilecito  UNChi UNdeC
# 8                        Universidad Nacional de Cuyo  UNCu UNCuyo
# 14                Universidad Nacional de José C. Paz   UNJP UNPAZ
# 15                      Universidad Nacional de Jujuy         UNJu
# 16                 Universidad Nacional de La Matanza   UNLM UNLaM
# 17                   Universidad Nacional de La Pampa       UNLPam
# 18       Universidad Nacional de la Patagonia Austral         UNPA
# 22                  Universidad Nacional de las Artes          UNA
# 25          Universidad Nacional de los Comechingones         UNLC
# 29                     Universidad Nacional de Moreno     UNM UNMo
# 30                    Universidad Nacional de Quilmes          UNQ
# 33                  Universidad Nacional de Río Negro         UNRN
# 34                    Universidad Nacional de Rosario          UNR
# 35                      Universidad Nacional de Salta         UNSa
# 36                   Universidad Nacional de San Juan         UNSJ
# 37                   Universidad Nacional de San Luis         UNSL
# 38       Universidad Nacional de San Antonio de Areco       UNSAdA
# 39        Universidad Nacional de Santiago del Estero         UNSE
# 40  Universidad Nacional de Tierra del Fuego, Antá...        UNTDF
# 41            Universidad Nacional de Tres de Febrero       UNTREF
# 42                    Universidad Nacional de Tucumán          UNT
# 43                Universidad Nacional de Villa María         UNVM
# 44             Universidad Nacional de Villa Mercedes       UNViMe
# 45              Universidad Nacional del Alto Uruguay         UNAU
# 48                   Universidad Nacional del Comahue  UNCOMA UNCo
# 50                  Universidad Nacional del Nordeste         UNNE
# 52                     Universidad Nacional del Oeste          UNO
# 53                       Universidad Nacional del Sur          UNS
# 54         Universidad Nacional Raúl Scalabrini Ortiz         UNSO
# 55                   Universidad Tecnológica Nacional          UTN
#
#                                                  addr
# 0             Dirección, Ciudad, Provincia, Argentina
# 1   Viamonte 430, Buenos Aires, Ciudad de Buenos A...
# 3   Av. San Martín 2002, Florencio Varela, Buenos ...
# 5         Esquiú 612, Catamarca, Catamarca, Argentina
# 6       9 de Julio 22, Chilecito, La Rioja, Argentina
# 8   Centro Universitario, Mendoza, Mendoza, Argentina
# 14  Leandro N. Alem 4731, José C. Paz, Buenos Aire...
# 15  Av. Bolivia 1239, San Salvador de Jujuy, Jujuy...
# 16  Florencio Varela 1903, San Justo, Buenos Aires...
# 17   Coronel Gil 353, Santa Rosa, La Pampa, Argentina
# 18  Lisandro de la Torre 1070, Río Gallegos, Santa...
# 22  Azcuénaga 1129, Buenos Aires, Ciudad de Buenos...
# 25  Poeta Agüero 380, Villa de Merlo, San Luis, Ar...
# 29  Av. Bartolomé Mitre 1891, Moreno, Buenos Aires...
# 30  Roque Sáenz Peña 352, Quilmes, Buenos Aires, A...
# 33            Colón 450, Viedma, Río Negro, Argentina
# 34          Córdoba 181, Rosario, Santa Fe, Argentina
# 35          Av. Bolivia 5150, Salta, Salta, Argentina
# 36         Mitre 396 E, San Juan, San Juan, Argentina
# 37  Ejército de los Andes 950, San Luis, San Luis,...
# 38  Av. Güiraldes 689, San Antonio de Areco, Bueno...
# 39  Av. Belgrano 1912, Santiago del Estero, Santia...
# 40  Fuegia Basket 251, Ushuaia, Tierra del Fuego, ...
# 41  Mosconi 2736, Saenz Peña, Buenos Aires, Argentina
# 42  Ayacucho 491, San Miguel de Tucumán, Tucumán, ...
# 43   Entre Ríos 1425, Villa María, Córdoba, Argentina
# 44  Las Heras 383, Villa Mercedes, San Luis, Argen...
# 45                                                NaN
# 48     Buenos Aires 1400, Neuquén, Neuquén, Argentina
# 50  25 de Mayo 868, Corrientes, Corrientes, Argentina
# 52  Belgrano 369, San Antonio de Padua, Buenos Air...
# 53  Av. Alem 1253, Bahía Blanca, Buenos Aires, Arg...
# 54                                                NaN
# 55  Sarmiento 440, Buenos Aires, Ciudad de Buenos ...

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Creamos un campo lon y lat para cada universidad, para comparar con los limites del mapa.
# Simplemente tomamos el valor x e y de la columna geometry (esto es posible porque es un geodataframe)
gdf_uni['lon'] = gdf_uni['geometry'].x
gdf_uni['lat'] = gdf_uni['geometry'].y

# %%
# Filtramos los que tienen una longitud mayor al límite
gdf_uni.loc[gdf_uni['lon']>prov_maxx]
# Out:
# Empty GeoDataFrame
# Columns: [geometry, address, Nombre, Acrónimo, addr, lon, lat]
# Index: []

# %%
# Nos quedamos con el resto de los puntos, salvo los dos que están fuera del límite..
gdf_uni = gdf_uni.loc[gdf_uni['lon']<prov_maxx]

# %%
# Guardamos el GDF de las universidades como GDF (no como DF)
# gdf_uni.to_file('data/uni.geojson', driver='GeoJSON')
# Out:
# ERROR:fiona._env:Failed to create GeoJSON datasource: data/uni.geojson: data/uni.geojson: No such file or directory
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/ogrext.pyx in fiona.ogrext.gdal_create()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Failed to create GeoJSON datasource: data/uni.geojson: data/uni.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-129-87a8f9f5e3b1> in <cell line: 2>()
#       1 # Guardamos el GDF de las universidades como GDF (no como DF)
# ----> 2 gdf_uni.to_file('data/uni.geojson', driver='GeoJSON')
#
# /usr/local/lib/python3.10/dist-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, index, **kwargs)
#    1261         from geopandas.io.file import _to_file
#    1262
# -> 1263         _to_file(self, filename, driver, schema, index, **kwargs)
#    1264
#    1265     def set_crs(self, crs=None, epsg=None, inplace=False, allow_override=False):
#
# /usr/local/lib/python3.10/dist-packages/geopandas/io/file.py in _to_file(df, filename, driver, schema, index, mode, crs, engine, **kwargs)
#     537
#     538     if engine == "fiona":
# --> 539         _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     540     elif engine == "pyogrio":
#     541         _to_file_pyogrio(df, filename, driver, schema, crs, mode, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/geopandas/io/file.py in _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
#     563         elif crs:
#     564             crs_wkt = crs.to_wkt("WKT1_GDAL")
# --> 565         with fiona.open(
#     566             filename, mode=mode, driver=driver, crs_wkt=crs_wkt, schema=schema, **kwargs
#     567         ) as colxn:
#
# /usr/local/lib/python3.10/dist-packages/fiona/env.py in wrapper(*args, **kwds)
#     455
#     456         with env_ctor(session=session):
# --> 457             return f(*args, **kwds)
#     458
#     459     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/fiona/__init__.py in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     345             )
#     346         elif mode == "w":
# --> 347             colxn = Collection(
#     348                 path,
#     349                 mode,
#
# /usr/local/lib/python3.10/dist-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     244             elif self.mode in ("a", "w"):
#     245                 self.session = WritingSession()
# --> 246                 self.session.start(self, **kwargs)
#     247         except OSError:
#     248             self.session = None
#
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# fiona/ogrext.pyx in fiona.ogrext.gdal_create()
#
# DriverError: Failed to create GeoJSON datasource: data/uni.geojson: data/uni.geojson: No such file or directory

# %%
f, ax = plt.subplots(1, figsize=(30, 20))

# Graficamos las provincias
gdf_prov.plot(ax = ax, alpha=0.5)

# Graficamos las universidades
gdf_uni.plot(alpha=0.3, marker='o', color='red', markersize=15, ax=ax)

# Titulo
ax.set(title='Universidades Nacionales')

# Marcamos cada punto con su acrónimo
for x, y, label in zip(gdf_uni['geometry'].x, gdf_uni['geometry'].y, gdf_uni['Acrónimo']):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points")


# Borramos los ejes
ax.set_axis_off();

# %% [markdown]
# ### Buffers

# %% [markdown]
# El análisis de buffers es una importante tarea en el geoprocesamiento. Se utiliza para obtener una distancia alrededor de un punto.
#
# En este ejemplo, crearemos un buffer alrededor de cada universidad, como proxy de la zona de influencia.
#
# Es necesario saber qué CRS/proyección se está utilizando para obtener el resultado correcto. Necesitamos usar una proyección que mida en metros, no en grados ni en ninguna otra alternativa. Este es un error clásico en el mundo de Geodata.
#
# En una primera aproximación, vamos a seguir trabajando con los puntos localizados en Mendoza Capital.

# %%
gdf_uni = gpd.read_file('https://raw.githubusercontent.com/matog/Flacso_ciencia_de_datos_python_2022/main/Clase4/data/uni.geojson')

# %%
gdf_caba = gpd.read_file('https://raw.githubusercontent.com/mgaitan/departamentos_argentina/master/departamentos-ciudad_autonoma_de_buenos_aires.json')

# %%
gdf_caba.plot()
# Out:
# <Axes: >

# %%
gdf_uba = gdf_uni.loc[gdf_uni['Acrónimo']=='UBA']

# %%
gdf_uba
# Out:
#                                              address  \
# 0  430, Viamonte, San Nicolás, Buenos Aires, Comu...
#
#                         Nombre Acrónimo  \
# 0  Universidad de Buenos Aires      UBA
#
#                                                 addr        lon        lat  \
# 0  Viamonte 430, Buenos Aires, Ciudad de Buenos A... -58.373123 -34.599771
#
#                       geometry
# 0  POINT (-58.37312 -34.59977)

# %%
gdf_uba.crs = {"init": "EPSG:4326"}
gdf_caba.crs = {"init": "EPSG:4326"}
gdf_uba = gdf_uba.to_crs(epsg = 5343)
gdf_caba = gdf_caba.to_crs(epsg = 5343)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# Podemos crear un buffer para todos los registros del GDF (aunque en este caso tenemos solo la UBA), creando una columna para ese fin. El buffer se mide en unidades de medida de del sistema de coordenadas que estemos utilizando en la capa:

# %%
gdf_uba['buffer'] = gdf_uba['geometry'].buffer(1500)

# %%
gdf_uba
# Out:
#                                              address  \
# 0  430, Viamonte, San Nicolás, Buenos Aires, Comu...
#
#                         Nombre Acrónimo  \
# 0  Universidad de Buenos Aires      UBA
#
#                                                 addr        lon        lat  \
# 0  Viamonte 430, Buenos Aires, Ciudad de Buenos A... -58.373123 -34.599771
#
#                           geometry  \
# 0  POINT (2754166.837 6086123.863)
#
#                                               buffer
# 0  POLYGON ((2755666.837 6086123.863, 2755659.614...

# %% [markdown]
# O podemos crear varios buffer individuales para el mismo punto:

# %%
uba_300 = gdf_uba.buffer(300)
uba_800 = gdf_uba.buffer(800)
uba_1000 = gdf_uba.buffer(1000)

# %%
uba_300
# Out:
# 0    POLYGON ((2754466.837 6086123.863, 2754465.393...
# dtype: geometry

# %%
fig, ax = plt.subplots(figsize=(8,6))

gdf_caba.plot(ax=ax)

gdf_uba['buffer'].plot(ax=ax, color='lightblue')
uba_800.plot(ax=ax, color='green', alpha = 0.1)
gdf_uba.plot(ax=ax, color='yellow', markersize=10); # Universidad

ax.set(title='Buffer en columna')

ax.set_axis_off();

# %%
fig, ax = plt.subplots(figsize=(8,6))

gdf_caba.plot(ax=ax)

# Ordenas los buffers de los mas amplios al los mas pequeños, para que los grandes no tapen a los chicos. 
# O ajustar el alpha, que genera transparencia
uba_1000.plot(ax=ax, color='red')
uba_800.plot(ax=ax, color='green', alpha = 0.3)
uba_300.plot(ax=ax, color='gray', alpha = 0.3) # Este buffer es tapado por el punto amarillo de la UBA

gdf_uba.plot(ax=ax, color='yellow', markersize=3); # Universidad
ax.set(title='Buffers individuales')

ax.set_axis_off();

# %% [markdown]
# Nos quedamos con las provincias de Mendoza, San Juan, San Luis y La Rioja, sólo a efectos prácticos y para mejorar la visualización de la información

# %%
gdf_prov_sel = gdf_prov.loc[(gdf_prov['nam']=='Mendoza') | 
                    (gdf_prov['nam']=='San Juan') | 
                    (gdf_prov['nam']=='San Luis') | 
                    (gdf_prov['nam']=='La Rioja')]

# %% [markdown]
# Acá viene un paso clave. Tenemos que convertir los sistemas de coordenadas de referencias a uno que mida distancias en metros (no en grados, ni ninguna otra medida), para poder definir el buffer en metros. Para eso, primero con `init` definimos un sistema de inicio, y con `to_crs`  lo convertimos al epsg 5343, que mide distancias en metros.
# Esto debemos correrlos una sola vez, porque si lo corremos dos veces, borramos la información de `geometry`. Si asi ocurriese, volvemos a cargar el GDF.

# %%
gdf_uni.crs = {"init": "EPSG:4326"}
gdf_prov_sel.crs = {"init": "EPSG:4326"}
gdf_uni = gdf_uni.to_crs(epsg = 5343)
gdf_prov_sel = gdf_prov_sel.to_crs(epsg = 5343)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
# Chequeamos que la información de geometry esté ok
gdf_uni.head(3)
# Out:
#                                              address  \
# 0  430, Viamonte, San Nicolás, Buenos Aires, Comu...
# 1  262, Maipú, San Nicolás, Buenos Aires, Comuna ...
# 2  Avenida San Martín, San Emilio, Florencio Vare...
#
#                                   Nombre Acrónimo  \
# 0            Universidad de Buenos Aires      UBA
# 1     Universidad de la Defensa Nacional    UNDEF
# 2  Universidad Nacional Arturo Jauretche     UNAJ
#
#                                                 addr        lon        lat  \
# 0  Viamonte 430, Buenos Aires, Ciudad de Buenos A... -58.373123 -34.599771
# 1  Maipú 262, Buenos Aires, Ciudad de Buenos Aire... -58.376629 -34.605139
# 2  Av. San Martín 2002, Florencio Varela, Buenos ... -58.281357 -34.774374
#
#                           geometry
# 0  POINT (2754166.837 6086123.863)
# 1  POINT (2753759.287 6085567.249)
# 2  POINT (2759950.333 6065386.799)

# %% [markdown]
# Como queremos generar un buffer para cada universidad, generemos una columna.

# %%
gdf_uni['buffer'] = gdf_uni['geometry'].buffer(30000)

# %%
gdf_prov_sel
# Out:
#     gid  entidad     objeto                    fna        gna       nam in1  \
# 2     3      0.0  Provincia  Provincia de San Luis  Provincia  San Luis  74
# 4     5      0.0  Provincia  Provincia de La Rioja  Provincia  La Rioja  46
# 11   12      0.0  Provincia   Provincia de Mendoza  Provincia   Mendoza  50
# 14   15      0.0  Provincia  Provincia de San Juan  Provincia  San Juan  70
#
#           fdc  sag                                           geometry
# 2   Geografía  IGN  MULTIPOLYGON (((2005183.431 6456459.783, 20105...
# 4   Geografía  IGN  MULTIPOLYGON (((2134525.261 6650268.607, 21263...
# 11  Geografía  IGN  MULTIPOLYGON (((1940807.474 6408091.085, 19408...
# 14  Geografía  IGN  MULTIPOLYGON (((1732320.285 6857608.694, 17323...

# %%
fig, ax = plt.subplots(figsize=(20,12))
# cx.add_basemap(ax, crs='epsg:5343')

# prov.plot(ax=ax, color = 'gray')
gdf_prov_sel.plot(ax=ax, color = 'gray')

gdf_uni['buffer'].plot(ax=ax, color='red', cmap='winter')

# Limites del mapa de provincias
ax.set_ylim(gdf_prov_sel.bounds.miny.min(), gdf_prov_sel.bounds.maxy.max())
ax.set_xlim(gdf_prov_sel.bounds.minx.min(), gdf_prov_sel.bounds.maxx.max())

ax.set(title='Buffers para cada universidad en expresado en metros')


# Borramos los ejes
ax.set_axis_off();

# %% [markdown]
# Link a documentación de cmpa: https://geopandas.org/en/stable/docs/user_guide/mapping.html

# %% [markdown]
# Por mas que hayamos cortado el gráfico según los límites de la capa provincia, quedan algunos puntos que deberíamos borrarlos. Ahora exploraremos operaciones para hacerlo

# %% [markdown]
# ### Overlays y Spatial Joins

# %% [markdown]
# La principal diferencia entre `spatial join` y `overlay` es que el primer mezcla (_merge_) atributos de otro `geodataframe` a la geometría existente y el segundo, crea una nueva geometría (intersercción, diferencia, etc)

# %% [markdown]
# #### Overlays

# %% [markdown]
# https://geopandas.org/en/stable/docs/user_guide/set_operations.html

# %%
gdf_uni_buffer = gpd.GeoDataFrame()
gdf_uni_buffer['geometry'] = gdf_uni['buffer']
# Out:
# <ipython-input-149-4c6049c6a326>:2: FutureWarning: You are adding a column named 'geometry' to a GeoDataFrame constructed without an active geometry column. Currently, this automatically sets the active geometry column to 'geometry' but in the future that will no longer happen. Instead, either provide geometry to the GeoDataFrame constructor (GeoDataFrame(... geometry=GeoSeries()) or use `set_geometry('geometry')` to explicitly set the active geometry column.
#   gdf_uni_buffer['geometry'] = gdf_uni['buffer']

# %%
gdf_uni_buffer.plot()
# Out:
# <Axes: >

# %%
overlay_prov_inter = gpd.overlay(gdf_uni_buffer, gdf_prov_sel, how='intersection')

# %%
overlay_prov_inter.head()
# Out:
#    gid  entidad     objeto                    fna        gna       nam in1  \
# 0    5      0.0  Provincia  Provincia de La Rioja  Provincia  La Rioja  46
# 1   12      0.0  Provincia   Provincia de Mendoza  Provincia   Mendoza  50
# 2   12      0.0  Provincia   Provincia de Mendoza  Provincia   Mendoza  50
# 3    3      0.0  Provincia  Provincia de San Luis  Provincia  San Luis  74
# 4    3      0.0  Provincia  Provincia de San Luis  Provincia  San Luis  74
#
#          fdc  sag                                           geometry
# 0  Geografía  IGN  POLYGON ((1968407.292 6763060.276, 1967975.309...
# 1  Geografía  IGN  POLYGON ((1858826.676 6318371.768, 1858394.693...
# 2  Geografía  IGN  POLYGON ((1847965.510 6337999.065, 1847533.527...
# 3  Geografía  IGN  POLYGON ((2166930.480 6371947.015, 2164074.649...
# 4  Geografía  IGN  POLYGON ((2136564.565 6253170.826, 2136132.582...

# %%
fig, ax = plt.subplots(figsize=(20,12))

# gdf_prov_sel.plot(ax=ax, color = 'gray', edgecolor='k', cmap='tab10')
overlay_prov_inter.plot(ax = ax, color = 'green')

# Borramos los ejes
ax.set_axis_off();

# %%
overlay_prov_diff = gpd.overlay(gdf_prov_sel, gdf_uni_buffer, how='difference')

# %%
fig, ax = plt.subplots(figsize=(20,12))

overlay_prov_diff.plot(ax = ax, color = 'red')

# Borramos los ejes
ax.set_axis_off();
plt.savefig('books_read.png')

# %%
gdf_prov_sel.plot()
# Out:
# <Axes: >

# %%
gdf_prov_sel_disolve = gdf_prov_sel.dissolve()

# %%
gdf_prov_sel_disolve.plot()
# Out:
# <Axes: >

# %%
localidades = pd.read_csv('https://infra.datos.gob.ar/catalog/modernizacion/dataset/7/distribution/7.29/download/localidades-censales.csv')

# %%
localidades = localidades[['centroide_lat','centroide_lon', 'nombre']]

# %%
gdf_localidades = gpd.GeoDataFrame(localidades, 
                                   geometry=gpd.points_from_xy(localidades['centroide_lon'], 
                                                               localidades['centroide_lat']),
                                   crs='EPSG:4326')

# %%
gdf_localidades.crs = {"init": "EPSG:4326"}
gdf_localidades = gdf_localidades.to_crs(epsg = 5343)
# prov_sel_disolve.crs = {"init": "EPSG:4326"}
# prov_sel_disolve = prov_sel_disolve.to_crs(epsg = 5343)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
gdf_localidades.head(3)
# Out:
#    centroide_lat  centroide_lon         nombre  \
# 0     -37.823387     -60.484640  Juan E. Barra
# 1     -37.625498     -58.746186      Napaleofú
# 2     -37.542635     -58.340719    Ramos Otero
#
#                           geometry
# 0  POINT (2515522.934 5751009.736)
# 1  POINT (2672633.378 5752385.898)
# 2  POINT (2710043.880 5756382.477)

# %% [markdown]
# #### Spatial Joins

# %%
s_join = gdf_localidades.sjoin(gdf_prov_sel_disolve, how="inner", predicate='intersects')

# %%
s_join
# Out:
#       centroide_lat  centroide_lon                    nombre  \
# 1979     -28.556467     -66.817983                 Aimogasta
# 1980     -28.583403     -66.803641                    Arauco
# 1981     -28.387179     -66.836912    Bañado de los Pantanos
# 1982     -28.664826     -66.516620            Estación Mazán
# 1983     -28.591775     -66.556389  Termas de Santa Teresita
# ...             ...            ...                       ...
# 2844     -32.629812     -65.551144               Las Lagunas
# 2845     -32.876974     -65.634530               Paso Grande
# 2846     -32.671401     -65.662627                Potrerillo
# 2847     -32.413269     -65.675931                San Martín
# 2848     -32.533964     -65.647704            Villa de Praga
#
#                              geometry  index_right  gid  entidad     objeto  \
# 1979  POINT (2007448.749 6830865.910)            0    3      0.0  Provincia
# 1980  POINT (2008725.158 6827812.803)            0    3      0.0  Provincia
# 1981  POINT (2006402.395 6849749.781)            0    3      0.0  Provincia
# 1982  POINT (2036454.196 6817507.525)            0    3      0.0  Provincia
# 1983  POINT (2032927.689 6825802.489)            0    3      0.0  Provincia
# ...                               ...          ...  ...      ...        ...
# 2844  POINT (2105708.824 6371844.804)            0    3      0.0  Provincia
# 2845  POINT (2096204.488 6344839.134)            0    3      0.0  Provincia
# 2846  POINT (2094942.603 6367854.525)            0    3      0.0  Provincia
# 2847  POINT (2095402.604 6396629.220)            0    3      0.0  Provincia
# 2848  POINT (2097262.579 6383051.203)            0    3      0.0  Provincia
#
#                         fna        gna       nam in1        fdc  sag
# 1979  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# 1980  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# 1981  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# 1982  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# 1983  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# ...                     ...        ...       ...  ..        ...  ...
# 2844  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# 2845  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# 2846  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# 2847  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
# 2848  Provincia de San Luis  Provincia  San Luis  74  Geografía  IGN
#
# [391 rows x 14 columns]

# %%
fig, ax = plt.subplots(figsize=(20,12))

gdf_prov_sel_disolve.plot(ax=ax, color = 'gray', alpha = 0.6)
s_join.plot(ax=ax, color = 'red', alpha = 0.5)

# Borramos los ejes
ax.set_axis_off();

# %% [markdown]
# Ahora vamos a pegarle a estos puntos que están en mendoza, el nombre del departamento. Ya está en el GDF esa info, por lo que la vamos a borrar, y buscar en la capa de departamentos con un `spatial_join`.

# %%
gdf_depart = gpd.read_file('https://github.com/matog/Flacso_ciencia_de_datos_python_2023/raw/main/Clase4/data/departamento.zip')

# %%
gdf_depart.crs = {"init": "EPSG:4326"}
gdf_depart = gdf_depart.to_crs(epsg = 5343)
# Out:
# /usr/local/lib/python3.10/dist-packages/pyproj/crs/crs.py:141: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %% [markdown]
# Nos quedamos solo con el campo geometry, que tiene la lat y lon de cada punto. A ese campo, le vamos a pegar el resto de la info de la capa de departamentos

# %%
s_join = s_join[['geometry']]

# %%
# Solo quedo la columna necesaria para el spatial join
s_join
# Out:
#                              geometry
# 1979  POINT (2007448.749 6830865.910)
# 1980  POINT (2008725.158 6827812.803)
# 1981  POINT (2006402.395 6849749.781)
# 1982  POINT (2036454.196 6817507.525)
# 1983  POINT (2032927.689 6825802.489)
# ...                               ...
# 2844  POINT (2105708.824 6371844.804)
# 2845  POINT (2096204.488 6344839.134)
# 2846  POINT (2094942.603 6367854.525)
# 2847  POINT (2095402.604 6396629.220)
# 2848  POINT (2097262.579 6383051.203)
#
# [391 rows x 1 columns]

# %%
gdf_depar_join = s_join.sjoin(gdf_depart, how="inner", predicate='intersects')

# %%
gdf_depar_join
# Out:
#                              geometry  index_right  gid        objeto  \
# 1979  POINT (2007448.749 6830865.910)          102   65  Departamento
# 1980  POINT (2008725.158 6827812.803)          102   65  Departamento
# 1981  POINT (2006402.395 6849749.781)          102   65  Departamento
# 1982  POINT (2036454.196 6817507.525)          102   65  Departamento
# 1983  POINT (2032927.689 6825802.489)          102   65  Departamento
# ...                               ...          ...  ...           ...
# 2844  POINT (2105708.824 6371844.804)          480  482  Departamento
# 2845  POINT (2096204.488 6344839.134)          480  482  Departamento
# 2846  POINT (2094942.603 6367854.525)          480  482  Departamento
# 2847  POINT (2095402.604 6396629.220)          480  482  Departamento
# 2848  POINT (2097262.579 6383051.203)          480  482  Departamento
#
#                                              fna           gna  \
# 1979                         Departamento Arauco  Departamento
# 1980                         Departamento Arauco  Departamento
# 1981                         Departamento Arauco  Departamento
# 1982                         Departamento Arauco  Departamento
# 1983                         Departamento Arauco  Departamento
# ...                                          ...           ...
# 2844  Departamento Libertador General San Martín  Departamento
# 2845  Departamento Libertador General San Martín  Departamento
# 2846  Departamento Libertador General San Martín  Departamento
# 2847  Departamento Libertador General San Martín  Departamento
# 2848  Departamento Libertador General San Martín  Departamento
#
#                                 nam    in1                            fdc  sag
# 1979                         Arauco  46007                            IGN  IGN
# 1980                         Arauco  46007                            IGN  IGN
# 1981                         Arauco  46007                            IGN  IGN
# 1982                         Arauco  46007                            IGN  IGN
# 1983                         Arauco  46007                            IGN  IGN
# ...                             ...    ...                            ...  ...
# 2844  Libertador General San Martín  74063  Direc. de Geodesia y Catastro  IGN
# 2845  Libertador General San Martín  74063  Direc. de Geodesia y Catastro  IGN
# 2846  Libertador General San Martín  74063  Direc. de Geodesia y Catastro  IGN
# 2847  Libertador General San Martín  74063  Direc. de Geodesia y Catastro  IGN
# 2848  Libertador General San Martín  74063  Direc. de Geodesia y Catastro  IGN
#
# [782 rows x 10 columns]

# %%
fig, ax = plt.subplots(figsize=(20,12))

gdf_depar_join.plot(ax=ax, color = 'gray', alpha = 0.6)
gdf_depart.plot(ax=ax, color = 'yellow', alpha = 0.5)

# Borramos los ejes
ax.set_axis_off();

# %%
df.to_excel('nombre del archivo.xls', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-177-b863a76f1c2a> in <cell line: 1>()
# ----> 1 df.to_excel('nombre del archivo.xls', index = False)
#
# NameError: name 'df' is not defined
